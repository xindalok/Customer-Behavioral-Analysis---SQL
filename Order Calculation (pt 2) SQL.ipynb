# %% [markdown]
# #### (Part 1)
#
# ### SUM Questions:
# 1. Find the total amount of poster_qty paper ordered in the orders table.
# 2. Find the total amount of standard_qty paper ordered in the orders table.
# 3. Find the total dollar amount of sales using the total_amt_usd in the orders table.
# 4. Find the total amount spent on standard_amt_usd and gloss_amt_usd paper for each order in the orders table. This should give a dollar amount for each order in the table.
# 5. Find the unit cost of each paper.
#
# ### MIN, MAX, & AVG Questions:
# 6. When was the earliest order ever placed?
# 7. Try performing the same query as in question 6 without using an aggregation function.
# 8. When did the most recent (latest) web_event occur?
# 9. Try to perform the result of the previous query without using an aggregation function.
# 10. Find the mean (AVERAGE) amount spent per order on each paper type, as well as the mean amount of each paper type purchased per order. Your final answer should have 6 values - one for each paper type for the average number of sales, as well as the average amount.
#
# ____________
#
# #### (Part 2)
#
# ### GROUP BY Questions:
# 11. Which account (by name) placed the earliest order? Include the account name and the date of the order.
# 12. Find the total sales in USD for each account. You should include two columns - the total sales for each company's orders in USD and the company name.
# 13. Via what channel did the most recent (latest) web_event occur, which account was associated with this web_event? Your query should return only three values - the date, channel, and account name.
# 14. Find the total number of times each type of channel from the web_events was used. Your final table should have two columns - the channel and the number of times the channel was used.
# 15. Who was the primary contact associated with the earliest web_event?
# 16. What was the smallest order placed by each account in terms of total USD? Provide only two columns - the account name and the total USD. Order from smallest dollar amounts to largest.
# 17. Find the number of sales reps in each region. Your final table should have two columns - the region and the number of sales reps. Order from fewest reps to most reps.
# 18. For each account, determine the average amount of each type of paper they purchased across their orders. Your result should have four columns - one for the account name and one for the average quantity purchased for each of the paper types for each account.
# 19. For each account, determine the average amount spent per order on each paper type. Your result should have four columns - one for the account name and one for the average amount spent on each paper type.
# 20. Determine the number of times a particular channel was used in the web_events table for each sales rep. Your final table should have three columns - the name of the sales rep, the channel, and the number of occurrences. Order your table with the highest number of occurrences first.
# 21. Determine the number of times a particular channel was used in the web_events table for each region. Your final table should have three columns - the region name, the channel, and the number of occurrences. Order your table with the highest number of occurrences first.
#
# _______
#
# #### (Part 3)
#
# ### DISTINCT Questions:
# 22. Are any accounts associated with more than one region?
# 23. Have any sales reps worked on more than one account?
#
# ### HAVING Questions:
# 24. How many of the sales reps have more than 5 accounts that they manage?
# 25. How many accounts have more than 20 orders?
# 26. Which account has the most orders?
# 27. How many accounts spent more than 30,000 USD total across all orders?
# 28. Which accounts spent less than 1,000 USD total across all orders?
# 29. Which account has spent the most with us?
# 30. Which account has spent the least with us?
# 31. Which accounts used Facebook as a channel to contact customers more than 6 times?
# 32. Which account used Facebook most as a channel?
# 33. Which channel was most frequently used by most accounts?
#
#
# _______
#
# #### (Part 4)
#
# ### DATE Function Questions:
# 34. Find the sales in terms of total dollars for all orders in each year, ordered from greatest to least.
# 35. Which month did Parch & Posey have the greatest sales in terms of total dollars? Are all months evenly represented by the dataset?
# 36. Which year did Parch & Posey have the greatest sales in terms of total number of orders? Are all years evenly represented by the dataset?
# 37. Which month did Parch & Posey have the greatest sales in terms of total number of orders? Are all months evenly represented by the dataset?
# 38. In which month of which year did Walmart spend the most on gloss paper in terms of dollars?
#
# ### CASE Questions:
# 39. Write a query to display for each order, the account ID, total amount of the order, and the level of the order - ‘Large’ or ‘Small’ - depending on if the order is 3000 USD or more, or smaller than 3000 USD.
# 40. Write a query to display the number of orders in each of three categories, based on the total number of items in each order. The three categories are: 'At Least 2000', 'Between 1000 and 2000' and 'Less than 1000'.
# 41. We would like to understand 3 different levels of customers based on the amount associated with their purchases. The top level includes anyone with a Lifetime Value (total sales of all orders) greater than 200,000 USD. The second level is between 200,000 and 100,000 USD. The lowest level is anyone under 100,000 USD. Provide a table that includes the level associated with each account. You should provide the account name, the total sales of all orders for the customer, and the level. Order with the top spending customers listed first.
# 42. We would now like to perform a similar calculation to the first, but we want to obtain the total amount spent by customers only in 2016 and 2017. Keep the same levels as in the previous question. Order with the top spending customers listed first.

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /opt/anaconda3/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (3.14.0)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (8.20.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (2.0.38)
# Requirement already satisfied: sqlparse in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:Champions12!@localhost:5432/postgres

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# DO $$
# BEGIN
#     IF NOT EXISTS (SELECT 1 FROM information_schema.tables WHERE table_name = 'orders_consolidated') THEN
#         CREATE TABLE orders_consolidated AS
#         SELECT
#             o.*,
#             a.name AS company,
#             a.primary_poc
#         FROM orders AS o
#         JOIN accounts AS a
#         ON a.id = o.account_id;
#     END IF;
# END $$;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# Done.
# []

# %% [markdown]
# #### 11. Which account (by name) placed the earliest order? Include the account name and the date of the order.

# %%
# %%sql
# SELECT
#     company,
#     MIN(occurred_at) AS earliest_order
# FROM orders_consolidated
# GROUP BY company
# ORDER BY earliest_order
# LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [('DISH Network', datetime.datetime(2013, 12, 4, 4, 22, 44))]

# %% [markdown]
# #### 12. Find the total sales in USD for each account. You should include two columns - the total sales for each company's orders in USD and the company name.

# %%
# %%sql
# SELECT
#     company,
#     SUM(total_amt_usd) AS total_spend
# FROM orders_consolidated
# GROUP BY company
# ORDER BY total_spend DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 350 rows affected.
# [('EOG Resources', Decimal('382873.30')),
#  ('Mosaic', Decimal('345618.59')),
#  ('IBM', Decimal('326819.48')),
#  ('General Dynamics', Decimal('300694.79')),
#  ('Republic Services', Decimal('293861.14')),
#  ('Leucadia National', Decimal('291047.25')),
#  ('Arrow Electronics', Decimal('281018.36')),
#  ('Sysco', Decimal('278575.64')),
#  ('Supervalu', Decimal('275288.30')),
#  ('Archer Daniels Midland', Decimal('272672.84')),
#  ('Western Digital', Decimal('269155.34')),
#  ('Pacific Life', Decimal('255319.18')),
#  ('DISH Network', Decimal('253635.75')),
#  ('Fluor', Decimal('251299.77')),
#  ('United States Steel', Decimal('244695.99')),
#  ('Avis Budget Group', Decimal('241711.25')),
#  ('Centene', Decimal('238962.47')),
#  ('Aetna', Decimal('237781.30')),
#  ('United Technologies', Decimal('235051.07')),
#  ('Freddie Mac', Decimal('234225.65')),
#  ('Core-Mark Holding', Decimal('231856.98')),
#  ('KKR', Decimal('217473.85')),
#  ('Disney', Decimal('205886.97')),
#  ('Wells Fargo', Decimal('200174.66')),
#  ('Bristol-Myers Squibb', Decimal('188457.46')),
#  ('Goodyear Tire & Rubber', Decimal('185463.76')),
#  ('Jarden', Decimal('179761.43')),
#  ('Intel', Decimal('167717.40')),
#  ('CHS', Decimal('167271.80')),
#  ('Best Buy', Decimal('163887.39')),
#  ('ADP', Decimal('163579.18')),
#  ('Paccar', Decimal('161294.62')),
#  ('Citigroup', Decimal('160051.04')),
#  ('Prudential Financial', Decimal('157782.52')),
#  ('Guardian Life Ins. Co. of America', Decimal('157523.24')),
#  ('Travelers Cos.', Decimal('156582.24')),
#  ('Ford Motor', Decimal('154811.43')),
#  ('Thermo Fisher Scientific', Decimal('153705.10')),
#  ('American Family Insurance Group', Decimal('153015.87')),
#  ('BlackRock', Decimal('147599.56')),
#  ('Pfizer', Decimal('144865.83')),
#  ('Emerson Electric', Decimal('143471.26')),
#  ('TJX', Decimal('140046.68')),
#  ('Sears Holdings', Decimal('139015.09')),
#  ("Land O'Lakes", Decimal('138323.59')),
#  ('Philip Morris International', Decimal('137600.67')),
#  ('Marathon Petroleum', Decimal('137227.88')),
#  ('Charter Communications', Decimal('135924.15')),
#  ('AutoNation', Decimal('135822.85')),
#  ('Franklin Resources', Decimal('135730.44')),
#  ('Ecolab', Decimal('135517.95')),
#  ('Synnex', Decimal('134039.25')),
#  ('FirstEnergy', Decimal('132868.82')),
#  ('National Oilwell Varco', Decimal('131318.64')),
#  ('Phillips 66', Decimal('131173.41')),
#  ('Monsanto', Decimal('130964.11')),
#  ('Cisco Systems', Decimal('130917.00')),
#  ('Colgate-Palmolive', Decimal('130893.51')),
#  ('Walgreens Boots Alliance', Decimal('130153.59')),
#  ('3M', Decimal('127945.10')),
#  ('Cigna', Decimal('127671.94')),
#  ('New York Life Insurance', Decimal('126898.91')),
#  ('Southwest Airlines', Decimal('125968.04')),
#  ('Walmart', Decimal('124014.87')),
#  ('BB&T Corp.', Decimal('123847.32')),
#  ('Entergy', Decimal('123503.18')),
#  ('CST Brands', Decimal('122957.11')),
#  ('Target', Decimal('120523.91')),
#  ('FedEx', Decimal('119965.08')),
#  ('State Street Corp.', Decimal('119173.59')),
#  ('United Continental Holdings', Decimal('118879.76')),
#  ('Duke Energy', Decimal('118867.17')),
#  ('Aflac', Decimal('117862.77')),
#  ('Altria Group', Decimal('116165.15')),
#  ('Verizon', Decimal('115376.17')),
#  ('PPL', Decimal('112176.03')),
#  ('State Farm Insurance Cos.', Decimal('111810.55')),
#  ('Fidelity National Financial', Decimal('110027.29')),
#  ('Western Refining', Decimal('108579.84')),
#  ('Lithia Motors', Decimal('107142.63')),
#  ('Occidental Petroleum', Decimal('105115.44')),
#  ('CDW', Decimal('101553.15')),
#  ('SunTrust Banks', Decimal('99125.76')),
#  ('D.R. Horton', Decimal('98474.44')),
#  ('Abbott Laboratories', Decimal('96819.92')),
#  ('Allstate', Decimal('96779.18')),
#  ('Celgene', Decimal('96593.53')),
#  ('Farmers Insurance Exchange', Decimal('96376.94')),
#  ('Raytheon', Decimal('94725.92')),
#  ('J.P. Morgan Chase', Decimal('94684.25')),
#  ('eBay', Decimal('94244.44')),
#  ('Bank of America Corp.', Decimal('93217.80')),
#  ("Kohl's", Decimal('90105.16')),
#  ('Hormel Foods', Decimal('88946.14')),
#  ('Honeywell International', Decimal('86362.70')),
#  ('PayPal Holdings', Decimal('84768.94')),
#  ('Kellogg', Decimal('83419.38')),
#  ('Amgen', Decimal('82013.05')),
#  ('Caterpillar', Decimal('81700.33')),
#  ('PG&E Corp.', Decimal('81697.27')),
#  ('Anadarko Petroleum', Decimal('80328.56')),
#  ('HollyFrontier', Decimal('79488.37')),
#  ('Jabil Circuit', Decimal('79246.93')),
#  ('Lincoln National', Decimal('77628.11')),
#  ('Nationwide', Decimal('76630.92')),
#  ('Jacobs Engineering Group', Decimal('75600.49')),
#  ('Broadcom', Decimal('75130.50')),
#  ('Crown Holdings', Decimal('75110.81')),
#  ('Public Service Enterprise Group', Decimal('73833.01')),
#  ('Progressive', Decimal('72875.84')),
#  ('Stanley Black & Decker', Decimal('72788.52')),
#  ('Capital One Financial', Decimal('72595.01')),
#  ('Time Warner', Decimal('69479.06')),
#  ('Global Partners', Decimal('67909.96')),
#  ('Cameron International', Decimal('67459.65')),
#  ('Illinois Tool Works', Decimal('67439.95')),
#  ('Avnet', Decimal('66812.24')),
#  ('Molina Healthcare', Decimal('66381.57')),
#  ('AutoZone', Decimal('65958.07')),
#  ('Boeing', Decimal('65091.39')),
#  ('Dominion Resources', Decimal('64604.00')),
#  ('Merck', Decimal('64536.17')),
#  ('CarMax', Decimal('64251.56')),
#  ('Precision Castparts', Decimal('63743.89')),
#  ('Cognizant Technology Solutions', Decimal('62504.05')),
#  ('Gilead Sciences', Decimal('62148.87')),
#  ('Genuine Parts', Decimal('61561.44')),
#  ('Visa', Decimal('61255.50')),
#  ('Nucor', Decimal('60936.18')),
#  ('Kroger', Decimal('59946.40')),
#  ('NRG Energy', Decimal('59727.21')),
#  ('International Paper', Decimal('59086.76')),
#  ('Time Warner Cable', Decimal('57130.53')),
#  ('Eversource Energy', Decimal('57059.76')),
#  ('Discover Financial Services', Decimal('57035.05')),
#  ('Community Health Systems', Decimal('56644.60')),
#  ("Toys 'R' Us", Decimal('56179.21')),
#  ('HP', Decimal('56162.34')),
#  ('Ameriprise Financial', Decimal('55883.55')),
#  ('Kinder Morgan', Decimal('54891.56')),
#  ('Texas Instruments', Decimal('54792.72')),
#  ('United Natural Foods', Decimal('54443.06')),
#  ('Qualcomm', Decimal('54114.02')),
#  ('Valero Energy', Decimal('52020.60')),
#  ('AT&T', Decimal('51647.76')),
#  ('Office Depot', Decimal('51477.19')),
#  ('HD Supply Holdings', Decimal('50888.03')),
#  ('Dollar General', Decimal('49975.93')),
#  ('Reynolds American', Decimal('49930.29')),
#  ('Freeport-McMoRan', Decimal('49162.70')),
#  ('Northrop Grumman', Decimal('48578.16')),
#  ('Performance Food Group', Decimal('47645.86')),
#  ('Anthem', Decimal('47487.78')),
#  ('Tyson Foods', Decimal('47417.76')),
#  ("McDonald's", Decimal('47258.13')),
#  ('USAA', Decimal('46822.63')),
#  ('Chevron', Decimal('46725.41')),
#  ('PNC Financial Services Group', Decimal('46208.37')),
#  ('First Data', Decimal('45967.25')),
#  ("Lowe's", Decimal('45873.47')),
#  ('American Express', Decimal('45557.51')),
#  ('CenturyLink', Decimal('44535.04')),
#  ('Chesapeake Energy', Decimal('44534.95')),
#  ('Alphabet', Decimal('44407.22')),
#  ('Coca-Cola', Decimal('43692.29')),
#  ('Southern', Decimal('42881.21')),
#  ('Twenty-First Century Fox', Decimal('42065.82')),
#  ('BorgWarner', Decimal('41242.06')),
#  ('Omnicom Group', Decimal('41161.06')),
#  ('NGL Energy Partners', Decimal('40607.07')),
#  ('Icahn Enterprises', Decimal('38851.15')),
#  ('AmerisourceBergen', Decimal('38741.81')),
#  ('Hilton Worldwide Holdings', Decimal('38648.01')),
#  ('Sempra Energy', Decimal('38569.85')),
#  ('GameStop', Decimal('38469.65')),
#  ('Thrivent Financial for Lutherans', Decimal('38204.46')),
#  ('Estee Lauder', Decimal('38198.82')),
#  ('Johnson Controls', Decimal('37796.28')),
#  ('Ally Financial', Decimal('37653.96')),
#  ('Mondelez International', Decimal('37465.37')),
#  ('Edison International', Decimal('37010.95')),
#  ('EMC', Decimal('36982.12')),
#  ('Murphy USA', Decimal('36294.27')),
#  ('R.R. Donnelley & Sons', Decimal('36218.43')),
#  ('Becton Dickinson', Decimal('35961.76')),
#  ('CSX', Decimal('35759.70')),
#  ('Henry Schein', Decimal('35487.34')),
#  ('Cummins', Decimal('34839.82')),
#  ('News Corp.', Decimal('34675.03')),
#  ('DaVita HealthCare Partners', Decimal('33982.78')),
#  ('Viacom', Decimal('33673.86')),
#  ('Tenet Healthcare', Decimal('33028.08')),
#  ('Whirlpool', Decimal('32965.13')),
#  ('Humana', Decimal('32937.93')),
#  ('Halliburton', Decimal('32645.38')),
#  ('General Mills', Decimal('32226.37')),
#  ('American Electric Power', Decimal('32044.55')),
#  ('Enterprise Products Partners', Decimal('31971.72')),
#  ('Nordstrom', Decimal('31273.02')),
#  ('Oracle', Decimal('31231.56')),
#  ('Costco', Decimal('30741.01')),
#  ('Group 1 Automotive', Decimal('30708.92')),
#  ('PepsiCo', Decimal('30095.72')),
#  ('American Airlines Group', Decimal('30083.18')),
#  ('Kimberly-Clark', Decimal('29151.21')),
#  ('Amazon.com', Decimal('28678.06')),
#  ('Yum Brands', Decimal('28296.53')),
#  ('Computer Sciences', Decimal('28012.07')),
#  ('Health Net', Decimal('27733.33')),
#  ('Exelon', Decimal('27558.30')),
#  ('US Foods Holding', Decimal('27074.63')),
#  ('U.S. Bancorp', Decimal('26641.71')),
#  ('Dean Foods', Decimal('26514.93')),
#  ('Penske Automotive Group', Decimal('26485.87')),
#  ('Textron', Decimal('26339.70')),
#  ('Campbell Soup', Decimal('25765.95')),
#  ('Kraft Heinz', Decimal('25765.17')),
#  ('DuPont', Decimal('25526.30')),
#  ('Laboratory Corp. of America', Decimal('25507.06')),
#  ('General Electric', Decimal('25335.68')),
#  ('Ingram Micro', Decimal('25198.55')),
#  ('Union Pacific', Decimal('25107.81')),
#  ('Ross Stores', Decimal('24961.87')),
#  ('Lear', Decimal('23718.31')),
#  ('CVS Health', Decimal('23667.51')),
#  ('Facebook', Decimal('23522.79')),
#  ('Procter & Gamble', Decimal('22961.03')),
#  ('Unum Group', Decimal('22734.13')),
#  ('Baxter International', Decimal('22681.17')),
#  ('Navistar International', Decimal('22484.81')),
#  ('L-3 Communications', Decimal('22266.77')),
#  ('Norfolk Southern', Decimal('22100.01')),
#  ('PPG Industries', Decimal('21960.88')),
#  ('UnitedHealth Group', Decimal('21937.08')),
#  ('Aramark', Decimal('21692.01')),
#  ('Apple', Decimal('20767.15')),
#  ('Morgan Stanley', Decimal('20277.57')),
#  ('Hartford Financial Services Group', Decimal('20257.43')),
#  ('Whole Foods Market', Decimal('20240.66')),
#  ("Peter Kiewit Sons'", Decimal('20232.97')),
#  ('Huntsman', Decimal('20092.35')),
#  ('Xcel Energy', Decimal('19975.91')),
#  ('Masco', Decimal('19963.61')),
#  ('Alcoa', Decimal('19882.16')),
#  ('Energy Transfer Equity', Decimal('19539.86')),
#  ('Baker Hughes', Decimal('19409.95')),
#  ('Biogen', Decimal('19386.53')),
#  ('Tech Data', Decimal('19218.88')),
#  ('ConAgra Foods', Decimal('19142.48')),
#  ('Express Scripts Holding', Decimal('19090.45')),
#  ('Praxair', Decimal('19023.36')),
#  ('AECOM', Decimal('18491.51')),
#  ('PBF Energy', Decimal('18285.93')),
#  ('VF', Decimal('18251.39')),
#  ('Johnson & Johnson', Decimal('18242.74')),
#  ('L Brands', Decimal('17439.25')),
#  ('MGM Resorts International', Decimal('16976.76')),
#  ('Liberty Mutual Insurance Group', Decimal('16923.55')),
#  ('Gap', Decimal('16791.91')),
#  ('Univar', Decimal('16626.60')),
#  ('Eastman Chemical', Decimal('16303.42')),
#  ('Marsh & McLennan', Decimal('16257.21')),
#  ('Voya Financial', Decimal('15782.23')),
#  ('Parker-Hannifin', Decimal('15727.19')),
#  ('Staples', Decimal('15716.26')),
#  ('ConocoPhillips', Decimal('15578.40')),
#  ('Microsoft', Decimal('15454.01')),
#  ('McKesson', Decimal('15184.46')),
#  ('Principal Financial', Decimal('15177.80')),
#  ('Starbucks', Decimal('14875.19')),
#  ('SpartanNash', Decimal('14629.16')),
#  ('Tesoro', Decimal('14482.60')),
#  ('Owens & Minor', Decimal('13507.23')),
#  ('WestRock', Decimal('13282.42')),
#  ('AES', Decimal('13038.64')),
#  ('Comcast', Decimal('12868.38')),
#  ('Northwestern Mutual', Decimal('11862.92')),
#  ('Air Products & Chemicals', Decimal('11814.55')),
#  ('Plains GP Holdings', Decimal('11531.70')),
#  ('DTE Energy', Decimal('11501.84')),
#  ('AbbVie', Decimal('11243.63')),
#  ('Hertz Global Holdings', Decimal('10959.77')),
#  ('World Fuel Services', Decimal('10833.11')),
#  ('Marriott International', Decimal('10779.77')),
#  ('PVH', Decimal('10699.35')),
#  ('UPS', Decimal('10678.77')),
#  ('Home Depot', Decimal('10667.46')),
#  ('MasterCard', Decimal('10555.35')),
#  ('HCA Holdings', Decimal('10323.23')),
#  ('Autoliv', Decimal('10282.96')),
#  ('Reinsurance Group of America', Decimal('10264.51')),
#  ('Dollar Tree', Decimal('10212.06')),
#  ('Reliance Steel & Aluminum', Decimal('10187.64')),
#  ('Waste Management', Decimal('10067.87')),
#  ('General Motors', Decimal('9995.05')),
#  ('AIG', Decimal('9980.93')),
#  ("O'Reilly Automotive", Decimal('9914.23')),
#  ('WellCare Health Plans', Decimal('9743.13')),
#  ('CBRE Group', Decimal('9715.71')),
#  ('Newmont Mining', Decimal('9618.81')),
#  ("Macy's", Decimal('9613.32')),
#  ('Devon Energy', Decimal('9536.55')),
#  ('Eli Lilly', Decimal('9339.20')),
#  ('Xerox', Decimal('8759.93')),
#  ('CBS', Decimal('8648.07')),
#  ('Dow Chemical', Decimal('8431.81')),
#  ('W.W. Grainger', Decimal('8384.61')),
#  ('Publix Super Markets', Decimal('8364.40')),
#  ('Danaher', Decimal('8133.47')),
#  ('TIAA', Decimal('7971.51')),
#  ('Corning', Decimal('7940.37')),
#  ('MetLife', Decimal('7615.47')),
#  ('Berkshire Hathaway', Decimal('7474.32')),
#  ('C.H. Robinson Worldwide', Decimal('7460.32')),
#  ('ManpowerGroup', Decimal('7313.08')),
#  ('Cardinal Health', Decimal('7210.91')),
#  ('Sonic Automotive', Decimal('7192.13')),
#  ('Advance Auto Parts', Decimal('6962.07')),
#  ('Liberty Interactive', Decimal('6497.70')),
#  ('Genworth Financial', Decimal('6402.38')),
#  ('Tenneco', Decimal('5739.63')),
#  ('Veritiv', Decimal('5735.41')),
#  ('Rite Aid', Decimal('5616.90')),
#  ('NextEra Energy', Decimal('5321.23')),
#  ('Universal Health Services', Decimal('5269.51')),
#  ('Stryker', Decimal('4521.36')),
#  ('Massachusetts Mutual Life Insurance', Decimal('3927.05')),
#  ('Fannie Mae', Decimal('3780.53')),
#  ('J.C. Penney', Decimal('3253.04')),
#  ('Applied Materials', Decimal('3093.95')),
#  ('Mohawk Industries', Decimal('3025.65')),
#  ('Oneok', Decimal('2844.46')),
#  ('Exxon Mobil', Decimal('2734.59')),
#  ('Consolidated Edison', Decimal('2674.04')),
#  ('Lennar', Decimal('2670.97')),
#  ('Loews', Decimal('2566.22')),
#  ('Lockheed Martin', Decimal('2440.31')),
#  ('Micron Technology', Decimal('2438.51')),
#  ('Sherwin-Williams', Decimal('2372.95')),
#  ('INTL FCStone', Decimal('2372.11')),
#  ('Bank of New York Mellon Corp.', Decimal('2155.98')),
#  ('Priceline Group', Decimal('2129.24')),
#  ('Ball', Decimal('1982.74')),
#  ('Assurant', Decimal('1235.81')),
#  ('Las Vegas Sands', Decimal('1113.29')),
#  ('Bed Bath & Beyond', Decimal('1069.64')),
#  ('Deere', Decimal('1036.57')),
#  ('Level 3 Communications', Decimal('881.73')),
#  ('Delta Air Lines', Decimal('859.64')),
#  ('Nike', Decimal('390.25'))]

# %% [markdown]
# #### 13. Via what channel did the most recent (latest) web_event occur, which account was associated with this web_event? Your query should return only three values - the date, channel, and account name.

# %%
# %%sql
# WITH web_cte AS (
#     SELECT
#         w.*,
#         a.name AS company
#     FROM web_events AS w
#     JOIN accounts AS a
#     ON a.id = w.account_id
# )
# SELECT
#     *
# FROM web_cte
# ORDER BY occurred_at DESC
# LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(7271, 3001, datetime.datetime(2017, 1, 1, 23, 51, 9), 'organic', 'Molina Healthcare')]

# %% [markdown]
# #### 14. Find the total number of times each type of channel from the web_events was used. Your final table should have two columns - the channel and the number of times the channel was used.

# %%
# %%sql
# SELECT
#     channel,
#     COUNT(channel) AS channel_used_count
# FROM web_events
# GROUP BY channel
# ORDER BY channel_used_count DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 6 rows affected.
# [('direct', 5298),
#  ('facebook', 967),
#  ('organic', 952),
#  ('adwords', 906),
#  ('banner', 476),
#  ('twitter', 474)]

# %% [markdown]
# #### 15. Who was the primary contact associated with the earliest web_event?

# %%
# %%sql
# WITH web_cte AS (
#     SELECT
#         w.*,
#         a.name AS company,
#         a.primary_poc
#     FROM web_events AS w
#     JOIN accounts AS a
#     ON a.id = w.account_id
# )
# SELECT
#     company,
#     occurred_at,
#     primary_poc
# FROM(
# SELECT
#     *
# FROM web_cte
# ORDER BY occurred_at DESC
# LIMIT 1
# ) AS earliest_company
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [('Molina Healthcare', datetime.datetime(2017, 1, 1, 23, 51, 9), 'Hilde Klopfer')]

# %% [markdown]
# #### 16. What was the smallest order placed by each account in terms of total USD? Provide only two columns - the account name and the total USD. Order from smallest dollar amounts to largest.

# %%
# %%sql
# SELECT
#     company,
#     SUM(total_amt_usd) AS total_spend
# FROM orders_consolidated
# GROUP BY company
# ORDER BY total_spend
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 350 rows affected.
# [('Nike', Decimal('390.25')),
#  ('Delta Air Lines', Decimal('859.64')),
#  ('Level 3 Communications', Decimal('881.73')),
#  ('Deere', Decimal('1036.57')),
#  ('Bed Bath & Beyond', Decimal('1069.64')),
#  ('Las Vegas Sands', Decimal('1113.29')),
#  ('Assurant', Decimal('1235.81')),
#  ('Ball', Decimal('1982.74')),
#  ('Priceline Group', Decimal('2129.24')),
#  ('Bank of New York Mellon Corp.', Decimal('2155.98')),
#  ('INTL FCStone', Decimal('2372.11')),
#  ('Sherwin-Williams', Decimal('2372.95')),
#  ('Micron Technology', Decimal('2438.51')),
#  ('Lockheed Martin', Decimal('2440.31')),
#  ('Loews', Decimal('2566.22')),
#  ('Lennar', Decimal('2670.97')),
#  ('Consolidated Edison', Decimal('2674.04')),
#  ('Exxon Mobil', Decimal('2734.59')),
#  ('Oneok', Decimal('2844.46')),
#  ('Mohawk Industries', Decimal('3025.65')),
#  ('Applied Materials', Decimal('3093.95')),
#  ('J.C. Penney', Decimal('3253.04')),
#  ('Fannie Mae', Decimal('3780.53')),
#  ('Massachusetts Mutual Life Insurance', Decimal('3927.05')),
#  ('Stryker', Decimal('4521.36')),
#  ('Universal Health Services', Decimal('5269.51')),
#  ('NextEra Energy', Decimal('5321.23')),
#  ('Rite Aid', Decimal('5616.90')),
#  ('Veritiv', Decimal('5735.41')),
#  ('Tenneco', Decimal('5739.63')),
#  ('Genworth Financial', Decimal('6402.38')),
#  ('Liberty Interactive', Decimal('6497.70')),
#  ('Advance Auto Parts', Decimal('6962.07')),
#  ('Sonic Automotive', Decimal('7192.13')),
#  ('Cardinal Health', Decimal('7210.91')),
#  ('ManpowerGroup', Decimal('7313.08')),
#  ('C.H. Robinson Worldwide', Decimal('7460.32')),
#  ('Berkshire Hathaway', Decimal('7474.32')),
#  ('MetLife', Decimal('7615.47')),
#  ('Corning', Decimal('7940.37')),
#  ('TIAA', Decimal('7971.51')),
#  ('Danaher', Decimal('8133.47')),
#  ('Publix Super Markets', Decimal('8364.40')),
#  ('W.W. Grainger', Decimal('8384.61')),
#  ('Dow Chemical', Decimal('8431.81')),
#  ('CBS', Decimal('8648.07')),
#  ('Xerox', Decimal('8759.93')),
#  ('Eli Lilly', Decimal('9339.20')),
#  ('Devon Energy', Decimal('9536.55')),
#  ("Macy's", Decimal('9613.32')),
#  ('Newmont Mining', Decimal('9618.81')),
#  ('CBRE Group', Decimal('9715.71')),
#  ('WellCare Health Plans', Decimal('9743.13')),
#  ("O'Reilly Automotive", Decimal('9914.23')),
#  ('AIG', Decimal('9980.93')),
#  ('General Motors', Decimal('9995.05')),
#  ('Waste Management', Decimal('10067.87')),
#  ('Reliance Steel & Aluminum', Decimal('10187.64')),
#  ('Dollar Tree', Decimal('10212.06')),
#  ('Reinsurance Group of America', Decimal('10264.51')),
#  ('Autoliv', Decimal('10282.96')),
#  ('HCA Holdings', Decimal('10323.23')),
#  ('MasterCard', Decimal('10555.35')),
#  ('Home Depot', Decimal('10667.46')),
#  ('UPS', Decimal('10678.77')),
#  ('PVH', Decimal('10699.35')),
#  ('Marriott International', Decimal('10779.77')),
#  ('World Fuel Services', Decimal('10833.11')),
#  ('Hertz Global Holdings', Decimal('10959.77')),
#  ('AbbVie', Decimal('11243.63')),
#  ('DTE Energy', Decimal('11501.84')),
#  ('Plains GP Holdings', Decimal('11531.70')),
#  ('Air Products & Chemicals', Decimal('11814.55')),
#  ('Northwestern Mutual', Decimal('11862.92')),
#  ('Comcast', Decimal('12868.38')),
#  ('AES', Decimal('13038.64')),
#  ('WestRock', Decimal('13282.42')),
#  ('Owens & Minor', Decimal('13507.23')),
#  ('Tesoro', Decimal('14482.60')),
#  ('SpartanNash', Decimal('14629.16')),
#  ('Starbucks', Decimal('14875.19')),
#  ('Principal Financial', Decimal('15177.80')),
#  ('McKesson', Decimal('15184.46')),
#  ('Microsoft', Decimal('15454.01')),
#  ('ConocoPhillips', Decimal('15578.40')),
#  ('Staples', Decimal('15716.26')),
#  ('Parker-Hannifin', Decimal('15727.19')),
#  ('Voya Financial', Decimal('15782.23')),
#  ('Marsh & McLennan', Decimal('16257.21')),
#  ('Eastman Chemical', Decimal('16303.42')),
#  ('Univar', Decimal('16626.60')),
#  ('Gap', Decimal('16791.91')),
#  ('Liberty Mutual Insurance Group', Decimal('16923.55')),
#  ('MGM Resorts International', Decimal('16976.76')),
#  ('L Brands', Decimal('17439.25')),
#  ('Johnson & Johnson', Decimal('18242.74')),
#  ('VF', Decimal('18251.39')),
#  ('PBF Energy', Decimal('18285.93')),
#  ('AECOM', Decimal('18491.51')),
#  ('Praxair', Decimal('19023.36')),
#  ('Express Scripts Holding', Decimal('19090.45')),
#  ('ConAgra Foods', Decimal('19142.48')),
#  ('Tech Data', Decimal('19218.88')),
#  ('Biogen', Decimal('19386.53')),
#  ('Baker Hughes', Decimal('19409.95')),
#  ('Energy Transfer Equity', Decimal('19539.86')),
#  ('Alcoa', Decimal('19882.16')),
#  ('Masco', Decimal('19963.61')),
#  ('Xcel Energy', Decimal('19975.91')),
#  ('Huntsman', Decimal('20092.35')),
#  ("Peter Kiewit Sons'", Decimal('20232.97')),
#  ('Whole Foods Market', Decimal('20240.66')),
#  ('Hartford Financial Services Group', Decimal('20257.43')),
#  ('Morgan Stanley', Decimal('20277.57')),
#  ('Apple', Decimal('20767.15')),
#  ('Aramark', Decimal('21692.01')),
#  ('UnitedHealth Group', Decimal('21937.08')),
#  ('PPG Industries', Decimal('21960.88')),
#  ('Norfolk Southern', Decimal('22100.01')),
#  ('L-3 Communications', Decimal('22266.77')),
#  ('Navistar International', Decimal('22484.81')),
#  ('Baxter International', Decimal('22681.17')),
#  ('Unum Group', Decimal('22734.13')),
#  ('Procter & Gamble', Decimal('22961.03')),
#  ('Facebook', Decimal('23522.79')),
#  ('CVS Health', Decimal('23667.51')),
#  ('Lear', Decimal('23718.31')),
#  ('Ross Stores', Decimal('24961.87')),
#  ('Union Pacific', Decimal('25107.81')),
#  ('Ingram Micro', Decimal('25198.55')),
#  ('General Electric', Decimal('25335.68')),
#  ('Laboratory Corp. of America', Decimal('25507.06')),
#  ('DuPont', Decimal('25526.30')),
#  ('Kraft Heinz', Decimal('25765.17')),
#  ('Campbell Soup', Decimal('25765.95')),
#  ('Textron', Decimal('26339.70')),
#  ('Penske Automotive Group', Decimal('26485.87')),
#  ('Dean Foods', Decimal('26514.93')),
#  ('U.S. Bancorp', Decimal('26641.71')),
#  ('US Foods Holding', Decimal('27074.63')),
#  ('Exelon', Decimal('27558.30')),
#  ('Health Net', Decimal('27733.33')),
#  ('Computer Sciences', Decimal('28012.07')),
#  ('Yum Brands', Decimal('28296.53')),
#  ('Amazon.com', Decimal('28678.06')),
#  ('Kimberly-Clark', Decimal('29151.21')),
#  ('American Airlines Group', Decimal('30083.18')),
#  ('PepsiCo', Decimal('30095.72')),
#  ('Group 1 Automotive', Decimal('30708.92')),
#  ('Costco', Decimal('30741.01')),
#  ('Oracle', Decimal('31231.56')),
#  ('Nordstrom', Decimal('31273.02')),
#  ('Enterprise Products Partners', Decimal('31971.72')),
#  ('American Electric Power', Decimal('32044.55')),
#  ('General Mills', Decimal('32226.37')),
#  ('Halliburton', Decimal('32645.38')),
#  ('Humana', Decimal('32937.93')),
#  ('Whirlpool', Decimal('32965.13')),
#  ('Tenet Healthcare', Decimal('33028.08')),
#  ('Viacom', Decimal('33673.86')),
#  ('DaVita HealthCare Partners', Decimal('33982.78')),
#  ('News Corp.', Decimal('34675.03')),
#  ('Cummins', Decimal('34839.82')),
#  ('Henry Schein', Decimal('35487.34')),
#  ('CSX', Decimal('35759.70')),
#  ('Becton Dickinson', Decimal('35961.76')),
#  ('R.R. Donnelley & Sons', Decimal('36218.43')),
#  ('Murphy USA', Decimal('36294.27')),
#  ('EMC', Decimal('36982.12')),
#  ('Edison International', Decimal('37010.95')),
#  ('Mondelez International', Decimal('37465.37')),
#  ('Ally Financial', Decimal('37653.96')),
#  ('Johnson Controls', Decimal('37796.28')),
#  ('Estee Lauder', Decimal('38198.82')),
#  ('Thrivent Financial for Lutherans', Decimal('38204.46')),
#  ('GameStop', Decimal('38469.65')),
#  ('Sempra Energy', Decimal('38569.85')),
#  ('Hilton Worldwide Holdings', Decimal('38648.01')),
#  ('AmerisourceBergen', Decimal('38741.81')),
#  ('Icahn Enterprises', Decimal('38851.15')),
#  ('NGL Energy Partners', Decimal('40607.07')),
#  ('Omnicom Group', Decimal('41161.06')),
#  ('BorgWarner', Decimal('41242.06')),
#  ('Twenty-First Century Fox', Decimal('42065.82')),
#  ('Southern', Decimal('42881.21')),
#  ('Coca-Cola', Decimal('43692.29')),
#  ('Alphabet', Decimal('44407.22')),
#  ('Chesapeake Energy', Decimal('44534.95')),
#  ('CenturyLink', Decimal('44535.04')),
#  ('American Express', Decimal('45557.51')),
#  ("Lowe's", Decimal('45873.47')),
#  ('First Data', Decimal('45967.25')),
#  ('PNC Financial Services Group', Decimal('46208.37')),
#  ('Chevron', Decimal('46725.41')),
#  ('USAA', Decimal('46822.63')),
#  ("McDonald's", Decimal('47258.13')),
#  ('Tyson Foods', Decimal('47417.76')),
#  ('Anthem', Decimal('47487.78')),
#  ('Performance Food Group', Decimal('47645.86')),
#  ('Northrop Grumman', Decimal('48578.16')),
#  ('Freeport-McMoRan', Decimal('49162.70')),
#  ('Reynolds American', Decimal('49930.29')),
#  ('Dollar General', Decimal('49975.93')),
#  ('HD Supply Holdings', Decimal('50888.03')),
#  ('Office Depot', Decimal('51477.19')),
#  ('AT&T', Decimal('51647.76')),
#  ('Valero Energy', Decimal('52020.60')),
#  ('Qualcomm', Decimal('54114.02')),
#  ('United Natural Foods', Decimal('54443.06')),
#  ('Texas Instruments', Decimal('54792.72')),
#  ('Kinder Morgan', Decimal('54891.56')),
#  ('Ameriprise Financial', Decimal('55883.55')),
#  ('HP', Decimal('56162.34')),
#  ("Toys 'R' Us", Decimal('56179.21')),
#  ('Community Health Systems', Decimal('56644.60')),
#  ('Discover Financial Services', Decimal('57035.05')),
#  ('Eversource Energy', Decimal('57059.76')),
#  ('Time Warner Cable', Decimal('57130.53')),
#  ('International Paper', Decimal('59086.76')),
#  ('NRG Energy', Decimal('59727.21')),
#  ('Kroger', Decimal('59946.40')),
#  ('Nucor', Decimal('60936.18')),
#  ('Visa', Decimal('61255.50')),
#  ('Genuine Parts', Decimal('61561.44')),
#  ('Gilead Sciences', Decimal('62148.87')),
#  ('Cognizant Technology Solutions', Decimal('62504.05')),
#  ('Precision Castparts', Decimal('63743.89')),
#  ('CarMax', Decimal('64251.56')),
#  ('Merck', Decimal('64536.17')),
#  ('Dominion Resources', Decimal('64604.00')),
#  ('Boeing', Decimal('65091.39')),
#  ('AutoZone', Decimal('65958.07')),
#  ('Molina Healthcare', Decimal('66381.57')),
#  ('Avnet', Decimal('66812.24')),
#  ('Illinois Tool Works', Decimal('67439.95')),
#  ('Cameron International', Decimal('67459.65')),
#  ('Global Partners', Decimal('67909.96')),
#  ('Time Warner', Decimal('69479.06')),
#  ('Capital One Financial', Decimal('72595.01')),
#  ('Stanley Black & Decker', Decimal('72788.52')),
#  ('Progressive', Decimal('72875.84')),
#  ('Public Service Enterprise Group', Decimal('73833.01')),
#  ('Crown Holdings', Decimal('75110.81')),
#  ('Broadcom', Decimal('75130.50')),
#  ('Jacobs Engineering Group', Decimal('75600.49')),
#  ('Nationwide', Decimal('76630.92')),
#  ('Lincoln National', Decimal('77628.11')),
#  ('Jabil Circuit', Decimal('79246.93')),
#  ('HollyFrontier', Decimal('79488.37')),
#  ('Anadarko Petroleum', Decimal('80328.56')),
#  ('PG&E Corp.', Decimal('81697.27')),
#  ('Caterpillar', Decimal('81700.33')),
#  ('Amgen', Decimal('82013.05')),
#  ('Kellogg', Decimal('83419.38')),
#  ('PayPal Holdings', Decimal('84768.94')),
#  ('Honeywell International', Decimal('86362.70')),
#  ('Hormel Foods', Decimal('88946.14')),
#  ("Kohl's", Decimal('90105.16')),
#  ('Bank of America Corp.', Decimal('93217.80')),
#  ('eBay', Decimal('94244.44')),
#  ('J.P. Morgan Chase', Decimal('94684.25')),
#  ('Raytheon', Decimal('94725.92')),
#  ('Farmers Insurance Exchange', Decimal('96376.94')),
#  ('Celgene', Decimal('96593.53')),
#  ('Allstate', Decimal('96779.18')),
#  ('Abbott Laboratories', Decimal('96819.92')),
#  ('D.R. Horton', Decimal('98474.44')),
#  ('SunTrust Banks', Decimal('99125.76')),
#  ('CDW', Decimal('101553.15')),
#  ('Occidental Petroleum', Decimal('105115.44')),
#  ('Lithia Motors', Decimal('107142.63')),
#  ('Western Refining', Decimal('108579.84')),
#  ('Fidelity National Financial', Decimal('110027.29')),
#  ('State Farm Insurance Cos.', Decimal('111810.55')),
#  ('PPL', Decimal('112176.03')),
#  ('Verizon', Decimal('115376.17')),
#  ('Altria Group', Decimal('116165.15')),
#  ('Aflac', Decimal('117862.77')),
#  ('Duke Energy', Decimal('118867.17')),
#  ('United Continental Holdings', Decimal('118879.76')),
#  ('State Street Corp.', Decimal('119173.59')),
#  ('FedEx', Decimal('119965.08')),
#  ('Target', Decimal('120523.91')),
#  ('CST Brands', Decimal('122957.11')),
#  ('Entergy', Decimal('123503.18')),
#  ('BB&T Corp.', Decimal('123847.32')),
#  ('Walmart', Decimal('124014.87')),
#  ('Southwest Airlines', Decimal('125968.04')),
#  ('New York Life Insurance', Decimal('126898.91')),
#  ('Cigna', Decimal('127671.94')),
#  ('3M', Decimal('127945.10')),
#  ('Walgreens Boots Alliance', Decimal('130153.59')),
#  ('Colgate-Palmolive', Decimal('130893.51')),
#  ('Cisco Systems', Decimal('130917.00')),
#  ('Monsanto', Decimal('130964.11')),
#  ('Phillips 66', Decimal('131173.41')),
#  ('National Oilwell Varco', Decimal('131318.64')),
#  ('FirstEnergy', Decimal('132868.82')),
#  ('Synnex', Decimal('134039.25')),
#  ('Ecolab', Decimal('135517.95')),
#  ('Franklin Resources', Decimal('135730.44')),
#  ('AutoNation', Decimal('135822.85')),
#  ('Charter Communications', Decimal('135924.15')),
#  ('Marathon Petroleum', Decimal('137227.88')),
#  ('Philip Morris International', Decimal('137600.67')),
#  ("Land O'Lakes", Decimal('138323.59')),
#  ('Sears Holdings', Decimal('139015.09')),
#  ('TJX', Decimal('140046.68')),
#  ('Emerson Electric', Decimal('143471.26')),
#  ('Pfizer', Decimal('144865.83')),
#  ('BlackRock', Decimal('147599.56')),
#  ('American Family Insurance Group', Decimal('153015.87')),
#  ('Thermo Fisher Scientific', Decimal('153705.10')),
#  ('Ford Motor', Decimal('154811.43')),
#  ('Travelers Cos.', Decimal('156582.24')),
#  ('Guardian Life Ins. Co. of America', Decimal('157523.24')),
#  ('Prudential Financial', Decimal('157782.52')),
#  ('Citigroup', Decimal('160051.04')),
#  ('Paccar', Decimal('161294.62')),
#  ('ADP', Decimal('163579.18')),
#  ('Best Buy', Decimal('163887.39')),
#  ('CHS', Decimal('167271.80')),
#  ('Intel', Decimal('167717.40')),
#  ('Jarden', Decimal('179761.43')),
#  ('Goodyear Tire & Rubber', Decimal('185463.76')),
#  ('Bristol-Myers Squibb', Decimal('188457.46')),
#  ('Wells Fargo', Decimal('200174.66')),
#  ('Disney', Decimal('205886.97')),
#  ('KKR', Decimal('217473.85')),
#  ('Core-Mark Holding', Decimal('231856.98')),
#  ('Freddie Mac', Decimal('234225.65')),
#  ('United Technologies', Decimal('235051.07')),
#  ('Aetna', Decimal('237781.30')),
#  ('Centene', Decimal('238962.47')),
#  ('Avis Budget Group', Decimal('241711.25')),
#  ('United States Steel', Decimal('244695.99')),
#  ('Fluor', Decimal('251299.77')),
#  ('DISH Network', Decimal('253635.75')),
#  ('Pacific Life', Decimal('255319.18')),
#  ('Western Digital', Decimal('269155.34')),
#  ('Archer Daniels Midland', Decimal('272672.84')),
#  ('Supervalu', Decimal('275288.30')),
#  ('Sysco', Decimal('278575.64')),
#  ('Arrow Electronics', Decimal('281018.36')),
#  ('Leucadia National', Decimal('291047.25')),
#  ('Republic Services', Decimal('293861.14')),
#  ('General Dynamics', Decimal('300694.79')),
#  ('IBM', Decimal('326819.48')),
#  ('Mosaic', Decimal('345618.59')),
#  ('EOG Resources', Decimal('382873.30'))]

# %% [markdown]
# #### 17. Find the number of sales reps in each region. Your final table should have two columns - the region and the number of sales reps. Order from fewest reps to most reps.

# %%
# %%sql
# SELECT
#     region_id,
#     COUNT(name) AS sales_rep_num
# FROM sales_reps
# GROUP BY region_id
# ORDER BY region_id
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 4 rows affected.
# [(1, 21), (2, 9), (3, 10), (4, 10)]

# %% [markdown]
# #### 18. For each account, determine the average amount of each type of paper they purchased across their orders. Your result should have four columns - one for the account name and one for the average quantity purchased for each of the paper types for each account.

# %%
# %%sql
# SELECT
#     company,
#     ROUND(AVG(standard_qty),0) AS avg_standard_qty,
#     ROUND(AVG(gloss_qty),0) AS avg_gloss_qty,
#     ROUND(AVG(poster_qty),0) AS avg_poster_qty
# FROM orders_consolidated
# GROUP BY company
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 350 rows affected.
# [('Comcast', Decimal('294'), Decimal('18'), Decimal('29')),
#  ('Microsoft', Decimal('88'), Decimal('32'), Decimal('62')),
#  ('Monsanto', Decimal('354'), Decimal('43'), Decimal('26')),
#  ('Dean Foods', Decimal('207'), Decimal('214'), Decimal('142')),
#  ('KKR', Decimal('194'), Decimal('230'), Decimal('155')),
#  ('Performance Food Group', Decimal('329'), Decimal('34'), Decimal('46')),
#  ('Paccar', Decimal('113'), Decimal('247'), Decimal('134')),
#  ('USAA', Decimal('195'), Decimal('312'), Decimal('233')),
#  ('CST Brands', Decimal('345'), Decimal('33'), Decimal('66')),
#  ('Ally Financial', Decimal('304'), Decimal('300'), Decimal('117')),
#  ('Amgen', Decimal('234'), Decimal('252'), Decimal('129')),
#  ('Broadcom', Decimal('188'), Decimal('269'), Decimal('151')),
#  ('AIG', Decimal('301'), Decimal('349'), Decimal('108')),
#  ('W.W. Grainger', Decimal('167'), Decimal('271'), Decimal('164')),
#  ('Reynolds American', Decimal('348'), Decimal('28'), Decimal('27')),
#  ('Sears Holdings', Decimal('378'), Decimal('201'), Decimal('152')),
#  ('HCA Holdings', Decimal('301'), Decimal('348'), Decimal('130')),
#  ('Aetna', Decimal('229'), Decimal('212'), Decimal('238')),
#  ('Deere', Decimal('102'), Decimal('39'), Decimal('29')),
#  ('Procter & Gamble', Decimal('240'), Decimal('184'), Decimal('87')),
#  ('Gilead Sciences', Decimal('343'), Decimal('43'), Decimal('33')),
#  ('Dominion Resources', Decimal('204'), Decimal('190'), Decimal('97')),
#  ('Viacom', Decimal('405'), Decimal('32'), Decimal('18')),
#  ('Altria Group', Decimal('381'), Decimal('22'), Decimal('26')),
#  ('HP', Decimal('350'), Decimal('71'), Decimal('103')),
#  ('General Motors', Decimal('402'), Decimal('242'), Decimal('146')),
#  ('American Family Insurance Group', Decimal('376'), Decimal('31'), Decimal('71')),
#  ('Kinder Morgan', Decimal('364'), Decimal('37'), Decimal('24')),
#  ('PBF Energy', Decimal('123'), Decimal('20'), Decimal('47')),
#  ('Baker Hughes', Decimal('224'), Decimal('195'), Decimal('81')),
#  ('Bank of America Corp.', Decimal('258'), Decimal('247'), Decimal('92')),
#  ('CenturyLink', Decimal('298'), Decimal('391'), Decimal('370')),
#  ('Universal Health Services', Decimal('518'), Decimal('7'), Decimal('0')),
#  ('Marriott International', Decimal('395'), Decimal('348'), Decimal('101')),
#  ('CBRE Group', Decimal('289'), Decimal('284'), Decimal('159')),
#  ('AutoNation', Decimal('336'), Decimal('45'), Decimal('50')),
#  ('FedEx', Decimal('330'), Decimal('32'), Decimal('26')),
#  ('Best Buy', Decimal('129'), Decimal('234'), Decimal('53')),
#  ('Home Depot', Decimal('245'), Decimal('209'), Decimal('95')),
#  ('Leucadia National', Decimal('189'), Decimal('245'), Decimal('163')),
#  ('TIAA', Decimal('280'), Decimal('39'), Decimal('38')),
#  ('Tenneco', Decimal('75'), Decimal('76'), Decimal('61')),
#  ('Avis Budget Group', Decimal('209'), Decimal('228'), Decimal('150')),
#  ('MasterCard', Decimal('240'), Decimal('234'), Decimal('70')),
#  ('Western Refining', Decimal('345'), Decimal('99'), Decimal('31')),
#  ('American Airlines Group', Decimal('370'), Decimal('23'), Decimal('88')),
#  ('Plains GP Holdings', Decimal('402'), Decimal('15'), Decimal('23')),
#  ('Celgene', Decimal('215'), Decimal('221'), Decimal('140')),
#  ('Ross Stores', Decimal('344'), Decimal('37'), Decimal('34')),
#  ('Anthem', Decimal('363'), Decimal('35'), Decimal('23')),
#  ('Applied Materials', Decimal('74'), Decimal('116'), Decimal('39')),
#  ('Stanley Black & Decker', Decimal('345'), Decimal('44'), Decimal('19')),
#  ('Ameriprise Financial', Decimal('383'), Decimal('25'), Decimal('28')),
#  ('Northrop Grumman', Decimal('181'), Decimal('232'), Decimal('173')),
#  ('Progressive', Decimal('361'), Decimal('34'), Decimal('37')),
#  ('Allstate', Decimal('269'), Decimal('215'), Decimal('113')),
#  ('Freeport-McMoRan', Decimal('173'), Decimal('282'), Decimal('138')),
#  ('Valero Energy', Decimal('151'), Decimal('268'), Decimal('153')),
#  ('EOG Resources', Decimal('282'), Decimal('523'), Decimal('105')),
#  ('Unum Group', Decimal('340'), Decimal('78'), Decimal('30')),
#  ('Fannie Mae', Decimal('271'), Decimal('25'), Decimal('44')),
#  ('MGM Resorts International', Decimal('164'), Decimal('267'), Decimal('176')),
#  ('Freddie Mac', Decimal('193'), Decimal('235'), Decimal('130')),
#  ('Halliburton', Decimal('289'), Decimal('388'), Decimal('135')),
#  ('Costco', Decimal('143'), Decimal('186'), Decimal('372')),
#  ('DISH Network', Decimal('353'), Decimal('37'), Decimal('269')),
#  ('Icahn Enterprises', Decimal('248'), Decimal('144'), Decimal('113')),
#  ('Priceline Group', Decimal('349'), Decimal('29'), Decimal('21')),
#  ('Office Depot', Decimal('431'), Decimal('31'), Decimal('40')),
#  ('PPG Industries', Decimal('255'), Decimal('194'), Decimal('116')),
#  ('Chevron', Decimal('150'), Decimal('220'), Decimal('147')),
#  ('Aramark', Decimal('120'), Decimal('127'), Decimal('143')),
#  ('Republic Services', Decimal('197'), Decimal('220'), Decimal('400')),
#  ('BorgWarner', Decimal('185'), Decimal('248'), Decimal('119')),
#  ('D.R. Horton', Decimal('185'), Decimal('244'), Decimal('146')),
#  ('EMC', Decimal('265'), Decimal('267'), Decimal('97')),
#  ('Tyson Foods', Decimal('112'), Decimal('43'), Decimal('30')),
#  ('Marathon Petroleum', Decimal('307'), Decimal('62'), Decimal('27')),
#  ('Dollar General', Decimal('406'), Decimal('30'), Decimal('30')),
#  ('Oracle', Decimal('255'), Decimal('281'), Decimal('133')),
#  ('Baxter International', Decimal('403'), Decimal('21'), Decimal('44')),
#  ('Southern', Decimal('348'), Decimal('28'), Decimal('25')),
#  ('Autoliv', Decimal('223'), Decimal('182'), Decimal('117')),
#  ('Devon Energy', Decimal('311'), Decimal('304'), Decimal('116')),
#  ('Corning', Decimal('124'), Decimal('40'), Decimal('83')),
#  ('Xcel Energy', Decimal('417'), Decimal('157'), Decimal('9')),
#  ('Fidelity National Financial', Decimal('404'), Decimal('16'), Decimal('1431')),
#  ('Anadarko Petroleum', Decimal('183'), Decimal('183'), Decimal('114')),
#  ('Global Partners', Decimal('351'), Decimal('22'), Decimal('53')),
#  ('Enterprise Products Partners', Decimal('192'), Decimal('295'), Decimal('172')),
#  ('Mohawk Industries', Decimal('485'), Decimal('70'), Decimal('10')),
#  ('Navistar International', Decimal('310'), Decimal('21'), Decimal('67')),
#  ('R.R. Donnelley & Sons', Decimal('369'), Decimal('21'), Decimal('72')),
#  ('CVS Health', Decimal('154'), Decimal('259'), Decimal('152')),
#  ('Kimberly-Clark', Decimal('331'), Decimal('17'), Decimal('38')),
#  ('Fluor', Decimal('190'), Decimal('231'), Decimal('146')),
#  ('MetLife', Decimal('499'), Decimal('6'), Decimal('0')),
#  ('Time Warner', Decimal('254'), Decimal('247'), Decimal('91')),
#  ('Campbell Soup', Decimal('172'), Decimal('265'), Decimal('179')),
#  ('Mosaic', Decimal('214'), Decimal('243'), Decimal('289')),
#  ('Core-Mark Holding', Decimal('743'), Decimal('35'), Decimal('20')),
#  ('Liberty Mutual Insurance Group', Decimal('294'), Decimal('308'), Decimal('57')),
#  ('Morgan Stanley', Decimal('300'), Decimal('77'), Decimal('22')),
#  ('Laboratory Corp. of America', Decimal('375'), Decimal('27'), Decimal('7')),
#  ('Texas Instruments', Decimal('339'), Decimal('22'), Decimal('65')),
#  ('American Electric Power', Decimal('296'), Decimal('23'), Decimal('29')),
#  ('INTL FCStone', Decimal('330'), Decimal('73'), Decimal('22')),
#  ('Farmers Insurance Exchange', Decimal('326'), Decimal('40'), Decimal('21')),
#  ('Norfolk Southern', Decimal('349'), Decimal('82'), Decimal('12')),
#  ('AES', Decimal('255'), Decimal('304'), Decimal('98')),
#  ('Eastman Chemical', Decimal('228'), Decimal('158'), Decimal('115')),
#  ('Exxon Mobil', Decimal('527'), Decimal('14'), Decimal('0')),
#  ('First Data', Decimal('205'), Decimal('244'), Decimal('164')),
#  ('Time Warner Cable', Decimal('268'), Decimal('331'), Decimal('116')),
#  ('Rite Aid', Decimal('326'), Decimal('23'), Decimal('9')),
#  ('UPS', Decimal('401'), Decimal('323'), Decimal('114')),
#  ('News Corp.', Decimal('189'), Decimal('218'), Decimal('109')),
#  ('AutoZone', Decimal('203'), Decimal('240'), Decimal('162')),
#  ('Molina Healthcare', Decimal('361'), Decimal('220'), Decimal('30')),
#  ('Merck', Decimal('358'), Decimal('37'), Decimal('41')),
#  ('Assurant', Decimal('117'), Decimal('22'), Decimal('60')),
#  ('Biogen', Decimal('208'), Decimal('230'), Decimal('137')),
#  ('Textron', Decimal('389'), Decimal('33'), Decimal('25')),
#  ('Waste Management', Decimal('570'), Decimal('282'), Decimal('10')),
#  ('United States Steel', Decimal('213'), Decimal('225'), Decimal('125')),
#  ('CDW', Decimal('184'), Decimal('227'), Decimal('141')),
#  ('Bed Bath & Beyond', Decimal('79'), Decimal('75'), Decimal('14')),
#  ('Abbott Laboratories', Decimal('201'), Decimal('197'), Decimal('92')),
#  ('L-3 Communications', Decimal('333'), Decimal('28'), Decimal('19')),
#  ("Toys 'R' Us", Decimal('217'), Decimal('358'), Decimal('113')),
#  ('Kellogg', Decimal('357'), Decimal('30'), Decimal('46')),
#  ('CarMax', Decimal('222'), Decimal('194'), Decimal('150')),
#  ('Publix Super Markets', Decimal('185'), Decimal('269'), Decimal('154')),
#  ("Kohl's", Decimal('1878'), Decimal('286'), Decimal('167')),
#  ('Philip Morris International', Decimal('299'), Decimal('43'), Decimal('38')),
#  ('Goodyear Tire & Rubber', Decimal('171'), Decimal('329'), Decimal('148')),
#  ('TJX', Decimal('413'), Decimal('36'), Decimal('58')),
#  ('CBS', Decimal('297'), Decimal('32'), Decimal('853')),
#  ('Becton Dickinson', Decimal('193'), Decimal('213'), Decimal('128')),
#  ('VF', Decimal('316'), Decimal('284'), Decimal('106')),
#  ('Gap', Decimal('131'), Decimal('212'), Decimal('138')),
#  ('Union Pacific', Decimal('368'), Decimal('35'), Decimal('51')),
#  ('Air Products & Chemicals', Decimal('207'), Decimal('172'), Decimal('79')),
#  ('Supervalu', Decimal('198'), Decimal('249'), Decimal('147')),
#  ('ConocoPhillips', Decimal('431'), Decimal('30'), Decimal('27')),
#  ('ConAgra Foods', Decimal('176'), Decimal('241'), Decimal('141')),
#  ('United Natural Foods', Decimal('301'), Decimal('56'), Decimal('32')),
#  ('NGL Energy Partners', Decimal('204'), Decimal('218'), Decimal('90')),
#  ('Amazon.com', Decimal('195'), Decimal('196'), Decimal('141')),
#  ('PVH', Decimal('313'), Decimal('27'), Decimal('46')),
#  ('ADP', Decimal('355'), Decimal('61'), Decimal('62')),
#  ('J.P. Morgan Chase', Decimal('301'), Decimal('61'), Decimal('30')),
#  ('Lithia Motors', Decimal('312'), Decimal('141'), Decimal('45')),
#  ('Archer Daniels Midland', Decimal('198'), Decimal('245'), Decimal('162')),
#  ('Parker-Hannifin', Decimal('104'), Decimal('77'), Decimal('41')),
#  ('Energy Transfer Equity', Decimal('222'), Decimal('159'), Decimal('118')),
#  ('Whirlpool', Decimal('273'), Decimal('46'), Decimal('61')),
#  ('PNC Financial Services Group', Decimal('93'), Decimal('57'), Decimal('137')),
#  ('Reliance Steel & Aluminum', Decimal('364'), Decimal('330'), Decimal('100')),
#  ('Capital One Financial', Decimal('244'), Decimal('270'), Decimal('72')),
#  ('ManpowerGroup', Decimal('442'), Decimal('7'), Decimal('22')),
#  ('Chesapeake Energy', Decimal('272'), Decimal('291'), Decimal('113')),
#  ('Travelers Cos.', Decimal('526'), Decimal('268'), Decimal('94')),
#  ('Apple', Decimal('315'), Decimal('48'), Decimal('18')),
#  ('United Continental Holdings', Decimal('283'), Decimal('40'), Decimal('22')),
#  ('Johnson & Johnson', Decimal('239'), Decimal('263'), Decimal('173')),
#  ('BB&T Corp.', Decimal('364'), Decimal('219'), Decimal('184')),
#  ('Delta Air Lines', Decimal('149'), Decimal('9'), Decimal('6')),
#  ('GameStop', Decimal('306'), Decimal('174'), Decimal('15')),
#  ('State Farm Insurance Cos.', Decimal('1892'), Decimal('235'), Decimal('150')),
#  ('Boeing', Decimal('360'), Decimal('222'), Decimal('108')),
#  ('Hartford Financial Services Group', Decimal('343'), Decimal('25'), Decimal('16')),
#  ('American Express', Decimal('308'), Decimal('43'), Decimal('15')),
#  ('Humana', Decimal('384'), Decimal('44'), Decimal('13')),
#  ('Liberty Interactive', Decimal('240'), Decimal('48'), Decimal('9')),
#  ('Consolidated Edison', Decimal('176'), Decimal('0'), Decimal('57')),
#  ('National Oilwell Varco', Decimal('169'), Decimal('237'), Decimal('276')),
#  ('NRG Energy', Decimal('192'), Decimal('236'), Decimal('124')),
#  ('AECOM', Decimal('364'), Decimal('14'), Decimal('17')),
#  ('Sempra Energy', Decimal('208'), Decimal('345'), Decimal('148')),
#  ('Verizon', Decimal('278'), Decimal('220'), Decimal('152')),
#  ('Nationwide', Decimal('259'), Decimal('260'), Decimal('156')),
#  ('AmerisourceBergen', Decimal('178'), Decimal('262'), Decimal('842')),
#  ('Ford Motor', Decimal('221'), Decimal('236'), Decimal('161')),
#  ('Lincoln National', Decimal('191'), Decimal('228'), Decimal('176')),
#  ('CHS', Decimal('200'), Decimal('265'), Decimal('529')),
#  ('International Paper', Decimal('270'), Decimal('274'), Decimal('101')),
#  ('WellCare Health Plans', Decimal('316'), Decimal('313'), Decimal('118')),
#  ('Genuine Parts', Decimal('329'), Decimal('351'), Decimal('106')),
#  ('PPL', Decimal('221'), Decimal('231'), Decimal('127')),
#  ('Precision Castparts', Decimal('197'), Decimal('249'), Decimal('521')),
#  ('Tesoro', Decimal('177'), Decimal('195'), Decimal('157')),
#  ('Pfizer', Decimal('264'), Decimal('352'), Decimal('107')),
#  ('Facebook', Decimal('503'), Decimal('321'), Decimal('119')),
#  ('US Foods Holding', Decimal('188'), Decimal('321'), Decimal('65')),
#  ('WestRock', Decimal('98'), Decimal('44'), Decimal('48')),
#  ('Ecolab', Decimal('353'), Decimal('75'), Decimal('29')),
#  ('Tech Data', Decimal('383'), Decimal('21'), Decimal('8')),
#  ('General Electric', Decimal('102'), Decimal('58'), Decimal('48')),
#  ('McKesson', Decimal('167'), Decimal('154'), Decimal('129')),
#  ('Nordstrom', Decimal('226'), Decimal('222'), Decimal('138')),
#  ('Avnet', Decimal('249'), Decimal('310'), Decimal('109')),
#  ('Yum Brands', Decimal('281'), Decimal('39'), Decimal('24')),
#  ('Phillips 66', Decimal('212'), Decimal('212'), Decimal('136')),
#  ('Western Digital', Decimal('193'), Decimal('240'), Decimal('170')),
#  ("O'Reilly Automotive", Decimal('197'), Decimal('190'), Decimal('111')),
#  ('Eli Lilly', Decimal('300'), Decimal('316'), Decimal('100')),
#  ('Intel', Decimal('189'), Decimal('243'), Decimal('152')),
#  ('Veritiv', Decimal('89'), Decimal('41'), Decimal('49')),
#  ('Loews', Decimal('498'), Decimal('0'), Decimal('10')),
#  ('Computer Sciences', Decimal('137'), Decimal('42'), Decimal('21')),
#  ('PepsiCo', Decimal('297'), Decimal('300'), Decimal('70')),
#  ('U.S. Bancorp', Decimal('439'), Decimal('248'), Decimal('49')),
#  ('Whole Foods Market', Decimal('392'), Decimal('24'), Decimal('14')),
#  ('Henry Schein', Decimal('194'), Decimal('291'), Decimal('159')),
#  ('Northwestern Mutual', Decimal('278'), Decimal('23'), Decimal('52')),
#  ('Arrow Electronics', Decimal('191'), Decimal('263'), Decimal('156')),
#  ('Discover Financial Services', Decimal('208'), Decimal('209'), Decimal('118')),
#  ('AT&T', Decimal('107'), Decimal('42'), Decimal('43')),
#  ('Estee Lauder', Decimal('182'), Decimal('233'), Decimal('144')),
#  ('Health Net', Decimal('376'), Decimal('42'), Decimal('15')),
#  ('L Brands', Decimal('299'), Decimal('313'), Decimal('65')),
#  ('Wells Fargo', Decimal('184'), Decimal('257'), Decimal('153')),
#  ("Land O'Lakes", Decimal('349'), Decimal('25'), Decimal('56')),
#  ("Lowe's", Decimal('375'), Decimal('26'), Decimal('43')),
#  ('Dollar Tree', Decimal('212'), Decimal('181'), Decimal('17')),
#  ('Raytheon', Decimal('235'), Decimal('247'), Decimal('158')),
#  ('Bristol-Myers Squibb', Decimal('271'), Decimal('271'), Decimal('124')),
#  ('World Fuel Services', Decimal('208'), Decimal('207'), Decimal('15')),
#  ('SunTrust Banks', Decimal('202'), Decimal('241'), Decimal('185')),
#  ('PG&E Corp.', Decimal('264'), Decimal('420'), Decimal('79')),
#  ('Level 3 Communications', Decimal('123'), Decimal('0'), Decimal('33')),
#  ('CSX', Decimal('274'), Decimal('298'), Decimal('186')),
#  ('Honeywell International', Decimal('335'), Decimal('50'), Decimal('81')),
#  ('Cameron International', Decimal('403'), Decimal('29'), Decimal('22')),
#  ('Lennar', Decimal('517'), Decimal('10'), Decimal('2')),
#  ('Cummins', Decimal('207'), Decimal('186'), Decimal('131')),
#  ('Masco', Decimal('129'), Decimal('33'), Decimal('43')),
#  ('Tenet Healthcare', Decimal('312'), Decimal('244'), Decimal('91')),
#  ('Xerox', Decimal('267'), Decimal('19'), Decimal('88')),
#  ('AbbVie', Decimal('238'), Decimal('278'), Decimal('59')),
#  ('Principal Financial', Decimal('289'), Decimal('52'), Decimal('41')),
#  ('Target', Decimal('247'), Decimal('208'), Decimal('151')),
#  ('eBay', Decimal('362'), Decimal('32'), Decimal('80')),
#  ('State Street Corp.', Decimal('209'), Decimal('235'), Decimal('161')),
#  ('Starbucks', Decimal('164'), Decimal('314'), Decimal('526')),
#  ('Visa', Decimal('237'), Decimal('251'), Decimal('126')),
#  ('Community Health Systems', Decimal('409'), Decimal('294'), Decimal('111')),
#  ("McDonald's", Decimal('190'), Decimal('250'), Decimal('100')),
#  ('Colgate-Palmolive', Decimal('330'), Decimal('45'), Decimal('25')),
#  ('Crown Holdings', Decimal('285'), Decimal('394'), Decimal('123')),
#  ('DTE Energy', Decimal('395'), Decimal('20'), Decimal('23')),
#  ('Danaher', Decimal('178'), Decimal('261'), Decimal('151')),
#  ('Cigna', Decimal('535'), Decimal('46'), Decimal('22')),
#  ('Advance Auto Parts', Decimal('274'), Decimal('20'), Decimal('28')),
#  ('Owens & Minor', Decimal('92'), Decimal('57'), Decimal('57')),
#  ('Hertz Global Holdings', Decimal('314'), Decimal('50'), Decimal('31')),
#  ('Penske Automotive Group', Decimal('199'), Decimal('257'), Decimal('184')),
#  ('Mondelez International', Decimal('335'), Decimal('27'), Decimal('282')),
#  ('IBM', Decimal('263'), Decimal('251'), Decimal('278')),
#  ('Edison International', Decimal('757'), Decimal('25'), Decimal('423')),
#  ('Sysco', Decimal('191'), Decimal('231'), Decimal('174')),
#  ('Newmont Mining', Decimal('90'), Decimal('57'), Decimal('129')),
#  ('Genworth Financial', Decimal('332'), Decimal('33'), Decimal('29')),
#  ('Hormel Foods', Decimal('188'), Decimal('197'), Decimal('141')),
#  ('J.C. Penney', Decimal('95'), Decimal('22'), Decimal('22')),
#  ('Staples', Decimal('348'), Decimal('25'), Decimal('40')),
#  ('Duke Energy', Decimal('222'), Decimal('225'), Decimal('128')),
#  ('Dow Chemical', Decimal('181'), Decimal('278'), Decimal('152')),
#  ('Synnex', Decimal('304'), Decimal('272'), Decimal('95')),
#  ('Entergy', Decimal('329'), Decimal('28'), Decimal('39')),
#  ('Exelon', Decimal('104'), Decimal('45'), Decimal('42')),
#  ('Las Vegas Sands', Decimal('116'), Decimal('41'), Decimal('28')),
#  ('Group 1 Automotive', Decimal('397'), Decimal('39'), Decimal('12')),
#  ('Illinois Tool Works', Decimal('358'), Decimal('243'), Decimal('311')),
#  ('Aflac', Decimal('450'), Decimal('31'), Decimal('87')),
#  ('HollyFrontier', Decimal('205'), Decimal('232'), Decimal('175')),
#  ('Omnicom Group', Decimal('324'), Decimal('28'), Decimal('28')),
#  ('Jarden', Decimal('248'), Decimal('250'), Decimal('132')),
#  ('United Technologies', Decimal('220'), Decimal('242'), Decimal('140')),
#  ('Jacobs Engineering Group', Decimal('181'), Decimal('230'), Decimal('225')),
#  ('Southwest Airlines', Decimal('387'), Decimal('43'), Decimal('26')),
#  ('Massachusetts Mutual Life Insurance', Decimal('113'), Decimal('7'), Decimal('5')),
#  ('Lear', Decimal('114'), Decimal('41'), Decimal('38')),
#  ('Citigroup', Decimal('378'), Decimal('63'), Decimal('49')),
#  ('Alphabet', Decimal('317'), Decimal('250'), Decimal('122')),
#  ('Walmart', Decimal('282'), Decimal('280'), Decimal('114')),
#  ('Pacific Life', Decimal('336'), Decimal('30'), Decimal('2184')),
#  ('Kraft Heinz', Decimal('304'), Decimal('22'), Decimal('37')),
#  ('Public Service Enterprise Group', Decimal('181'), Decimal('313'), Decimal('358')),
#  ('Univar', Decimal('277'), Decimal('18'), Decimal('40')),
#  ('Charter Communications', Decimal('326'), Decimal('28'), Decimal('63')),
#  ('Lockheed Martin', Decimal('457'), Decimal('4'), Decimal('16')),
#  ('Occidental Petroleum', Decimal('273'), Decimal('295'), Decimal('99')),
#  ('DaVita HealthCare Partners', Decimal('109'), Decimal('40'), Decimal('128')),
#  ('Micron Technology', Decimal('145'), Decimal('45'), Decimal('20')),
#  ('3M', Decimal('313'), Decimal('280'), Decimal('112')),
#  ('HD Supply Holdings', Decimal('308'), Decimal('272'), Decimal('83')),
#  ('Centene', Decimal('206'), Decimal('229'), Decimal('145')),
#  ('Huntsman', Decimal('257'), Decimal('104'), Decimal('159')),
#  ('New York Life Insurance', Decimal('326'), Decimal('45'), Decimal('38')),
#  ('Thrivent Financial for Lutherans', Decimal('274'), Decimal('24'), Decimal('33')),
#  ('Praxair', Decimal('564'), Decimal('27'), Decimal('19')),
#  ('General Dynamics', Decimal('206'), Decimal('286'), Decimal('171')),
#  ('Eversource Energy', Decimal('286'), Decimal('446'), Decimal('115')),
#  ('Johnson Controls', Decimal('296'), Decimal('29'), Decimal('24')),
#  ('BlackRock', Decimal('395'), Decimal('48'), Decimal('26')),
#  ('PayPal Holdings', Decimal('321'), Decimal('26'), Decimal('40')),
#  ('Stryker', Decimal('268'), Decimal('84'), Decimal('37')),
#  ('C.H. Robinson Worldwide', Decimal('168'), Decimal('256'), Decimal('120')),
#  ('Emerson Electric', Decimal('191'), Decimal('235'), Decimal('130')),
#  ('Alcoa', Decimal('311'), Decimal('10'), Decimal('22')),
#  ('Twenty-First Century Fox', Decimal('95'), Decimal('54'), Decimal('83')),
#  ('SpartanNash', Decimal('78'), Decimal('51'), Decimal('44')),
#  ('Kroger', Decimal('284'), Decimal('42'), Decimal('175')),
#  ('Sherwin-Williams', Decimal('92'), Decimal('53'), Decimal('41')),
#  ('DuPont', Decimal('310'), Decimal('37'), Decimal('18')),
#  ('Cardinal Health', Decimal('250'), Decimal('39'), Decimal('32')),
#  ('Coca-Cola', Decimal('290'), Decimal('25'), Decimal('23')),
#  ('Prudential Financial', Decimal('193'), Decimal('232'), Decimal('153')),
#  ('Hilton Worldwide Holdings', Decimal('133'), Decimal('52'), Decimal('46')),
#  ('Nucor', Decimal('348'), Decimal('17'), Decimal('29')),
#  ('FirstEnergy', Decimal('322'), Decimal('38'), Decimal('35')),
#  ('Oneok', Decimal('209'), Decimal('26'), Decimal('24')),
#  ("Macy's", Decimal('372'), Decimal('50'), Decimal('21')),
#  ('Sonic Automotive', Decimal('283'), Decimal('28'), Decimal('22')),
#  ('Nike', Decimal('0'), Decimal('25'), Decimal('25')),
#  ('Marsh & McLennan', Decimal('174'), Decimal('253'), Decimal('160')),
#  ('Cisco Systems', Decimal('329'), Decimal('23'), Decimal('41')),
#  ('Voya Financial', Decimal('378'), Decimal('26'), Decimal('21')),
#  ('Disney', Decimal('307'), Decimal('246'), Decimal('29')),
#  ('Bank of New York Mellon Corp.', Decimal('370'), Decimal('24'), Decimal('16')),
#  ('Express Scripts Holding', Decimal('166'), Decimal('409'), Decimal('108')),
#  ('Ingram Micro', Decimal('162'), Decimal('172'), Decimal('87')),
#  ('Ball', Decimal('304'), Decimal('34'), Decimal('26')),
#  ('Cognizant Technology Solutions', Decimal('254'), Decimal('261'), Decimal('117')),
#  ('General Mills', Decimal('423'), Decimal('36'), Decimal('12')),
#  ('Qualcomm', Decimal('336'), Decimal('19'), Decimal('54')),
#  ('Jabil Circuit', Decimal('182'), Decimal('208'), Decimal('140')),
#  ('Guardian Life Ins. Co. of America', Decimal('206'), Decimal('228'), Decimal('161')),
#  ('UnitedHealth Group', Decimal('401'), Decimal('40'), Decimal('17')),
#  ('Thermo Fisher Scientific', Decimal('395'), Decimal('41'), Decimal('40')),
#  ('Caterpillar', Decimal('302'), Decimal('380'), Decimal('93')),
#  ('Berkshire Hathaway', Decimal('1148'), Decimal('0'), Decimal('215')),
#  ('Franklin Resources', Decimal('239'), Decimal('221'), Decimal('101')),
#  ('Murphy USA', Decimal('288'), Decimal('30'), Decimal('168')),
#  ('NextEra Energy', Decimal('101'), Decimal('27'), Decimal('44')),
#  ('Walgreens Boots Alliance', Decimal('402'), Decimal('25'), Decimal('21')),
#  ("Peter Kiewit Sons'", Decimal('323'), Decimal('319'), Decimal('131')),
#  ('Reinsurance Group of America', Decimal('403'), Decimal('52'), Decimal('20'))]

# %% [markdown]
# #### 19. For each account, determine the average amount spent per order on each paper type. Your result should have four columns - one for the account name and one for the average amount spent on each paper type.

# %%
# %%sql
# SELECT
#     company,
#     ROUND(AVG(standard_amt_usd),2) AS avg_standard_qty,
#     ROUND(AVG(gloss_amt_usd),2) AS avg_gloss_qty,
#     ROUND(AVG(poster_amt_usd),2) AS avg_poster_qty
# FROM orders_consolidated
# GROUP BY company
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 350 rows affected.
# [('Comcast', Decimal('1467.06'), Decimal('136.96'), Decimal('234.32')),
#  ('Microsoft', Decimal('441.42'), Decimal('241.41'), Decimal('505.94')),
#  ('Monsanto', Decimal('1764.53'), Decimal('319.97'), Decimal('213.11')),
#  ('Dean Foods', Decimal('1032.22'), Decimal('1606.07'), Decimal('1149.56')),
#  ('KKR', Decimal('970.51'), Decimal('1722.16'), Decimal('1261.41')),
#  ('Performance Food Group', Decimal('1641.00'), Decimal('253.95'), Decimal('373.91')),
#  ('Paccar', Decimal('564.52'), Decimal('1851.33'), Decimal('1090.55')),
#  ('USAA', Decimal('973.60'), Decimal('2336.05'), Decimal('1892.86')),
#  ('CST Brands', Decimal('1723.38'), Decimal('246.71'), Decimal('539.23')),
#  ('Ally Financial', Decimal('1514.47'), Decimal('2243.26'), Decimal('949.03')),
#  ('Amgen', Decimal('1168.41'), Decimal('1885.98'), Decimal('1046.26')),
#  ('Broadcom', Decimal('936.18'), Decimal('2015.23'), Decimal('1222.51')),
#  ('AIG', Decimal('1499.50'), Decimal('2614.01'), Decimal('876.96')),
#  ('W.W. Grainger', Decimal('830.84'), Decimal('2029.79'), Decimal('1331.68')),
#  ('Reynolds American', Decimal('1736.52'), Decimal('212.65'), Decimal('221.71')),
#  ('Sears Holdings', Decimal('1887.88'), Decimal('1508.74'), Decimal('1237.22')),
#  ('HCA Holdings', Decimal('1499.50'), Decimal('2606.52'), Decimal('1055.60')),
#  ('Aetna', Decimal('1143.69'), Decimal('1585.97'), Decimal('1932.72')),
#  ('Deere', Decimal('508.98'), Decimal('292.11'), Decimal('235.48')),
#  ('Procter & Gamble', Decimal('1196.89'), Decimal('1380.30'), Decimal('702.96')),
#  ('Gilead Sciences', Decimal('1711.57'), Decimal('319.57'), Decimal('270.67')),
#  ('Dominion Resources', Decimal('1018.46'), Decimal('1420.85'), Decimal('790.89')),
#  ('Viacom', Decimal('2019.88'), Decimal('238.08'), Decimal('147.32')),
#  ('Altria Group', Decimal('1901.68'), Decimal('168.45'), Decimal('207.62')),
#  ('HP', Decimal('1747.61'), Decimal('533.45'), Decimal('839.07')),
#  ('General Motors', Decimal('2003.49'), Decimal('1812.58'), Decimal('1181.46')),
#  ('American Family Insurance Group', Decimal('1877.64'), Decimal('230.61'), Decimal('576.24')),
#  ('Kinder Morgan', Decimal('1817.19'), Decimal('273.39'), Decimal('196.57')),
#  ('PBF Energy', Decimal('611.90'), Decimal('149.33'), Decimal('381.64')),
#  ('Baker Hughes', Decimal('1117.76'), Decimal('1456.81'), Decimal('660.43')),
#  ('Bank of America Corp.', Decimal('1285.76'), Decimal('1851.28'), Decimal('747.04')),
#  ('CenturyLink', Decimal('1487.02'), Decimal('2931.09'), Decimal('3004.40')),
#  ('Universal Health Services', Decimal('2582.33'), Decimal('52.43'), Decimal('0.00')),
#  ('Marriott International', Decimal('1971.05'), Decimal('2602.78'), Decimal('816.06')),
#  ('CBRE Group', Decimal('1439.62'), Decimal('2127.16'), Decimal('1291.08')),
#  ('AutoNation', Decimal('1677.71'), Decimal('340.39'), Decimal('407.31')),
#  ('FedEx', Decimal('1648.71'), Decimal('242.97'), Decimal('212.97')),
#  ('Best Buy', Decimal('643.02'), Decimal('1750.72'), Decimal('431.90')),
#  ('Home Depot', Decimal('1224.21'), Decimal('1562.91'), Decimal('768.69')),
#  ('Leucadia National', Decimal('941.35'), Decimal('1838.00'), Decimal('1319.90')),
#  ('TIAA', Decimal('1395.95'), Decimal('288.37'), Decimal('308.56')),
#  ('Tenneco', Decimal('374.25'), Decimal('567.37'), Decimal('493.29')),
#  ('Avis Budget Group', Decimal('1040.70'), Decimal('1707.11'), Decimal('1214.67')),
#  ('MasterCard', Decimal('1197.60'), Decimal('1755.16'), Decimal('565.69')),
#  ('Western Refining', Decimal('1722.30'), Decimal('744.13'), Decimal('248.07')),
#  ('American Airlines Group', Decimal('1844.49'), Decimal('174.31'), Decimal('716.04')),
#  ('Plains GP Holdings', Decimal('2006.98'), Decimal('109.35'), Decimal('190.01')),
#  ('Celgene', Decimal('1073.45'), Decimal('1653.49'), Decimal('1136.80')),
#  ('Ross Stores', Decimal('1716.56'), Decimal('274.41'), Decimal('278.29')),
#  ('Anthem', Decimal('1810.42'), Decimal('261.44'), Decimal('189.47')),
#  ('Applied Materials', Decimal('369.26'), Decimal('865.10'), Decimal('312.62')),
#  ('Stanley Black & Decker', Decimal('1721.10'), Decimal('329.11'), Decimal('155.51')),
#  ('Ameriprise Financial', Decimal('1913.46'), Decimal('190.37'), Decimal('224.65')),
#  ('Northrop Grumman', Decimal('901.94'), Decimal('1740.80'), Decimal('1405.44')),
#  ('Progressive', Decimal('1799.14'), Decimal('251.52'), Decimal('300.18')),
#  ('Allstate', Decimal('1342.51'), Decimal('1613.05'), Decimal('915.61')),
#  ('Freeport-McMoRan', Decimal('864.93'), Decimal('2113.43'), Decimal('1118.53')),
#  ('Valero Energy', Decimal('754.26'), Decimal('2005.59'), Decimal('1241.74')),
#  ('EOG Resources', Decimal('1407.50'), Decimal('3919.20'), Decimal('848.67')),
#  ('Unum Group', Decimal('1696.60'), Decimal('586.72'), Decimal('242.70')),
#  ('Fannie Mae', Decimal('1349.80'), Decimal('187.25'), Decimal('353.22')),
#  ('MGM Resorts International', Decimal('817.11'), Decimal('1997.96'), Decimal('1429.12')),
#  ('Freddie Mac', Decimal('961.06'), Decimal('1763.53'), Decimal('1053.24')),
#  ('Halliburton', Decimal('1439.62'), Decimal('2902.38'), Decimal('1098.91')),
#  ('Costco', Decimal('711.08'), Decimal('1393.14'), Decimal('3019.29')),
#  ('DISH Network', Decimal('1760.72'), Decimal('278.88'), Decimal('2187.66')),
#  ('Icahn Enterprises', Decimal('1236.27'), Decimal('1081.06'), Decimal('920.27')),
#  ('Priceline Group', Decimal('1741.51'), Decimal('217.21'), Decimal('170.52')),
#  ('Office Depot', Decimal('2148.59'), Decimal('233.37'), Decimal('327.36')),
#  ('PPG Industries', Decimal('1271.62'), Decimal('1449.32'), Decimal('939.21')),
#  ('Chevron', Decimal('748.12'), Decimal('1651.26'), Decimal('1194.89')),
#  ('Aramark', Decimal('600.05'), Decimal('950.29'), Decimal('1161.16')),
#  ('Republic Services', Decimal('981.63'), Decimal('1644.50'), Decimal('3251.09')),
#  ('BorgWarner', Decimal('924.51'), Decimal('1854.80'), Decimal('969.97')),
#  ('D.R. Horton', Decimal('921.95'), Decimal('1830.86'), Decimal('1186.17')),
#  ('EMC', Decimal('1323.46'), Decimal('1999.83'), Decimal('785.84')),
#  ('Tyson Foods', Decimal('560.78'), Decimal('321.71'), Decimal('246.50')),
#  ('Marathon Petroleum', Decimal('1532.49'), Decimal('464.50'), Decimal('216.36')),
#  ('Dollar General', Decimal('2026.69'), Decimal('227.70'), Decimal('244.41')),
#  ('Oracle', Decimal('1270.31'), Decimal('2107.90'), Decimal('1083.44')),
#  ('Baxter International', Decimal('2009.86'), Decimal('154.79'), Decimal('355.48')),
#  ('Southern', Decimal('1734.03'), Decimal('207.85'), Decimal('202.19')),
#  ('Autoliv', Decimal('1114.43'), Decimal('1363.18'), Decimal('950.04')),
#  ('Devon Energy', Decimal('1549.40'), Decimal('2276.96'), Decimal('941.92')),
#  ('Corning', Decimal('617.76'), Decimal('299.60'), Decimal('670.71')),
#  ('Xcel Energy', Decimal('2081.66'), Decimal('1175.93'), Decimal('71.73')),
#  ('Fidelity National Financial', Decimal('2015.96'), Decimal('120.78'), Decimal('11616.68')),
#  ('Anadarko Petroleum', Decimal('912.97'), Decimal('1371.57'), Decimal('928.60')),
#  ('Global Partners', Decimal('1749.08'), Decimal('164.52'), Decimal('428.12')),
#  ('Enterprise Products Partners', Decimal('960.22'), Decimal('2211.69'), Decimal('1395.48')),
#  ('Mohawk Industries', Decimal('2420.15'), Decimal('524.30'), Decimal('81.20')),
#  ('Navistar International', Decimal('1544.90'), Decimal('159.54'), Decimal('544.04')),
#  ('R.R. Donnelley & Sons', Decimal('1842.74'), Decimal('156.76'), Decimal('587.54')),
#  ('CVS Health', Decimal('769.29'), Decimal('1942.41'), Decimal('1232.89')),
#  ('Kimberly-Clark', Decimal('1650.26'), Decimal('125.73'), Decimal('306.24')),
#  ('Fluor', Decimal('950.56'), Decimal('1731.57'), Decimal('1184.02')),
#  ('MetLife', Decimal('2488.35'), Decimal('47.44'), Decimal('2.71')),
#  ('Time Warner', Decimal('1269.12'), Decimal('1849.20'), Decimal('741.63')),
#  ('Campbell Soup', Decimal('855.79'), Decimal('1982.35'), Decimal('1456.19')),
#  ('Mosaic', Decimal('1066.27'), Decimal('1822.34'), Decimal('2348.03')),
#  ('Core-Mark Holding', Decimal('3708.37'), Decimal('265.76'), Decimal('166.17')),
#  ('Liberty Mutual Insurance Group', Decimal('1467.06'), Decimal('2305.05'), Decimal('458.78')),
#  ('Morgan Stanley', Decimal('1499.22'), Decimal('573.40'), Decimal('180.44')),
#  ('Laboratory Corp. of America', Decimal('1869.59'), Decimal('198.49'), Decimal('57.52')),
#  ('Texas Instruments', Decimal('1689.66'), Decimal('164.13'), Decimal('528.51')),
#  ('American Electric Power', Decimal('1475.57'), Decimal('175.35'), Decimal('234.05')),
#  ('INTL FCStone', Decimal('1646.70'), Decimal('546.77'), Decimal('178.64')),
#  ('Farmers Insurance Exchange', Decimal('1625.55'), Decimal('299.44'), Decimal('170.17')),
#  ('Norfolk Southern', Decimal('1741.51'), Decimal('617.51'), Decimal('96.54')),
#  ('AES', Decimal('1270.79'), Decimal('2276.96'), Decimal('798.47')),
#  ('Eastman Chemical', Decimal('1138.72'), Decimal('1184.92'), Decimal('937.05')),
#  ('Exxon Mobil', Decimal('2629.73'), Decimal('104.86'), Decimal('0.00')),
#  ('First Data', Decimal('1022.50'), Decimal('1826.88'), Decimal('1329.47')),
#  ('Time Warner Cable', Decimal('1335.24'), Decimal('2481.69'), Decimal('943.95')),
#  ('Rite Aid', Decimal('1626.74'), Decimal('169.77'), Decimal('75.79')),
#  ('UPS', Decimal('1998.50'), Decimal('2419.27'), Decimal('921.62')),
#  ('News Corp.', Decimal('944.11'), Decimal('1635.07'), Decimal('888.33')),
#  ('AutoZone', Decimal('1014.22'), Decimal('1795.26'), Decimal('1312.90')),
#  ('Molina Healthcare', Decimal('1800.00'), Decimal('1646.97'), Decimal('240.89')),
#  ('Merck', Decimal('1784.20'), Decimal('274.91'), Decimal('331.12')),
#  ('Assurant', Decimal('583.83'), Decimal('164.78'), Decimal('487.20')),
#  ('Biogen', Decimal('1038.92'), Decimal('1722.70'), Decimal('1115.69')),
#  ('Textron', Decimal('1939.30'), Decimal('248.53'), Decimal('206.69')),
#  ('Waste Management', Decimal('2844.30'), Decimal('2108.44'), Decimal('81.20')),
#  ('United States Steel', Decimal('1062.41'), Decimal('1683.52'), Decimal('1018.62')),
#  ('CDW', Decimal('917.42'), Decimal('1701.89'), Decimal('1141.91')),
#  ('Bed Bath & Beyond', Decimal('394.21'), Decimal('561.75'), Decimal('113.68')),
#  ('Abbott Laboratories', Decimal('1003.49'), Decimal('1473.28'), Decimal('750.56')),
#  ('L-3 Communications', Decimal('1660.31'), Decimal('210.40'), Decimal('153.54')),
#  ("Toys 'R' Us", Decimal('1084.49'), Decimal('2679.55'), Decimal('917.56')),
#  ('Kellogg', Decimal('1783.14'), Decimal('227.91'), Decimal('372.36')),
#  ('CarMax', Decimal('1106.90'), Decimal('1451.74'), Decimal('1220.87')),
#  ('Publix Super Markets', Decimal('920.66'), Decimal('2011.07'), Decimal('1250.48')),
#  ("Kohl's", Decimal('9372.65'), Decimal('2140.00'), Decimal('1359.52')),
#  ('Philip Morris International', Decimal('1492.55'), Decimal('319.07'), Decimal('305.31')),
#  ('Goodyear Tire & Rubber', Decimal('855.48'), Decimal('2465.67'), Decimal('1202.35')),
#  ('TJX', Decimal('2059.77'), Decimal('270.69'), Decimal('470.47')),
#  ('CBS', Decimal('1482.03'), Decimal('239.68'), Decimal('6926.36')),
#  ('Becton Dickinson', Decimal('963.07'), Decimal('1595.37'), Decimal('1037.74')),
#  ('VF', Decimal('1576.84'), Decimal('2125.29'), Decimal('860.72')),
#  ('Gap', Decimal('654.69'), Decimal('1586.38'), Decimal('1117.31')),
#  ('Union Pacific', Decimal('1833.83'), Decimal('263.65'), Decimal('413.31')),
#  ('Air Products & Chemicals', Decimal('1031.68'), Decimal('1284.54'), Decimal('637.42')),
#  ('Supervalu', Decimal('988.83'), Decimal('1867.32'), Decimal('1192.21')),
#  ('ConocoPhillips', Decimal('2149.86'), Decimal('225.95'), Decimal('220.59')),
#  ('ConAgra Foods', Decimal('880.24'), Decimal('1806.59'), Decimal('1141.67')),
#  ('United Natural Foods', Decimal('1503.39'), Decimal('416.44'), Decimal('257.89')),
#  ('NGL Energy Partners', Decimal('1018.79'), Decimal('1630.95'), Decimal('734.18')),
#  ('Amazon.com', Decimal('974.92'), Decimal('1468.98'), Decimal('1140.86')),
#  ('PVH', Decimal('1560.87'), Decimal('202.23'), Decimal('376.77')),
#  ('ADP', Decimal('1769.62'), Decimal('453.39'), Decimal('503.30')),
#  ('J.P. Morgan Chase', Decimal('1500.83'), Decimal('456.02'), Decimal('245.11')),
#  ('Lithia Motors', Decimal('1556.33'), Decimal('1056.71'), Decimal('363.14')),
#  ('Archer Daniels Midland', Decimal('986.58'), Decimal('1832.21'), Decimal('1312.61')),
#  ('Parker-Hannifin', Decimal('519.41'), Decimal('577.41'), Decimal('332.92')),
#  ('Energy Transfer Equity', Decimal('1108.61'), Decimal('1187.17'), Decimal('960.87')),
#  ('Whirlpool', Decimal('1361.60'), Decimal('344.54'), Decimal('491.53')),
#  ('PNC Financial Services Group', Decimal('463.64'), Decimal('430.51'), Decimal('1114.91')),
#  ('Reliance Steel & Aluminum', Decimal('1813.87'), Decimal('2467.96'), Decimal('812.00')),
#  ('Capital One Financial', Decimal('1215.72'), Decimal('2019.15'), Decimal('585.92')),
#  ('ManpowerGroup', Decimal('2203.92'), Decimal('52.43'), Decimal('181.35')),
#  ('Chesapeake Energy', Decimal('1356.28'), Decimal('2178.84'), Decimal('918.37')),
#  ('Travelers Cos.', Decimal('2625.26'), Decimal('2008.61'), Decimal('765.52')),
#  ('Apple', Decimal('1572.85'), Decimal('361.77'), Decimal('142.10')),
#  ('United Continental Holdings', Decimal('1411.69'), Decimal('299.48'), Decimal('175.80')),
#  ('Johnson & Johnson', Decimal('1190.12'), Decimal('1969.87'), Decimal('1400.70')),
#  ('BB&T Corp.', Decimal('1818.76'), Decimal('1643.01'), Decimal('1492.13')),
#  ('Delta Air Lines', Decimal('743.51'), Decimal('67.41'), Decimal('48.72')),
#  ('GameStop', Decimal('1528.09'), Decimal('1305.56'), Decimal('125.55')),
#  ('State Farm Insurance Cos.', Decimal('9439.97'), Decimal('1761.81'), Decimal('1221.61')),
#  ('Boeing', Decimal('1797.73'), Decimal('1665.28'), Decimal('876.42')),
#  ('Hartford Financial Services Group', Decimal('1709.57'), Decimal('189.50'), Decimal('126.67')),
#  ('American Express', Decimal('1537.35'), Decimal('323.37'), Decimal('120.03')),
#  ('Humana', Decimal('1914.73'), Decimal('330.10'), Decimal('107.88')),
#  ('Liberty Interactive', Decimal('1197.60'), Decimal('355.78'), Decimal('71.05')),
#  ('Consolidated Edison', Decimal('878.24'), Decimal('0.00'), Decimal('458.78')),
#  ('National Oilwell Varco', Decimal('842.57'), Decimal('1778.46'), Decimal('2242.62')),
#  ('NRG Energy', Decimal('957.14'), Decimal('1770.45'), Decimal('1005.36')),
#  ('AECOM', Decimal('1815.25'), Decimal('104.03'), Decimal('135.33')),
#  ('Sempra Energy', Decimal('1036.67'), Decimal('2586.86'), Decimal('1197.70')),
#  ('Verizon', Decimal('1386.85'), Decimal('1650.30'), Decimal('1236.04')),
#  ('Nationwide', Decimal('1293.88'), Decimal('1950.92'), Decimal('1262.90')),
#  ('AmerisourceBergen', Decimal('888.22'), Decimal('1964.25'), Decimal('6832.98')),
#  ('Ford Motor', Decimal('1104.95'), Decimal('1770.07'), Decimal('1309.08')),
#  ('Lincoln National', Decimal('952.30'), Decimal('1708.11'), Decimal('1425.27')),
#  ('CHS', Decimal('995.61'), Decimal('1981.59'), Decimal('4295.48')),
#  ('International Paper', Decimal('1348.01'), Decimal('2051.19'), Decimal('821.28')),
#  ('WellCare Health Plans', Decimal('1576.84'), Decimal('2340.63'), Decimal('954.10')),
#  ('Genuine Parts', Decimal('1640.46'), Decimal('2629.61'), Decimal('860.04')),
#  ('PPL', Decimal('1103.13'), Decimal('1730.96'), Decimal('1034.04')),
#  ('Precision Castparts', Decimal('981.92'), Decimal('1867.51'), Decimal('4233.23')),
#  ('Tesoro', Decimal('883.23'), Decimal('1460.55'), Decimal('1276.87')),
#  ('Pfizer', Decimal('1318.52'), Decimal('2637.98'), Decimal('872.36')),
#  ('Facebook', Decimal('2509.97'), Decimal('2402.42'), Decimal('968.31')),
#  ('US Foods Holding', Decimal('936.69'), Decimal('2402.15'), Decimal('528.96')),
#  ('WestRock', Decimal('487.21'), Decimal('326.84'), Decimal('393.45')),
#  ('Ecolab', Decimal('1762.88'), Decimal('561.18'), Decimal('232.88')),
#  ('Tech Data', Decimal('1912.28'), Decimal('157.29'), Decimal('65.86')),
#  ('General Electric', Decimal('509.51'), Decimal('432.05'), Decimal('391.90')),
#  ('McKesson', Decimal('834.33'), Decimal('1153.46'), Decimal('1049.10')),
#  ('Nordstrom', Decimal('1129.61'), Decimal('1659.97'), Decimal('1119.55')),
#  ('Avnet', Decimal('1244.17'), Decimal('2324.90'), Decimal('885.08')),
#  ('Yum Brands', Decimal('1400.86'), Decimal('289.61'), Decimal('195.96')),
#  ('Phillips 66', Decimal('1060.30'), Decimal('1585.74'), Decimal('1101.77')),
#  ('Western Digital', Decimal('962.00'), Decimal('1796.33'), Decimal('1382.52')),
#  ("O'Reilly Automotive", Decimal('983.03'), Decimal('1423.10'), Decimal('898.61')),
#  ('Eli Lilly', Decimal('1494.51'), Decimal('2363.10'), Decimal('812.00')),
#  ('Intel', Decimal('943.47'), Decimal('1818.47'), Decimal('1231.34')),
#  ('Veritiv', Decimal('445.11'), Decimal('304.09'), Decimal('397.88')),
#  ('Loews', Decimal('2485.02'), Decimal('0.00'), Decimal('81.20')),
#  ('Computer Sciences', Decimal('683.63'), Decimal('313.02'), Decimal('170.52')),
#  ('PepsiCo', Decimal('1484.17'), Decimal('2249.14'), Decimal('566.08')),
#  ('U.S. Bancorp', Decimal('2191.44'), Decimal('1855.02'), Decimal('393.82')),
#  ('Whole Foods Market', Decimal('1956.63'), Decimal('182.26'), Decimal('110.07')),
#  ('Henry Schein', Decimal('969.31'), Decimal('2179.59'), Decimal('1287.02')),
#  ('Northwestern Mutual', Decimal('1386.39'), Decimal('168.53'), Decimal('422.24')),
#  ('Arrow Electronics', Decimal('951.97'), Decimal('1972.22'), Decimal('1270.11')),
#  ('Discover Financial Services', Decimal('1038.54'), Decimal('1564.94'), Decimal('961.21')),
#  ('AT&T', Decimal('534.16'), Decimal('316.84'), Decimal('350.10')),
#  ('Estee Lauder', Decimal('907.18'), Decimal('1746.67'), Decimal('1166.03')),
#  ('Health Net', Decimal('1876.66'), Decimal('313.33'), Decimal('121.12')),
#  ('L Brands', Decimal('1489.52'), Decimal('2342.50'), Decimal('527.80')),
#  ('Wells Fargo', Decimal('917.45'), Decimal('1923.40'), Decimal('1244.35')),
#  ("Land O'Lakes", Decimal('1740.56'), Decimal('190.87'), Decimal('453.46')),
#  ("Lowe's", Decimal('1873.61'), Decimal('191.19'), Decimal('349.59')),
#  ('Dollar Tree', Decimal('1059.13'), Decimal('1353.82'), Decimal('140.07')),
#  ('Raytheon', Decimal('1172.88'), Decimal('1851.73'), Decimal('1281.11')),
#  ('Bristol-Myers Squibb', Decimal('1351.48'), Decimal('2026.83'), Decimal('1004.43')),
#  ('World Fuel Services', Decimal('1037.92'), Decimal('1548.56'), Decimal('121.80')),
#  ('SunTrust Banks', Decimal('1005.59'), Decimal('1803.79'), Decimal('1500.43')),
#  ('PG&E Corp.', Decimal('1319.54'), Decimal('3148.61'), Decimal('637.93')),
#  ('Level 3 Communications', Decimal('613.77'), Decimal('0.00'), Decimal('267.96')),
#  ('CSX', Decimal('1369.40'), Decimal('2228.81'), Decimal('1510.32')),
#  ('Honeywell International', Decimal('1672.74'), Decimal('371.93'), Decimal('654.17')),
#  ('Cameron International', Decimal('2012.40'), Decimal('215.34'), Decimal('181.54')),
#  ('Lennar', Decimal('2579.83'), Decimal('74.90'), Decimal('16.24')),
#  ('Cummins', Decimal('1033.43'), Decimal('1390.89'), Decimal('1059.66')),
#  ('Masco', Decimal('645.58'), Decimal('250.45'), Decimal('351.70')),
#  ('Tenet Healthcare', Decimal('1558.13'), Decimal('1829.43'), Decimal('740.95')),
#  ('Xerox', Decimal('1331.08'), Decimal('142.31'), Decimal('716.59')),
#  ('AbbVie', Decimal('1189.28'), Decimal('2082.22'), Decimal('476.37')),
#  ('Principal Financial', Decimal('1441.40'), Decimal('391.62'), Decimal('335.24')),
#  ('Target', Decimal('1233.69'), Decimal('1557.92'), Decimal('1225.85')),
#  ('eBay', Decimal('1804.95'), Decimal('241.39'), Decimal('646.35')),
#  ('State Street Corp.', Decimal('1041.19'), Decimal('1760.92'), Decimal('1307.32')),
#  ('Starbucks', Decimal('818.36'), Decimal('2348.12'), Decimal('4271.12')),
#  ('Visa', Decimal('1183.63'), Decimal('1877.49'), Decimal('1022.58')),
#  ('Community Health Systems', Decimal('2042.72'), Decimal('2205.46'), Decimal('901.32')),
#  ("McDonald's", Decimal('950.02'), Decimal('1871.35'), Decimal('813.87')),
#  ('Colgate-Palmolive', Decimal('1645.87'), Decimal('334.18'), Decimal('201.51')),
#  ('Crown Holdings', Decimal('1420.37'), Decimal('2949.99'), Decimal('994.70')),
#  ('DTE Energy', Decimal('1970.05'), Decimal('146.80'), Decimal('183.51')),
#  ('Danaher', Decimal('885.73'), Decimal('1954.89'), Decimal('1226.12')),
#  ('Cigna', Decimal('2671.65'), Decimal('341.92'), Decimal('178.23')),
#  ('Advance Auto Parts', Decimal('1367.26'), Decimal('147.93'), Decimal('225.33')),
#  ('Owens & Minor', Decimal('460.08'), Decimal('426.18'), Decimal('464.46')),
#  ('Hertz Global Holdings', Decimal('1568.86'), Decimal('373.00'), Decimal('250.10')),
#  ('Penske Automotive Group', Decimal('991.35'), Decimal('1926.18'), Decimal('1496.79')),
#  ('Mondelez International', Decimal('1669.99'), Decimal('203.89'), Decimal('2288.94')),
#  ('IBM', Decimal('1313.87'), Decimal('1878.74'), Decimal('2254.38')),
#  ('Edison International', Decimal('3775.43'), Decimal('188.75'), Decimal('3438.01')),
#  ('Sysco', Decimal('953.38'), Decimal('1731.51'), Decimal('1411.81')),
#  ('Newmont Mining', Decimal('449.10'), Decimal('423.93'), Decimal('1050.73')),
#  ('Genworth Financial', Decimal('1656.68'), Decimal('244.67'), Decimal('232.77')),
#  ('Hormel Foods', Decimal('938.32'), Decimal('1474.93'), Decimal('1144.60')),
#  ('J.C. Penney', Decimal('471.56'), Decimal('161.04'), Decimal('180.67')),
#  ('Staples', Decimal('1736.52'), Decimal('186.18'), Decimal('322.48')),
#  ('Duke Energy', Decimal('1109.55'), Decimal('1682.11'), Decimal('1042.77')),
#  ('Dow Chemical', Decimal('903.19'), Decimal('2078.48'), Decimal('1234.24')),
#  ('Synnex', Decimal('1517.44'), Decimal('2036.31'), Decimal('770.09')),
#  ('Entergy', Decimal('1639.61'), Decimal('208.01'), Decimal('319.10')),
#  ('Exelon', Decimal('520.91'), Decimal('338.35'), Decimal('338.92')),
#  ('Las Vegas Sands', Decimal('578.84'), Decimal('307.09'), Decimal('227.36')),
#  ('Group 1 Automotive', Decimal('1978.73'), Decimal('289.81'), Decimal('93.69')),
#  ('Illinois Tool Works', Decimal('1785.97'), Decimal('1816.67'), Decimal('2528.27')),
#  ('Aflac', Decimal('2246.31'), Decimal('230.98'), Decimal('708.20')),
#  ('HollyFrontier', Decimal('1025.05'), Decimal('1739.26'), Decimal('1419.29')),
#  ('Omnicom Group', Decimal('1618.26'), Decimal('211.22'), Decimal('228.58')),
#  ('Jarden', Decimal('1236.13'), Decimal('1869.89'), Decimal('1074.48')),
#  ('United Technologies', Decimal('1099.52'), Decimal('1813.48'), Decimal('1139.60')),
#  ('Jacobs Engineering Group', Decimal('902.02'), Decimal('1720.94'), Decimal('1824.13')),
#  ('Southwest Airlines', Decimal('1932.60'), Decimal('325.45'), Decimal('211.92')),
#  ('Massachusetts Mutual Life Insurance', Decimal('563.87'), Decimal('48.69'), Decimal('41.95')),
#  ('Lear', Decimal('567.61'), Decimal('309.34'), Decimal('308.97')),
#  ('Citigroup', Decimal('1887.85'), Decimal('470.97'), Decimal('400.68')),
#  ('Alphabet', Decimal('1583.83'), Decimal('1869.50'), Decimal('987.39')),
#  ('Walmart', Decimal('1407.18'), Decimal('2094.79'), Decimal('927.13')),
#  ('Pacific Life', Decimal('1675.10'), Decimal('227.00'), Decimal('17737.83')),
#  ('Kraft Heinz', Decimal('1519.26'), Decimal('165.36'), Decimal('297.32')),
#  ('Public Service Enterprise Group', Decimal('902.77'), Decimal('2344.37'), Decimal('2905.61')),
#  ('Univar', Decimal('1383.34'), Decimal('135.65'), Decimal('328.41')),
#  ('Charter Communications', Decimal('1627.43'), Decimal('206.49'), Decimal('509.60')),
#  ('Lockheed Martin', Decimal('2280.43'), Decimal('29.96'), Decimal('129.92')),
#  ('Occidental Petroleum', Decimal('1364.56'), Decimal('2207.99'), Decimal('807.26')),
#  ('DaVita HealthCare Partners', Decimal('545.57'), Decimal('302.10'), Decimal('1040.26')),
#  ('Micron Technology', Decimal('723.55'), Decimal('333.31'), Decimal('162.40')),
#  ('3M', Decimal('1563.83'), Decimal('2095.33'), Decimal('910.31')),
#  ('HD Supply Holdings', Decimal('1535.26'), Decimal('2034.16'), Decimal('671.25')),
#  ('Centene', Decimal('1028.59'), Decimal('1712.75'), Decimal('1176.07')),
#  ('Huntsman', Decimal('1282.43'), Decimal('775.22'), Decimal('1291.08')),
#  ('New York Life Insurance', Decimal('1625.05'), Decimal('334.91'), Decimal('306.10')),
#  ('Thrivent Financial for Lutherans', Decimal('1368.92'), Decimal('180.83'), Decimal('269.51')),
#  ('Praxair', Decimal('2812.70'), Decimal('202.23'), Decimal('155.63')),
#  ('General Dynamics', Decimal('1026.96'), Decimal('2139.64'), Decimal('1389.38')),
#  ('Eversource Energy', Decimal('1427.64'), Decimal('3341.29'), Decimal('937.05')),
#  ('Johnson Controls', Decimal('1478.29'), Decimal('219.08'), Decimal('192.44')),
#  ('BlackRock', Decimal('1973.29'), Decimal('360.55'), Decimal('210.98')),
#  ('PayPal Holdings', Decimal('1601.91'), Decimal('192.31'), Decimal('325.00')),
#  ('Stryker', Decimal('1334.83'), Decimal('625.42'), Decimal('300.44')),
#  ('C.H. Robinson Worldwide', Decimal('838.32'), Decimal('1917.44'), Decimal('974.40')),
#  ('Emerson Electric', Decimal('954.80'), Decimal('1761.53'), Decimal('1059.23')),
#  ('Alcoa', Decimal('1554.16'), Decimal('77.62'), Decimal('175.69')),
#  ('Twenty-First Century Fox', Decimal('476.27'), Decimal('408.07'), Decimal('673.66')),
#  ('SpartanNash', Decimal('389.60'), Decimal('379.69'), Decimal('356.03')),
#  ('Kroger', Decimal('1416.63'), Decimal('316.16'), Decimal('1422.28')),
#  ('Sherwin-Williams', Decimal('456.59'), Decimal('396.97'), Decimal('332.92')),
#  ('DuPont', Decimal('1546.90'), Decimal('274.25'), Decimal('142.41')),
#  ('Cardinal Health', Decimal('1248.75'), Decimal('292.11'), Decimal('261.87')),
#  ('Coca-Cola', Decimal('1447.10'), Decimal('186.31'), Decimal('187.10')),
#  ('Prudential Financial', Decimal('964.07'), Decimal('1734.68'), Decimal('1245.81')),
#  ('Hilton Worldwide Holdings', Decimal('665.89'), Decimal('391.70'), Decimal('373.82')),
#  ('Nucor', Decimal('1734.97'), Decimal('129.40'), Decimal('236.88')),
#  ('FirstEnergy', Decimal('1607.35'), Decimal('287.69'), Decimal('283.14')),
#  ('Oneok', Decimal('1040.42'), Decimal('191.00'), Decimal('190.82')),
#  ("Macy's", Decimal('1856.28'), Decimal('374.50'), Decimal('172.55')),
#  ('Sonic Automotive', Decimal('1413.42'), Decimal('205.98'), Decimal('178.64')),
#  ('Nike', Decimal('0.00'), Decimal('187.25'), Decimal('203.00')),
#  ('Marsh & McLennan', Decimal('868.26'), Decimal('1896.84'), Decimal('1299.20')),
#  ('Cisco Systems', Decimal('1642.53'), Decimal('174.73'), Decimal('328.93')),
#  ('Voya Financial', Decimal('1884.79'), Decimal('195.81'), Decimal('174.00')),
#  ('Disney', Decimal('1531.84'), Decimal('1845.30'), Decimal('234.91')),
#  ('Bank of New York Mellon Corp.', Decimal('1846.30'), Decimal('179.76'), Decimal('129.92')),
#  ('Express Scripts Holding', Decimal('828.34'), Decimal('3065.28'), Decimal('878.99')),
#  ('Ingram Micro', Decimal('807.83'), Decimal('1288.28'), Decimal('703.73')),
#  ('Ball', Decimal('1516.96'), Decimal('254.66'), Decimal('211.12')),
#  ('Cognizant Technology Solutions', Decimal('1266.79'), Decimal('1953.89'), Decimal('946.25')),
#  ('General Mills', Decimal('2111.54'), Decimal('273.10'), Decimal('94.32')),
#  ('Qualcomm', Decimal('1674.77'), Decimal('143.87'), Decimal('436.11')),
#  ('Jabil Circuit', Decimal('906.59'), Decimal('1561.32'), Decimal('1134.22')),
#  ('Guardian Life Ins. Co. of America', Decimal('1028.20'), Decimal('1705.42'), Decimal('1305.45')),
#  ('UnitedHealth Group', Decimal('2000.44'), Decimal('296.27'), Decimal('140.75')),
#  ('Thermo Fisher Scientific', Decimal('1972.40'), Decimal('308.11'), Decimal('324.66')),
#  ('Caterpillar', Decimal('1506.98'), Decimal('2846.67'), Decimal('752.62')),
#  ('Berkshire Hathaway', Decimal('5728.52'), Decimal('0.00'), Decimal('1745.80')),
#  ('Franklin Resources', Decimal('1193.42'), Decimal('1655.29'), Decimal('819.68')),
#  ('Murphy USA', Decimal('1438.78'), Decimal('221.58'), Decimal('1364.16')),
#  ('NextEra Energy', Decimal('504.99'), Decimal('205.23'), Decimal('354.03')),
#  ('Walgreens Boots Alliance', Decimal('2004.98'), Decimal('190.93'), Decimal('170.52')),
#  ("Peter Kiewit Sons'", Decimal('1613.02'), Decimal('2385.57'), Decimal('1059.66')),
#  ('Reinsurance Group of America', Decimal('2012.22'), Decimal('389.48'), Decimal('164.43'))]

# %% [markdown]
# #### 20. Determine the number of times a particular channel was used in the web_events table for each sales rep. Your final table should have three columns - the name of the sales rep, the channel, and the number of occurrences. Order your table with the highest number of occurrences first.

# %%
# %%sql
# SELECT
#     primary_poc,
#     channel,
#     COUNT(occurred_at) AS num_count
# FROM (
# SELECT
#     w.id AS web_id,
#     w.account_id,
#     w.occurred_at,
#     w.channel,
#     a.name AS company,
#     a.primary_poc,
#     sales_rep_id
# FROM web_events AS w
# JOIN accounts AS a
# ON a.id = w.account_id
# ) AS web_sales
# GROUP BY primary_poc, channel
# ORDER BY num_count DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1446 rows affected.
# [('Tamara Tuma', 'direct', 68),
#  ('Jodee Lupo', 'direct', 56),
#  ('Merrill Rubino', 'direct', 52),
#  ('Arlyne Mauzy', 'direct', 51),
#  ('Barton Hyatt', 'direct', 51),
#  ('Angla Ingrassia', 'direct', 49),
#  ('Natacha Rita', 'direct', 48),
#  ('Nam Rothfuss', 'direct', 48),
#  ('Jay Gauger', 'direct', 48),
#  ('Catherine Bermejo', 'direct', 48),
#  ('September Jacquet', 'direct', 48),
#  ('Juliet Nugent', 'direct', 47),
#  ('Racquel Andrus', 'direct', 47),
#  ('Keren Mcconn', 'direct', 47),
#  ('Lorette Blasi', 'direct', 47),
#  ('Emmitt Mcnab', 'direct', 46),
#  ('Donnie Ehrhardt', 'direct', 46),
#  ('Deadra Waggener', 'direct', 46),
#  ('Marita Demasi', 'direct', 46),
#  ('Kristopher Moton', 'direct', 45),
#  ('Esta Engelhardt', 'direct', 45),
#  ('Leana Hawker', 'direct', 45),
#  ('Sheryl Diamond', 'direct', 44),
#  ('Alida Desrosier', 'direct', 44),
#  ('Loren Schlanger', 'direct', 44),
#  ('Timika Mistretta', 'direct', 44),
#  ('Julia Laracuente', 'direct', 44),
#  ('Craig Mcalpine', 'direct', 44),
#  ('Erin Viverette', 'direct', 44),
#  ('Laurette Sakai', 'direct', 44),
#  ('Janett Wisecarver', 'direct', 43),
#  ('Nannie Brinkman', 'direct', 43),
#  ('Jamel Mosqueda', 'direct', 43),
#  ('Idalia Agosta', 'direct', 42),
#  ('Kandi Mailloux', 'direct', 42),
#  ('Denis Gros', 'direct', 42),
#  ('Chas Nagler', 'direct', 42),
#  ('Diedra Crossman', 'direct', 41),
#  ('Buffy Azure', 'direct', 40),
#  ('Shasta Rodas', 'direct', 40),
#  ('Venessa Moreles', 'direct', 40),
#  ('Elayne Grunewald', 'direct', 40),
#  ('Kayleen Orlowski', 'direct', 39),
#  ('Shanika Mariani', 'direct', 39),
#  ('Fay Rogowski', 'direct', 39),
#  ('Josh Deslauriers', 'direct', 39),
#  ('Ana Blount', 'direct', 39),
#  ('Bea Sera', 'direct', 38),
#  ('Gail Widmer', 'direct', 37),
#  ('Noah Melugin', 'direct', 36),
#  ('Eloisa Lafuente', 'direct', 36),
#  ('Love Quirion', 'direct', 36),
#  ('Ardelle Khoury', 'direct', 35),
#  ('Delora Musson', 'direct', 33),
#  ('Kellee Suniga', 'direct', 33),
#  ('Dominique Favela', 'direct', 32),
#  ('Monet Maclaren', 'direct', 31),
#  ('Domonique Cave', 'direct', 31),
#  ('Deanne Hertlein', 'direct', 30),
#  ('Janyce Quarles', 'direct', 30),
#  ('Birgit Lacasse', 'direct', 30),
#  ('Trisha Tigner', 'direct', 30),
#  ('Kym Hagerman', 'direct', 30),
#  ('Elouise Beyers', 'direct', 29),
#  ('Florentino Madrigal', 'direct', 29),
#  ('Chantell Drescher', 'direct', 29),
#  ('Chantal Laureano', 'direct', 28),
#  ('Lakenya Volker', 'direct', 28),
#  ('Jere Storey', 'direct', 28),
#  ('Willodean Steinberger', 'direct', 28),
#  ('Alejandro Taunton', 'direct', 27),
#  ('Chantal Dahmen', 'direct', 27),
#  ('Nickie Moulden', 'direct', 26),
#  ('Jodee Indelicato', 'direct', 26),
#  ('Savanna Gayman', 'direct', 26),
#  ('Lyda Lamarr', 'direct', 25),
#  ('Nichelle Singley', 'direct', 24),
#  ('Catrice Klingbeil', 'direct', 24),
#  ('Antwan Seagraves', 'direct', 24),
#  ('Maria Garibay', 'direct', 24),
#  ('Lacey Kight', 'direct', 23),
#  ('Hsiu Benedetti', 'direct', 23),
#  ('Vernie Pound', 'direct', 23),
#  ('Olevia Taubman', 'direct', 22),
#  ('Jeanne Harty', 'direct', 22),
#  ('Melody Neuner', 'direct', 21),
#  ('Newton Belmonte', 'direct', 21),
#  ('Tisha Coletti', 'direct', 21),
#  ('Natividad Pauli', 'direct', 21),
#  ('Khadijah Riemann', 'direct', 21),
#  ('Davida Woldt', 'direct', 21),
#  ('Adelia Weston', 'direct', 20),
#  ('Torri Northrop', 'direct', 20),
#  ('Hanh Oram', 'direct', 20),
#  ('Luba Streett', 'direct', 20),
#  ('Rema Skipworth', 'direct', 20),
#  ('Horacio Weidman', 'direct', 20),
#  ('Seymour Olmedo', 'direct', 20),
#  ('Brianne Hunger', 'direct', 20),
#  ('Jordan Fils', 'direct', 20),
#  ('Corey Tobia', 'direct', 20),
#  ('Scot Feagin', 'direct', 19),
#  ('Paige Bartos', 'direct', 19),
#  ('Orville Leavell', 'direct', 19),
#  ('Adell Lever', 'direct', 19),
#  ('Maryalice Giltner', 'direct', 19),
#  ('Latesha Garcia', 'direct', 19),
#  ('Carisa Tinajero', 'direct', 18),
#  ('Keturah Cuadrado', 'direct', 18),
#  ('Parker Hoggan', 'direct', 18),
#  ('Chin Coppola', 'direct', 18),
#  ('Catherine Bermejo', 'organic', 18),
#  ('Jenny Poland', 'direct', 18),
#  ('Viva Jarrells', 'direct', 18),
#  ('Leana Godines', 'direct', 17),
#  ('Claudette Katzman', 'direct', 17),
#  ('Marita Demasi', 'adwords', 17),
#  ('Reagan Derouen', 'direct', 17),
#  ('Roselee Pardini', 'direct', 17),
#  ('Daisey Wyss', 'direct', 17),
#  ('Sheilah Truss', 'direct', 17),
#  ('Bernadine Stahly', 'direct', 17),
#  ('Lincoln Damewood', 'direct', 16),
#  ('Nickie Moulden', 'facebook', 16),
#  ('Stephanie Balfour', 'direct', 16),
#  ('Natasha Kopczynski', 'direct', 16),
#  ('Yun Kleeman', 'direct', 16),
#  ('Cammy Sosnowski', 'direct', 16),
#  ('Rhoda Holtsclaw', 'direct', 16),
#  ('Bettye Close', 'direct', 15),
#  ('Terrilyn Kesler', 'direct', 15),
#  ('Sheryl Diamond', 'facebook', 15),
#  ('Donnie Ehrhardt', 'adwords', 15),
#  ('Jodee Lupo', 'facebook', 15),
#  ('Janyce Mun', 'direct', 15),
#  ('Yasuko Heffernan', 'direct', 15),
#  ('Jodee Lupo', 'adwords', 15),
#  ('Richelle Borger', 'direct', 15),
#  ('Janise Voth', 'direct', 15),
#  ('Vania Warthen', 'direct', 15),
#  ('Melva Lyall', 'direct', 15),
#  ('Lashaun Lightfoot', 'direct', 15),
#  ('Chadwick Fortenberry', 'direct', 15),
#  ('Isreal Shreffler', 'direct', 14),
#  ('Lucile Pasek', 'direct', 14),
#  ('Domonique Cave', 'organic', 14),
#  ('Donnie Ehrhardt', 'organic', 14),
#  ('Mickey Eversole', 'direct', 14),
#  ('Jodee Lupo', 'organic', 14),
#  ('Lavonda Hoyle', 'direct', 14),
#  ('Sung Shields', 'direct', 14),
#  ('Timika Mistretta', 'adwords', 14),
#  ('Lakeisha Kridler', 'direct', 14),
#  ('Jay Gauger', 'facebook', 14),
#  ('Tamara Tuma', 'adwords', 14),
#  ('Ursula Sarinana', 'direct', 14),
#  ('Alida Desrosier', 'organic', 13),
#  ('Monserrate Winsett', 'direct', 13),
#  ('Hilde Klopfer', 'direct', 13),
#  ('Jay Gauger', 'organic', 13),
#  ('Henriette Dawes', 'direct', 13),
#  ('Maricela Humphries', 'direct', 13),
#  ('Bobbi Rackers', 'direct', 13),
#  ('Vi Skeeter', 'direct', 13),
#  ('Natacha Rita', 'facebook', 13),
#  ('Lauryn Hogge', 'direct', 13),
#  ('Emmitt Mcnab', 'facebook', 12),
#  ('Chantell Drescher', 'organic', 12),
#  ('Nigel Mincks', 'direct', 12),
#  ('Vanetta Castleman', 'direct', 12),
#  ('Sabra Bellis', 'direct', 12),
#  ('Natacha Rita', 'adwords', 12),
#  ('Timika Mistretta', 'facebook', 12),
#  ('Tamara Tuma', 'organic', 12),
#  ('Debby Myers', 'direct', 12),
#  ('Lorette Blasi', 'adwords', 12),
#  ('Keren Mcconn', 'organic', 12),
#  ('Alida Desrosier', 'adwords', 12),
#  ('Myrtice Maxon', 'direct', 12),
#  ('Nickie Moulden', 'organic', 12),
#  ('Angla Ingrassia', 'facebook', 12),
#  ('Deanne Hertlein', 'adwords', 12),
#  ('Deadra Waggener', 'organic', 12),
#  ('Latia Beene', 'direct', 11),
#  ('Alida Desrosier', 'facebook', 11),
#  ('Esta Engelhardt', 'facebook', 11),
#  ('Staci Alegria', 'direct', 11),
#  ('Nannie Brinkman', 'adwords', 11),
#  ('Esta Engelhardt', 'organic', 11),
#  ('Lurlene Wojtowicz', 'direct', 11),
#  ('Barton Hyatt', 'adwords', 11),
#  ('Sage Battiste', 'direct', 11),
#  ('Maryellen Strohmeyer', 'direct', 11),
#  ('Stewart Mcnitt', 'direct', 11),
#  ('Genesis Schroer', 'direct', 11),
#  ('Chanelle Keach', 'direct', 11),
#  ('Diedra Crossman', 'facebook', 11),
#  ('Natacha Rita', 'organic', 11),
#  ('Marita Demasi', 'organic', 11),
#  ('Domenic Mally', 'direct', 11),
#  ('Cassey Hewey', 'direct', 11),
#  ('Donnie Ehrhardt', 'facebook', 11),
#  ('Florentino Madrigal', 'organic', 11),
#  ('Barton Hyatt', 'facebook', 10),
#  ('Kyoko Randall', 'direct', 10),
#  ('Devona Denison', 'direct', 10),
#  ('Isobel Mcdaniel', 'direct', 10),
#  ('Nannie Brinkman', 'facebook', 10),
#  ('Emmitt Mcnab', 'organic', 10),
#  ('Lorette Blasi', 'facebook', 10),
#  ('Catherine Bermejo', 'facebook', 10),
#  ('Garfield Levenson', 'direct', 10),
#  ('Tyree Folden', 'direct', 10),
#  ('Noah Melugin', 'facebook', 10),
#  ('Madlyn Brothers', 'direct', 10),
#  ('Janyce Quarles', 'organic', 10),
#  ('Alexandria Zielke', 'organic', 10),
#  ('Kandi Mailloux', 'organic', 10),
#  ('Jewell Likes', 'direct', 10),
#  ('Arlyne Mauzy', 'facebook', 10),
#  ('Martin Mcgough', 'direct', 10),
#  ('Nam Rothfuss', 'facebook', 10),
#  ('Timika Mistretta', 'organic', 10),
#  ('Eloisa Lafuente', 'organic', 10),
#  ('Diedra Crossman', 'organic', 10),
#  ('Stephnie Mccrum', 'direct', 10),
#  ('Sheryl Diamond', 'adwords', 10),
#  ('Barton Hyatt', 'organic', 10),
#  ('Kandi Mailloux', 'adwords', 10),
#  ('Minna Dehner', 'direct', 9),
#  ('Janyce Quarles', 'facebook', 9),
#  ('Angla Ingrassia', 'organic', 9),
#  ('Latosha Hollar', 'direct', 9),
#  ('Nicolasa Housel', 'direct', 9),
#  ('September Jacquet', 'facebook', 9),
#  ('Lindsay Malbon', 'direct', 9),
#  ('Natacha Rita', 'twitter', 9),
#  ('Twanda Renninger', 'direct', 9),
#  ('Monet Maclaren', 'adwords', 9),
#  ('Deanne Hertlein', 'facebook', 9),
#  ('Keren Mcconn', 'banner', 9),
#  ('Chantal Laureano', 'facebook', 9),
#  ('Grazyna Dewald', 'direct', 9),
#  ('Sharie Sanborn', 'direct', 9),
#  ('Jon Esteban', 'direct', 9),
#  ('Idalia Agosta', 'organic', 9),
#  ('Tamara Tuma', 'facebook', 9),
#  ('Nannie Brinkman', 'organic', 9),
#  ('Janyce Quarles', 'adwords', 9),
#  ('Erin Viverette', 'adwords', 9),
#  ('Loren Schlanger', 'adwords', 9),
#  ('Anabel Haskell', 'direct', 9),
#  ('Antwan Seagraves', 'facebook', 9),
#  ('Mauricio Croce', 'direct', 9),
#  ('Nannie Brinkman', 'twitter', 9),
#  ('Donnie Ehrhardt', 'banner', 9),
#  ('Jeannetta Fowkes', 'direct', 9),
#  ('Eugena Jerman', 'direct', 9),
#  ('Cassey Hewey', 'facebook', 9),
#  ('Natasha Kopczynski', 'facebook', 9),
#  ('Rosena Jessop', 'direct', 9),
#  ('Diedra Crossman', 'adwords', 9),
#  ('Idalia Agosta', 'facebook', 9),
#  ('Idalia Agosta', 'twitter', 9),
#  ('Craig Mcalpine', 'facebook', 9),
#  ('Whitney Koga', 'direct', 9),
#  ('Shasta Rodas', 'organic', 9),
#  ('Shasta Rodas', 'facebook', 9),
#  ('Tisha Coletti', 'adwords', 8),
#  ('Craig Mcalpine', 'organic', 8),
#  ('Nichelle Singley', 'adwords', 8),
#  ('Birgit Lacasse', 'facebook', 8),
#  ('Emmitt Mcnab', 'banner', 8),
#  ('Erin Viverette', 'facebook', 8),
#  ('Deadra Waggener', 'facebook', 8),
#  ('Jay Gauger', 'adwords', 8),
#  ('Shasta Rodas', 'banner', 8),
#  ('Merrill Rubino', 'organic', 8),
#  ('Chas Nagler', 'organic', 8),
#  ('Marita Demasi', 'facebook', 8),
#  ('Barton Hyatt', 'banner', 8),
#  ('Theodore Staten', 'direct', 8),
#  ('Elodia Olague', 'direct', 8),
#  ('Deadra Waggener', 'adwords', 8),
#  ('Eloisa Lafuente', 'adwords', 8),
#  ('Chantal Laureano', 'adwords', 8),
#  ('September Jacquet', 'organic', 8),
#  ('Jung Soden', 'direct', 8),
#  ('Arlyne Mauzy', 'organic', 8),
#  ('Emogene Howarth', 'direct', 8),
#  ('Darren Villafana', 'direct', 8),
#  ('Savanna Gayman', 'adwords', 8),
#  ('Reagan Derouen', 'adwords', 8),
#  ('Lavonda Geier', 'direct', 8),
#  ('Esta Engelhardt', 'adwords', 8),
#  ('Willard Crenshaw', 'direct', 8),
#  ('Gail Widmer', 'organic', 8),
#  ('Sasha Haughey', 'direct', 8),
#  ('Love Quirion', 'facebook', 8),
#  ('Chantal Laureano', 'organic', 8),
#  ('Noah Melugin', 'organic', 8),
#  ('Chas Nagler', 'facebook', 8),
#  ('Kandi Mailloux', 'twitter', 8),
#  ('Leia Vargas', 'direct', 8),
#  ('Darrel Macintosh', 'direct', 8),
#  ('Brendan Anzalone', 'direct', 8),
#  ('September Jacquet', 'adwords', 8),
#  ('Yukiko Nails', 'direct', 8),
#  ('Della Arceo', 'direct', 8),
#  ('Alisa Rega', 'direct', 8),
#  ('Tamica Laborde', 'direct', 8),
#  ('Cassey Hewey', 'organic', 7),
#  ('Craig Mcalpine', 'adwords', 7),
#  ('Dagmar Pangle', 'direct', 7),
#  ('Angla Ingrassia', 'twitter', 7),
#  ('Lessie Quijada', 'direct', 7),
#  ('Maria Garibay', 'organic', 7),
#  ('Audria Witter', 'organic', 7),
#  ('Rico Rison', 'direct', 7),
#  ('Domenic Mally', 'facebook', 7),
#  ('Tegan Metzgar', 'direct', 7),
#  ('Domonique Cave', 'adwords', 7),
#  ('Chauncey Koss', 'direct', 7),
#  ('Richelle Borger', 'adwords', 7),
#  ('Rosena Jessop', 'adwords', 7),
#  ('Willodean Steinberger', 'organic', 7),
#  ('Merrill Rubino', 'facebook', 7),
#  ('Francine Sealey', 'direct', 7),
#  ('Dennise Hungate', 'direct', 7),
#  ('Hanh Oram', 'organic', 7),
#  ('Laurette Sakai', 'facebook', 7),
#  ('Eloisa Lafuente', 'facebook', 7),
#  ('Lakenya Volker', 'facebook', 7),
#  ('Nam Rothfuss', 'organic', 7),
#  ('Horacio Weidman', 'adwords', 7),
#  ('Monet Maclaren', 'facebook', 7),
#  ('Jeanne Harty', 'adwords', 7),
#  ('Alexandria Zielke', 'facebook', 7),
#  ('Savanna Gayman', 'organic', 7),
#  ('Chelsey Marasco', 'direct', 7),
#  ('Florentino Madrigal', 'facebook', 7),
#  ('Porter Shrout', 'direct', 7),
#  ('Natasha Kopczynski', 'adwords', 7),
#  ('Emmitt Mcnab', 'adwords', 7),
#  ('Jay Gauger', 'twitter', 7),
#  ('Angeles Crusoe', 'direct', 7),
#  ('Sheryl Diamond', 'organic', 7),
#  ('Lucile Pasek', 'organic', 7),
#  ('Louis Whitted', 'direct', 7),
#  ('Nickie Moulden', 'twitter', 7),
#  ('Emmitt Mcnab', 'twitter', 7),
#  ('Erin Viverette', 'organic', 7),
#  ('Jeanne Harty', 'facebook', 7),
#  ('Neomi Nishida', 'direct', 7),
#  ('Chantal Laureano', 'banner', 7),
#  ('Jon Esteban', 'facebook', 7),
#  ('Yan Crater', 'direct', 7),
#  ('Taylor Capone', 'direct', 7),
#  ('Susana Dixion', 'direct', 7),
#  ('Kellee Suniga', 'adwords', 7),
#  ('Sheryl Diamond', 'twitter', 7),
#  ('Noah Melugin', 'adwords', 7),
#  ('Lorette Blasi', 'organic', 7),
#  ('Lisa Rayborn', 'direct', 7),
#  ('Maryalice Giltner', 'adwords', 6),
#  ('Roberto Calender', 'direct', 6),
#  ('Porter Shrout', 'facebook', 6),
#  ('Chauncey Koss', 'banner', 6),
#  ('Loren Schlanger', 'organic', 6),
#  ('Jamel Mosqueda', 'adwords', 6),
#  ('Teddy Braddock', 'direct', 6),
#  ('Chantell Drescher', 'adwords', 6),
#  ('Keren Mcconn', 'facebook', 6),
#  ('Laurette Sakai', 'organic', 6),
#  ('Antwan Seagraves', 'organic', 6),
#  ('Newton Belmonte', 'organic', 6),
#  ('Lucile Pasek', 'adwords', 6),
#  ('September Jacquet', 'banner', 6),
#  ('Dagmar Pangle', 'organic', 6),
#  ('Cordia Winters', 'direct', 6),
#  ('Leana Hawker', 'facebook', 6),
#  ('Angla Ingrassia', 'adwords', 6),
#  ('Antwan Seagraves', 'adwords', 6),
#  ('Jodee Lupo', 'banner', 6),
#  ('Savanna Gayman', 'facebook', 6),
#  ('Gail Widmer', 'facebook', 6),
#  ('Racquel Andrus', 'organic', 6),
#  ('Maranda Papas', 'direct', 6),
#  ('Tamara Tuma', 'banner', 6),
#  ('Loris Manfredi', 'direct', 6),
#  ('Loren Schlanger', 'facebook', 6),
#  ('Adell Lever', 'adwords', 6),
#  ('Tuan Trainer', 'facebook', 6),
#  ('Trisha Tigner', 'organic', 6),
#  ('Adelia Weston', 'adwords', 6),
#  ('Idalia Agosta', 'adwords', 6),
#  ('Sheryl Diamond', 'banner', 6),
#  ('Olevia Taubman', 'organic', 6),
#  ('Chin Coppola', 'facebook', 6),
#  ('Denis Gros', 'adwords', 6),
#  ('Alexandria Zielke', 'direct', 6),
#  ('Pamula Hammel', 'direct', 6),
#  ('Love Quirion', 'organic', 6),
#  ('Catherine Bermejo', 'adwords', 6),
#  ('Nannette Costa', 'direct', 6),
#  ('Delora Musson', 'adwords', 6),
#  ('Spring Hedstrom', 'direct', 6),
#  ('Catherine Bermejo', 'twitter', 6),
#  ('Roselee Pardini', 'adwords', 6),
#  ('Maryalice Giltner', 'facebook', 6),
#  ('Jon Esteban', 'adwords', 6),
#  ('Claudette Katzman', 'facebook', 6),
#  ('Yun Kleeman', 'organic', 6),
#  ('Jon Esteban', 'twitter', 6),
#  ('Janett Wisecarver', 'facebook', 6),
#  ('Maurice Matsuda', 'direct', 6),
#  ('Carisa Tinajero', 'organic', 6),
#  ('Racquel Andrus', 'adwords', 6),
#  ('Isreal Shreffler', 'facebook', 6),
#  ('Paige Bartos', 'organic', 6),
#  ('Erin Viverette', 'banner', 6),
#  ('Lelah Lamothe', 'direct', 6),
#  ('Elvia Snipes', 'direct', 6),
#  ('Esta Engelhardt', 'banner', 6),
#  ('Hilde Klopfer', 'organic', 6),
#  ('Domonique Pillow', 'direct', 6),
#  ('Lorette Blasi', 'twitter', 6),
#  ('Donnie Ehrhardt', 'twitter', 6),
#  ('Eufemia Spady', 'banner', 6),
#  ('Chas Nagler', 'adwords', 6),
#  ('Kym Hagerman', 'twitter', 6),
#  ('Vanetta Lerch', 'direct', 6),
#  ('Rosena Jessop', 'banner', 6),
#  ('Myrtice Maxon', 'adwords', 5),
#  ('Cathleen Delamater', 'direct', 5),
#  ('Chantell Drescher', 'facebook', 5),
#  ('Roselee Pardini', 'organic', 5),
#  ('Jodee Lupo', 'twitter', 5),
#  ('Craig Mcalpine', 'banner', 5),
#  ('Stephnie Mccrum', 'adwords', 5),
#  ('Vanetta Lerch', 'adwords', 5),
#  ('Bettye Close', 'facebook', 5),
#  ('Lakenya Volker', 'organic', 5),
#  ('Mickey Eversole', 'organic', 5),
#  ('Fay Rogowski', 'facebook', 5),
#  ('Kandi Mailloux', 'banner', 5),
#  ('Buffy Azure', 'twitter', 5),
#  ('Rhoda Holtsclaw', 'facebook', 5),
#  ('Mallory Gosselin', 'direct', 5),
#  ('Natividad Pauli', 'facebook', 5),
#  ('Melva Lyall', 'facebook', 5),
#  ('Nickie Moulden', 'adwords', 5),
#  ('Tuan Trainer', 'direct', 5),
#  ('Rosena Jessop', 'facebook', 5),
#  ('Chin Coppola', 'banner', 5),
#  ('Merrill Rubino', 'adwords', 5),
#  ('Chas Nagler', 'banner', 5),
#  ('Tamekia Isherwood', 'direct', 5),
#  ('Grover Chamblee', 'direct', 5),
#  ('Torri Northrop', 'facebook', 5),
#  ('Shirely Cantara', 'direct', 5),
#  ('Alida Desrosier', 'twitter', 5),
#  ('Arlyne Mauzy', 'adwords', 5),
#  ('Willodean Steinberger', 'banner', 5),
#  ('Gail Widmer', 'twitter', 5),
#  ('Brendan Anzalone', 'facebook', 5),
#  ('Jodee Indelicato', 'adwords', 5),
#  ('Chantal Laureano', 'twitter', 5),
#  ('Alejandro Taunton', 'adwords', 5),
#  ('Spring Hedstrom', 'facebook', 5),
#  ('Isreal Shreffler', 'adwords', 5),
#  ('Richelle Borger', 'organic', 5),
#  ('Willodean Steinberger', 'facebook', 5),
#  ('Khadijah Riemann', 'adwords', 5),
#  ('Catrice Klingbeil', 'adwords', 5),
#  ('Idalia Agosta', 'banner', 5),
#  ('Leana Hawker', 'organic', 5),
#  ('Richelle Borger', 'facebook', 5),
#  ('Terrilyn Kesler', 'banner', 5),
#  ('Lakeisha Kridler', 'twitter', 5),
#  ('Maria Garibay', 'facebook', 5),
#  ('Isaac Demery', 'direct', 5),
#  ('Bobbi Rackers', 'organic', 5),
#  ('Sterling Tarlton', 'direct', 5),
#  ('Laurette Sakai', 'twitter', 5),
#  ('Kellee Suniga', 'twitter', 5),
#  ('Ana Blount', 'organic', 5),
#  ('Arlyne Mauzy', 'twitter', 5),
#  ('Leana Godines', 'facebook', 5),
#  ('Henriette Dawes', 'adwords', 5),
#  ('Denis Gros', 'facebook', 5),
#  ('Janyce Quarles', 'banner', 5),
#  ('Nichelle Singley', 'organic', 5),
#  ('Alexandria Zielke', 'twitter', 5),
#  ('Alexandria Zielke', 'adwords', 5),
#  ('Keturah Cuadrado', 'organic', 5),
#  ('Kym Hagerman', 'adwords', 5),
#  ('Shana Sanborn', 'direct', 5),
#  ('Vania Warthen', 'banner', 5),
#  ('Twanda Renninger', 'organic', 5),
#  ('Lacey Kight', 'adwords', 5),
#  ('Annetta Claytor', 'direct', 5),
#  ('Christoper Mcghie', 'direct', 5),
#  ('Antwan Seagraves', 'banner', 5),
#  ('Birgit Lacasse', 'organic', 5),
#  ('Florentino Madrigal', 'adwords', 5),
#  ('Deadra Waggener', 'banner', 5),
#  ('Viva Jarrells', 'adwords', 5),
#  ('Keturah Cuadrado', 'adwords', 5),
#  ('Laurette Sakai', 'adwords', 5),
#  ('Sabra Bellis', 'adwords', 5),
#  ('Diedra Crossman', 'twitter', 5),
#  ('Tegan Metzgar', 'organic', 5),
#  ('Tamara Tuma', 'twitter', 5),
#  ('Alejandro Taunton', 'organic', 5),
#  ('Catrice Klingbeil', 'banner', 5),
#  ('Cori Byerley', 'direct', 5),
#  ('Monet Maclaren', 'organic', 5),
#  ('Antwan Seagraves', 'twitter', 5),
#  ('Shasta Rodas', 'twitter', 5),
#  ('Forrest Brodeur', 'direct', 5),
#  ('Roselee Pardini', 'banner', 5),
#  ('Jodee Indelicato', 'facebook', 5),
#  ('Janett Wisecarver', 'banner', 5),
#  ('Eufemia Spady', 'direct', 5),
#  ('Dionne Hensel', 'direct', 5),
#  ('Parker Hoggan', 'banner', 5),
#  ('Mistie Martines', 'direct', 5),
#  ('Deanne Hertlein', 'organic', 5),
#  ('Porter Shrout', 'organic', 5),
#  ('Jule Alberti', 'direct', 5),
#  ('Adell Lever', 'organic', 4),
#  ('Daisey Wyss', 'organic', 4),
#  ('Gail Widmer', 'adwords', 4),
#  ('Chadwick Fortenberry', 'banner', 4),
#  ('Carisa Tinajero', 'banner', 4),
#  ('Chin Coppola', 'adwords', 4),
#  ('Faustino Henshaw', 'direct', 4),
#  ('Ladonna Kouba', 'adwords', 4),
#  ('Venessa Moreles', 'adwords', 4),
#  ('Ardelle Khoury', 'adwords', 4),
#  ('Alisa Rega', 'facebook', 4),
#  ('Leana Hawker', 'adwords', 4),
#  ('Nita Mingle', 'direct', 4),
#  ('Viva Jarrells', 'organic', 4),
#  ('Kasandra Correa', 'direct', 4),
#  ('Della Arceo', 'facebook', 4),
#  ('Mauricio Croce', 'adwords', 4),
#  ('Florentino Madrigal', 'banner', 4),
#  ('Whitney Koga', 'adwords', 4),
#  ('Vernie Pound', 'facebook', 4),
#  ('Janett Wisecarver', 'adwords', 4),
#  ('Nichelle Singley', 'twitter', 4),
#  ('Barrie Omega', 'direct', 4),
#  ('Lisabeth Aitken', 'direct', 4),
#  ('Ethan Penaloza', 'direct', 4),
#  ('Torri Northrop', 'twitter', 4),
#  ('Jay Gauger', 'banner', 4),
#  ('Marina Catoe', 'direct', 4),
#  ('Catrice Klingbeil', 'organic', 4),
#  ('Natividad Pauli', 'twitter', 4),
#  ('Grazyna Dewald', 'twitter', 4),
#  ('Elmo Burstein', 'direct', 4),
#  ('Nam Rothfuss', 'adwords', 4),
#  ('Julia Laracuente', 'facebook', 4),
#  ('Lindsay Malbon', 'organic', 4),
#  ('Grazyna Dewald', 'adwords', 4),
#  ('Lucile Pasek', 'facebook', 4),
#  ('Domonique Cave', 'facebook', 4),
#  ('Leia Vargas', 'organic', 4),
#  ('Chantell Drescher', 'banner', 4),
#  ('Henriette Dawes', 'organic', 4),
#  ('Noah Melugin', 'banner', 4),
#  ('Janyce Quarles', 'twitter', 4),
#  ('Domenic Mally', 'twitter', 4),
#  ('Devona Denison', 'facebook', 4),
#  ('Ana Blount', 'facebook', 4),
#  ('Parker Hoggan', 'organic', 4),
#  ('Savanna Gayman', 'twitter', 4),
#  ('Grazyna Dewald', 'organic', 4),
#  ('Rosena Jessop', 'twitter', 4),
#  ('Fay Rogowski', 'organic', 4),
#  ('Adelia Weston', 'organic', 4),
#  ('Viva Jarrells', 'facebook', 4),
#  ('Loren Schlanger', 'banner', 4),
#  ('Ardelle Khoury', 'organic', 4),
#  ('Maryalice Giltner', 'banner', 4),
#  ('Janyce Mun', 'organic', 4),
#  ('Karren Dively', 'direct', 4),
#  ('Serafina Banda', 'direct', 4),
#  ('Melva Lyall', 'banner', 4),
#  ('Trisha Tigner', 'facebook', 4),
#  ('Loren Schlanger', 'twitter', 4),
#  ('Caitlyn Claycomb', 'direct', 4),
#  ('Kellee Suniga', 'facebook', 4),
#  ('Maxwell Vandergriff', 'direct', 4),
#  ('Jordan Fils', 'twitter', 4),
#  ('Alida Desrosier', 'banner', 4),
#  ('Isidra Thieme', 'direct', 4),
#  ('Serafina Banda', 'facebook', 4),
#  ('Deadra Waggener', 'twitter', 4),
#  ('Yasuko Heffernan', 'facebook', 4),
#  ('Keren Mcconn', 'adwords', 4),
#  ('Tobi Whiteaker', 'direct', 4),
#  ('Kandi Mailloux', 'facebook', 4),
#  ('Ladonna Kouba', 'direct', 4),
#  ('Marita Demasi', 'banner', 4),
#  ('Antonia Parkhurst', 'direct', 4),
#  ('Lucile Pasek', 'banner', 4),
#  ('Rhoda Holtsclaw', 'adwords', 4),
#  ('Domonique Cave', 'twitter', 4),
#  ('Arlyne Mauzy', 'banner', 4),
#  ('Davida Woldt', 'organic', 4),
#  ('Garfield Levenson', 'organic', 4),
#  ('Parker Hoggan', 'adwords', 4),
#  ('Nam Rothfuss', 'banner', 4),
#  ('Wynell Lepore', 'direct', 4),
#  ('Birgit Lacasse', 'adwords', 4),
#  ('Jere Storey', 'twitter', 4),
#  ('Craig Mcalpine', 'twitter', 4),
#  ('Esta Engelhardt', 'twitter', 4),
#  ('Maryalice Giltner', 'organic', 4),
#  ('Hsiu Benedetti', 'facebook', 4),
#  ('Kym Hagerman', 'organic', 4),
#  ('Tisha Coletti', 'facebook', 4),
#  ('Kellee Suniga', 'organic', 4),
#  ('Melissa Hacker', 'direct', 4),
#  ('Stewart Mcnitt', 'facebook', 4),
#  ('Kimiko Brasfield', 'direct', 4),
#  ('Isreal Shreffler', 'organic', 4),
#  ('Cassey Hewey', 'adwords', 4),
#  ('Jung Soden', 'organic', 4),
#  ('Vernie Pound', 'adwords', 4),
#  ('Buffy Azure', 'facebook', 4),
#  ('Audria Witter', 'facebook', 4),
#  ('Tamica Laborde', 'facebook', 4),
#  ('Martin Mcgough', 'facebook', 4),
#  ('Maria Garibay', 'twitter', 4),
#  ('Lurlene Wojtowicz', 'facebook', 4),
#  ('Nichelle Singley', 'facebook', 4),
#  ('Yukiko Nails', 'adwords', 4),
#  ('Julia Laracuente', 'adwords', 4),
#  ('Hilde Klopfer', 'adwords', 4),
#  ('Kristopher Moton', 'facebook', 4),
#  ('Annalisa Butt', 'direct', 4),
#  ('Shanika Mariani', 'organic', 4),
#  ('Domonique Harvell', 'direct', 4),
#  ('Eddie Mcgaughey', 'direct', 4),
#  ('Tobi Whiteaker', 'organic', 4),
#  ('Brianne Hunger', 'facebook', 4),
#  ('Garfield Levenson', 'facebook', 3),
#  ('Staci Alegria', 'adwords', 3),
#  ('Latosha Hollar', 'adwords', 3),
#  ('Natasha Kopczynski', 'banner', 3),
#  ('Elvia Snipes', 'facebook', 3),
#  ('Isobel Mcdaniel', 'facebook', 3),
#  ('Angeles Crusoe', 'adwords', 3),
#  ('Bettye Close', 'adwords', 3),
#  ('Shanika Mariani', 'facebook', 3),
#  ('Staci Alegria', 'organic', 3),
#  ('Daisey Wyss', 'twitter', 3),
#  ('Tyree Folden', 'banner', 3),
#  ('Shanika Mariani', 'adwords', 3),
#  ('Ardelle Khoury', 'facebook', 3),
#  ('Sung Shields', 'adwords', 3),
#  ('Martin Mcgough', 'twitter', 3),
#  ('Sterling Tarlton', 'organic', 3),
#  ('Delphia Jamerson', 'direct', 3),
#  ('Isaac Demery', 'twitter', 3),
#  ('Janett Wisecarver', 'twitter', 3),
#  ('Eugena Jerman', 'facebook', 3),
#  ('Merrill Rubino', 'banner', 3),
#  ('Annetta Claytor', 'adwords', 3),
#  ('Jeannetta Fowkes', 'twitter', 3),
#  ('Elouise Beyers', 'adwords', 3),
#  ('Newton Belmonte', 'facebook', 3),
#  ('Love Quirion', 'adwords', 3),
#  ('Olevia Taubman', 'adwords', 3),
#  ('Dominique Favela', 'organic', 3),
#  ('Deanne Hertlein', 'banner', 3),
#  ('Natasha Kopczynski', 'twitter', 3),
#  ('Lea Quillen', 'facebook', 3),
#  ('Nannie Brinkman', 'banner', 3),
#  ('Jon Esteban', 'organic', 3),
#  ('Newton Belmonte', 'adwords', 3),
#  ('Claudette Katzman', 'adwords', 3),
#  ('Myrtice Maxon', 'facebook', 3),
#  ('Mireille Worthley', 'direct', 3),
#  ('Horacio Weidman', 'organic', 3),
#  ('Ursula Sarinana', 'facebook', 3),
#  ('Keturah Cuadrado', 'facebook', 3),
#  ('Tamiko Calhoon', 'direct', 3),
#  ('Jamel Mosqueda', 'banner', 3),
#  ('Racquel Andrus', 'facebook', 3),
#  ('Domonique Harvell', 'facebook', 3),
#  ('Sung Shields', 'facebook', 3),
#  ('Sterling Tarlton', 'facebook', 3),
#  ('Trisha Tigner', 'adwords', 3),
#  ('Grazyna Dewald', 'facebook', 3),
#  ('Nell Younts', 'organic', 3),
#  ('Dionne Hensel', 'organic', 3),
#  ('Chauncey Koss', 'twitter', 3),
#  ('Jamel Mosqueda', 'organic', 3),
#  ('Timika Mistretta', 'twitter', 3),
#  ('Fay Rogowski', 'adwords', 3),
#  ('Lakenya Volker', 'adwords', 3),
#  ('Jesus Philippi', 'direct', 3),
#  ('Florentino Madrigal', 'twitter', 3),
#  ('Lakeisha Kridler', 'adwords', 3),
#  ('Hsiu Benedetti', 'twitter', 3),
#  ('Natacha Rita', 'banner', 3),
#  ('Daisey Wyss', 'adwords', 3),
#  ('Janyce Mun', 'adwords', 3),
#  ('Alisa Rega', 'organic', 3),
#  ('Reagan Derouen', 'facebook', 3),
#  ('Marina Catoe', 'facebook', 3),
#  ('Gregorio Schank', 'direct', 3),
#  ('Tobi Whiteaker', 'facebook', 3),
#  ('September Jacquet', 'twitter', 3),
#  ('Kyoko Randall', 'facebook', 3),
#  ('Deanne Hertlein', 'twitter', 3),
#  ('Jamel Mosqueda', 'facebook', 3),
#  ('Lacey Kight', 'organic', 3),
#  ('Melody Neuner', 'organic', 3),
#  ('Marita Demasi', 'twitter', 3),
#  ('Sabra Bellis', 'organic', 3),
#  ('Teresita Ashalintubbi', 'facebook', 3),
#  ('Devona Denison', 'organic', 3),
#  ('Viva Jarrells', 'banner', 3),
#  ('Rema Skipworth', 'facebook', 3),
#  ('Shasta Rodas', 'adwords', 3),
#  ('Caprice Hohler', 'direct', 3),
#  ('Catherine Bermejo', 'banner', 3),
#  ('Birgit Lacasse', 'banner', 3),
#  ('Maranda Papas', 'adwords', 3),
#  ('Domenic Mally', 'organic', 3),
#  ('Chauncey Koss', 'adwords', 3),
#  ('Laurette Sakai', 'banner', 3),
#  ('Loris Manfredi', 'adwords', 3),
#  ('Daisey Wyss', 'facebook', 3),
#  ('Natividad Pauli', 'organic', 3),
#  ('Whitney Koga', 'facebook', 3),
#  ('Willodean Steinberger', 'twitter', 3),
#  ('Anabel Haskell', 'organic', 3),
#  ('Devona Denison', 'adwords', 3),
#  ('Jodee Indelicato', 'banner', 3),
#  ('Chin Coppola', 'twitter', 3),
#  ('Barton Hyatt', 'twitter', 3),
#  ('Scot Feagin', 'organic', 3),
#  ('Cammy Sosnowski', 'organic', 3),
#  ('Natasha Kopczynski', 'organic', 3),
#  ('Natividad Pauli', 'adwords', 3),
#  ('Olevia Taubman', 'facebook', 3),
#  ('Glennis Vann', 'direct', 3),
#  ('Janett Wisecarver', 'organic', 3),
#  ('Dee Daulton', 'adwords', 3),
#  ('Angla Ingrassia', 'banner', 3),
#  ('Tangela Vahle', 'direct', 3),
#  ('Leana Godines', 'organic', 3),
#  ('Yun Kleeman', 'facebook', 3),
#  ('Nam Rothfuss', 'twitter', 3),
#  ('Monet Maclaren', 'banner', 3),
#  ('Latosha Hollar', 'twitter', 3),
#  ('Domonique Cave', 'banner', 3),
#  ('Jere Storey', 'adwords', 3),
#  ('Nell Younts', 'facebook', 3),
#  ('Nita Mingle', 'organic', 3),
#  ('Jon Esteban', 'banner', 3),
#  ('Lavonda Hoyle', 'adwords', 3),
#  ('Genesis Schroer', 'adwords', 3),
#  ('Buffy Azure', 'adwords', 3),
#  ('Stephnie Mccrum', 'banner', 3),
#  ('Cammy Sosnowski', 'banner', 3),
#  ('Genevieve Fenton', 'direct', 3),
#  ('Shirely Cantara', 'organic', 3),
#  ('Sabra Bellis', 'twitter', 3),
#  ('Jeannetta Fowkes', 'adwords', 3),
#  ('Teresita Ashalintubbi', 'direct', 3),
#  ('Georgiana Coniglio', 'direct', 3),
#  ('Genesis Schroer', 'organic', 3),
#  ('Leana Hawker', 'banner', 3),
#  ('Venessa Moreles', 'banner', 3),
#  ('Genesis Schroer', 'facebook', 3),
#  ('Cammy Sosnowski', 'facebook', 3),
#  ('Vanetta Castleman', 'banner', 3),
#  ('Vania Warthen', 'organic', 3),
#  ('Lavonda Hoyle', 'facebook', 3),
#  ('Audria Witter', 'adwords', 3),
#  ('Julia Laracuente', 'banner', 3),
#  ('Elodia Olague', 'twitter', 3),
#  ('Lauryn Hogge', 'adwords', 3),
#  ('Tisha Coletti', 'banner', 3),
#  ('Shantae Leone', 'direct', 3),
#  ('Brianne Hunger', 'adwords', 3),
#  ('Chad Winer', 'direct', 3),
#  ('Kellee Suniga', 'banner', 3),
#  ('Della Arceo', 'organic', 3),
#  ('Kristopher Moton', 'organic', 3),
#  ('Jeanne Harty', 'twitter', 3),
#  ('Trisha Tigner', 'twitter', 3),
#  ('Elouise Beyers', 'organic', 3),
#  ('Tuan Trainer', 'organic', 3),
#  ('Leia Vargas', 'adwords', 3),
#  ('Audria Witter', 'direct', 3),
#  ('Vania Warthen', 'adwords', 3),
#  ('Tuan Trainer', 'twitter', 3),
#  ('Myrtice Maxon', 'organic', 3),
#  ('Tegan Metzgar', 'twitter', 3),
#  ('Yan Crater', 'facebook', 3),
#  ('Catrice Klingbeil', 'twitter', 3),
#  ('Erin Viverette', 'twitter', 3),
#  ('Chin Coppola', 'organic', 3),
#  ('Sheilah Truss', 'banner', 3),
#  ('Shana Sanborn', 'facebook', 3),
#  ('Nell Younts', 'direct', 3),
#  ('Mallory Gosselin', 'facebook', 3),
#  ('Adell Lever', 'facebook', 3),
#  ('Maryellen Strohmeyer', 'organic', 3),
#  ('Maria Garibay', 'adwords', 3),
#  ('Venessa Moreles', 'organic', 3),
#  ('Khadijah Riemann', 'organic', 3),
#  ('Lea Quillen', 'direct', 3),
#  ('Eloisa Lafuente', 'twitter', 3),
#  ('Leana Godines', 'twitter', 3),
#  ('Scot Feagin', 'facebook', 3),
#  ('Hanh Oram', 'twitter', 3),
#  ('Adell Lever', 'banner', 3),
#  ('Chanelle Keach', 'facebook', 2),
#  ('Adam Ptacek', 'direct', 2),
#  ('Noah Melugin', 'twitter', 2),
#  ('Nickie Moulden', 'banner', 2),
#  ('Alejandro Taunton', 'twitter', 2),
#  ('Stephnie Mccrum', 'organic', 2),
#  ('Stephanie Balfour', 'adwords', 2),
#  ('Timika Mistretta', 'banner', 2),
#  ('Tisha Coletti', 'organic', 2),
#  ('Chanelle Keach', 'adwords', 2),
#  ('Vanetta Castleman', 'facebook', 2),
#  ('Sherell Yankey', 'direct', 2),
#  ('Sharie Sanborn', 'organic', 2),
#  ('Chadwick Fortenberry', 'facebook', 2),
#  ('Venessa Moreles', 'facebook', 2),
#  ('Taylor Capone', 'banner', 2),
#  ('Maranda Papas', 'organic', 2),
#  ('Rosena Jessop', 'organic', 2),
#  ('Bernadine Stahly', 'adwords', 2),
#  ('Maxwell Vandergriff', 'organic', 2),
#  ('Natividad Pauli', 'banner', 2),
#  ('Julia Laracuente', 'organic', 2),
#  ('Chauncey Koss', 'organic', 2),
#  ('Melody Neuner', 'facebook', 2),
#  ('Shana Sanborn', 'organic', 2),
#  ('Haley Klos', 'direct', 2),
#  ('Lakenya Volker', 'banner', 2),
#  ('Sung Shields', 'organic', 2),
#  ('Elvia Snipes', 'organic', 2),
#  ('Lavonda Geier', 'adwords', 2),
#  ('Twanda Renninger', 'facebook', 2),
#  ('Lisabeth Aitken', 'twitter', 2),
#  ('Delphia Jamerson', 'adwords', 2),
#  ('Chauncey Koss', 'facebook', 2),
#  ('Julia Laracuente', 'twitter', 2),
#  ('Latesha Garcia', 'adwords', 2),
#  ('Enola Thoms', 'direct', 2),
#  ('Taylor Capone', 'adwords', 2),
#  ('Darrel Macintosh', 'organic', 2),
#  ('Jeanne Harty', 'organic', 2),
#  ('Cori Byerley', 'organic', 2),
#  ('Cordia Winters', 'twitter', 2),
#  ('Dennise Hungate', 'organic', 2),
#  ('Davida Woldt', 'banner', 2),
#  ('Tangela Vahle', 'banner', 2),
#  ('Reagan Derouen', 'organic', 2),
#  ('Theodore Staten', 'banner', 2),
#  ('Vi Skeeter', 'adwords', 2),
#  ('Enola Thoms', 'facebook', 2),
#  ('Buffy Azure', 'organic', 2),
#  ('Susana Dixion', 'adwords', 2),
#  ('Ana Blount', 'banner', 2),
#  ('Sage Battiste', 'adwords', 2),
#  ('Dagmar Pangle', 'facebook', 2),
#  ('Sage Battiste', 'facebook', 2),
#  ('Tisha Coletti', 'twitter', 2),
#  ('Martin Mcgough', 'banner', 2),
#  ('Stewart Mcnitt', 'banner', 2),
#  ('Neomi Nishida', 'banner', 2),
#  ('Jung Soden', 'banner', 2),
#  ('Hilde Klopfer', 'facebook', 2),
#  ('Daisey Wyss', 'banner', 2),
#  ('Wynell Lepore', 'adwords', 2),
#  ('Kayleen Orlowski', 'organic', 2),
#  ('Adell Lever', 'twitter', 2),
#  ('Grover Chamblee', 'twitter', 2),
#  ('Agnus Jenkin', 'direct', 2),
#  ('Sheilah Truss', 'facebook', 2),
#  ('Horacio Weidman', 'facebook', 2),
#  ('Cordia Winters', 'adwords', 2),
#  ('Gail Widmer', 'banner', 2),
#  ('Claudette Katzman', 'twitter', 2),
#  ('Deeanna Burpo', 'direct', 2),
#  ('Terrilyn Kesler', 'facebook', 2),
#  ('Roselee Pardini', 'facebook', 2),
#  ('Hanh Oram', 'banner', 2),
#  ('Kristopher Moton', 'twitter', 2),
#  ('Madlyn Brothers', 'organic', 2),
#  ('Jamel Mosqueda', 'twitter', 2),
#  ('Tegan Metzgar', 'facebook', 2),
#  ('Elayne Grunewald', 'facebook', 2),
#  ('Kip Stringham', 'adwords', 2),
#  ('Stephnie Mccrum', 'facebook', 2),
#  ('Hubert Blanch', 'banner', 2),
#  ('Jung Soden', 'adwords', 2),
#  ('Staci Alegria', 'twitter', 2),
#  ('Della Arceo', 'adwords', 2),
#  ('Keena Caffrey', 'direct', 2),
#  ('Gregorio Schank', 'organic', 2),
#  ('Denis Gros', 'twitter', 2),
#  ('Darrel Macintosh', 'adwords', 2),
#  ('Martin Mcgough', 'adwords', 2),
#  ('Kasandra Correa', 'facebook', 2),
#  ('Kasandra Correa', 'banner', 2),
#  ('Hsiu Benedetti', 'adwords', 2),
#  ('Garfield Levenson', 'twitter', 2),
#  ('Marivel Keeley', 'direct', 2),
#  ('Elouise Beyers', 'twitter', 2),
#  ('Ethan Penaloza', 'adwords', 2),
#  ('Neomi Nishida', 'adwords', 2),
#  ('Tyree Folden', 'adwords', 2),
#  ('Lurlene Wojtowicz', 'organic', 2),
#  ('Newton Belmonte', 'banner', 2),
#  ('Birgit Lacasse', 'twitter', 2),
#  ('Ericka Hamid', 'direct', 2),
#  ('Madlyn Brothers', 'adwords', 2),
#  ('Leia Vargas', 'twitter', 2),
#  ('Diedra Crossman', 'banner', 2),
#  ('Lakeisha Kridler', 'facebook', 2),
#  ('Kyoko Randall', 'organic', 2),
#  ('Latesha Garcia', 'banner', 2),
#  ('Leia Vargas', 'banner', 2),
#  ('Juliet Nugent', 'twitter', 2),
#  ('Adelia Weston', 'twitter', 2),
#  ('Kayleen Orlowski', 'adwords', 2),
#  ('Willard Crenshaw', 'twitter', 2),
#  ('Aura Walz', 'direct', 2),
#  ('Maybell Bascombe', 'direct', 2),
#  ('Buffy Azure', 'banner', 2),
#  ('Yukiko Nails', 'twitter', 2),
#  ('Adelia Weston', 'banner', 2),
#  ('Celsa Hamsher', 'direct', 2),
#  ('Maryellen Strohmeyer', 'banner', 2),
#  ('Janyce Mun', 'facebook', 2),
#  ('Jenny Poland', 'facebook', 2),
#  ('Lucile Pasek', 'twitter', 2),
#  ('Lavonda Hoyle', 'organic', 2),
#  ('Yun Kleeman', 'adwords', 2),
#  ('Jodee Indelicato', 'organic', 2),
#  ('Dagmar Pangle', 'adwords', 2),
#  ('Reagan Derouen', 'banner', 2),
#  ('Brendan Anzalone', 'adwords', 2),
#  ('Josh Deslauriers', 'organic', 2),
#  ('Whitney Koga', 'organic', 2),
#  ('Adelia Weston', 'facebook', 2),
#  ('Bernadine Stahly', 'banner', 2),
#  ('Reagan Derouen', 'twitter', 2),
#  ('Elayne Grunewald', 'adwords', 2),
#  ('Jodee Indelicato', 'twitter', 2),
#  ('Georgiana Coniglio', 'organic', 2),
#  ('Tamica Laborde', 'organic', 2),
#  ('Anabel Haskell', 'adwords', 2),
#  ('Racquel Andrus', 'banner', 2),
#  ('Elmo Burstein', 'adwords', 2),
#  ('Enola Thoms', 'organic', 2),
#  ('Bettye Close', 'organic', 2),
#  ('Yukiko Nails', 'organic', 2),
#  ('Jung Soden', 'facebook', 2),
#  ('Emogene Howarth', 'organic', 2),
#  ('Henriette Dawes', 'facebook', 2),
#  ('Maryellen Strohmeyer', 'twitter', 2),
#  ('Delora Musson', 'twitter', 2),
#  ('Mallory Gosselin', 'twitter', 2),
#  ('Brendan Anzalone', 'twitter', 2),
#  ('Paige Bartos', 'facebook', 2),
#  ('Taylor Capone', 'facebook', 2),
#  ('Bobbi Rackers', 'twitter', 2),
#  ('Ursula Sarinana', 'adwords', 2),
#  ('Eufemia Spady', 'organic', 2),
#  ('Maryellen Strohmeyer', 'facebook', 2),
#  ('Kayleen Orlowski', 'facebook', 2),
#  ('Monet Maclaren', 'twitter', 2),
#  ('Glennis Vann', 'adwords', 2),
#  ('Lashaun Lightfoot', 'banner', 2),
#  ('Tegan Metzgar', 'banner', 2),
#  ('Carisa Tinajero', 'adwords', 2),
#  ('Tyree Folden', 'facebook', 2),
#  ('Annetta Claytor', 'organic', 2),
#  ('Tobi Whiteaker', 'adwords', 2),
#  ('Audria Witter', 'twitter', 2),
#  ('Loris Manfredi', 'organic', 2),
#  ('Ivory Crockett', 'direct', 2),
#  ('Maryalice Giltner', 'twitter', 2),
#  ...]

# %% [markdown]
# #### 21. Determine the number of times a particular channel was used in the web_events table for each region. Your final table should have three columns - the region name, the channel, and the number of occurrences. Order your table with the highest number of occurrences first.

# %%
# %%sql
# SELECT
#     region_id,
#     channel,
#     COUNT(order_id) AS order_count
# FROM (
# SELECT
#     w.id AS order_id,
#     w.account_id AS company_id,
#     channel,
#     a.name AS company,
#     sr.region_id AS region_id
# FROM web_events AS w
# JOIN accounts AS a
# ON a.id = w.account_id
# JOIN sales_reps AS sr
# ON sr.id = a.sales_rep_id
# ) AS web_sales_rep
# GROUP BY region_id, channel
# ORDER BY order_count DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 24 rows affected.
# [(1, 'direct', 1800),
#  (3, 'direct', 1548),
#  (4, 'direct', 1254),
#  (2, 'direct', 696),
#  (1, 'facebook', 335),
#  (1, 'organic', 317),
#  (1, 'adwords', 300),
#  (3, 'facebook', 278),
#  (3, 'organic', 275),
#  (3, 'adwords', 264),
#  (4, 'organic', 243),
#  (4, 'adwords', 241),
#  (4, 'facebook', 229),
#  (1, 'banner', 155),
#  (1, 'twitter', 154),
#  (3, 'banner', 146),
#  (3, 'twitter', 127),
#  (2, 'facebook', 125),
#  (4, 'twitter', 122),
#  (2, 'organic', 117),
#  (4, 'banner', 116),
#  (2, 'adwords', 101),
#  (2, 'twitter', 71),
#  (2, 'banner', 59)]
