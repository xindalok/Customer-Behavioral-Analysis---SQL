# %% [markdown]
# #### (Part 1)
#
# ### SUM Questions:
# 1. Find the total amount of poster_qty paper ordered in the orders table.
# 2. Find the total amount of standard_qty paper ordered in the orders table.
# 3. Find the total dollar amount of sales using the total_amt_usd in the orders table.
# 4. Find the total amount spent on standard_amt_usd and gloss_amt_usd paper for each order in the orders table. This should give a dollar amount for each order in the table.
# 5. Find the unit cost of each paper.
#
# ### MIN, MAX, & AVG Questions:
# 6. When was the earliest order ever placed?
# 7. Try performing the same query as in question 6 without using an aggregation function.
# 8. When did the most recent (latest) web_event occur?
# 9. Try to perform the result of the previous query without using an aggregation function.
# 10. Find the mean (AVERAGE) amount spent per order on each paper type, as well as the mean amount of each paper type purchased per order. Your final answer should have 6 values - one for each paper type for the average number of sales, as well as the average amount.
#
# ____________
#
# #### (Part 2)
#
# ### GROUP BY Questions:
# 11. Which account (by name) placed the earliest order? Include the account name and the date of the order.
# 12. Find the total sales in USD for each account. You should include two columns - the total sales for each company's orders in USD and the company name.
# 13. Via what channel did the most recent (latest) web_event occur, which account was associated with this web_event? Your query should return only three values - the date, channel, and account name.
# 14. Find the total number of times each type of channel from the web_events was used. Your final table should have two columns - the channel and the number of times the channel was used.
# 15. Who was the primary contact associated with the earliest web_event?
# 16. What was the smallest order placed by each account in terms of total USD? Provide only two columns - the account name and the total USD. Order from smallest dollar amounts to largest.
# 17. Find the number of sales reps in each region. Your final table should have two columns - the region and the number of sales reps. Order from fewest reps to most reps.
# 18. For each account, determine the average amount of each type of paper they purchased across their orders. Your result should have four columns - one for the account name and one for the average quantity purchased for each of the paper types for each account.
# 19. For each account, determine the average amount spent per order on each paper type. Your result should have four columns - one for the account name and one for the average amount spent on each paper type.
# 20. Determine the number of times a particular channel was used in the web_events table for each sales rep. Your final table should have three columns - the name of the sales rep, the channel, and the number of occurrences. Order your table with the highest number of occurrences first.
# 21. Determine the number of times a particular channel was used in the web_events table for each region. Your final table should have three columns - the region name, the channel, and the number of occurrences. Order your table with the highest number of occurrences first.
#
# _______
#
# #### (Part 3)
#
# ### DISTINCT Questions:
# 22. Are any accounts associated with more than one region?
# 23. Have any sales reps worked on more than one account?
#
# ### HAVING Questions:
# 24. How many of the sales reps have more than 5 accounts that they manage?
# 25. How many accounts have more than 20 orders?
# 26. Which account has the most orders?
# 27. How many accounts spent more than 30,000 USD total across all orders?
# 28. Which accounts spent less than 1,000 USD total across all orders?
# 29. Which account has spent the most with us?
# 30. Which account has spent the least with us?
# 31. Which accounts used Facebook as a channel to contact customers more than 6 times?
# 32. Which account used Facebook most as a channel?
# 33. Which channel was most frequently used by most accounts?
#
#
# _______
#
# #### (Part 4)
#
# ### DATE Function Questions:
# 34. Find the sales in terms of total dollars for all orders in each year, ordered from greatest to least.
# 35. Which month did Parch & Posey have the greatest sales in terms of total dollars? Are all months evenly represented by the dataset?
# 36. Which year did Parch & Posey have the greatest sales in terms of total number of orders? Are all years evenly represented by the dataset?
# 37. Which month did Parch & Posey have the greatest sales in terms of total number of orders? Are all months evenly represented by the dataset?
# 38. In which month of which year did Walmart spend the most on gloss paper in terms of dollars?
#
# ### CASE Questions:
# 39. Write a query to display for each order, the account ID, total amount of the order, and the level of the order - ‘Large’ or ‘Small’ - depending on if the order is 3000 USD or more, or smaller than 3000 USD.
# 40. Write a query to display the number of orders in each of three categories, based on the total number of items in each order. The three categories are: 'At Least 2000', 'Between 1000 and 2000' and 'Less than 1000'.
# 41. We would like to understand 3 different levels of customers based on the amount associated with their purchases. The top level includes anyone with a Lifetime Value (total sales of all orders) greater than 200,000 USD. The second level is between 200,000 and 100,000 USD. The lowest level is anyone under 100,000 USD. Provide a table that includes the level associated with each account. You should provide the account name, the total sales of all orders for the customer, and the level. Order with the top spending customers listed first.
# 42. We would now like to perform a similar calculation to the first, but we want to obtain the total amount spent by customers only in 2016 and 2017. Keep the same levels as in the previous question. Order with the top spending customers listed first.
#
# #### (Part 5)
#
# ### SQL Window Functions and Aggregations Questions
#
# 43. Create a running total of `standard_amt_usd` in the `orders` table over order time with no date truncation. The final table should have two columns: one with the amount being added for each new row and a second with the running total.
#
# 44. Modify the previous query to partition by the year-truncated `occurred_at` date. The final table should include three columns: the amount being added, the truncated date, and the running total within each year.
#
# 45. Rank the total amount of paper ordered (`total`) for each account (`account_id`) in the `orders` table using the `RANK()` function. The final table should include `id`, `account_id`, `total`, and `total_rank`.
#
# 46. Evaluate the impact of removing `ORDER BY DATE_TRUNC('month', occurred_at)` in a query that calculates rank, sum, count, average, minimum, and maximum of `standard_qty` per account. Compare the results before and after the modification.
#
# 47. Create and use an alias named `account_year_window` to simplify a query containing multiple window functions that partition by `account_id` and order by the truncated year of `occurred_at`.
#
# 48. Compare each order’s total revenue (`total_amt_usd`) with the next order’s total revenue using the `LEAD()` function. The final table should include `occurred_at`, `total_amt_usd`, `lead`, and `lead_difference`.
#
# 49. Use the `NTILE(4)` function to divide the accounts into four quartiles based on the amount of `standard_qty` for their orders. The final table should include `account_id`, `occurred_at`, `standard_qty`, and `standard_quartile`.
#
# 50. Use the `NTILE(2)` function to divide the accounts into two levels based on the amount of `gloss_qty` for their orders. The final table should include `account_id`, `occurred_at`, `gloss_qty`, and `gloss_half`.
#
# 51. Use the `NTILE(100)` function to divide the orders for each account into 100 percentile levels based on `total_amt_usd`. The final table should include `account_id`, `occurred_at`, `total_amt_usd`, and `total_percentile`.
#
# 52. determine how the current order's total revenue ("total" meaning from sales of all types of paper) compares to the next order's total revenue. (There should be four columns: occurred_at, total_amt_usd, lead, and lead_difference.)

# %%
# !pip install ipython-sql
# Out:
# Requirement already satisfied: ipython-sql in /opt/anaconda3/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (3.14.0)
# Requirement already satisfied: ipython in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (8.20.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (2.0.38)
# Requirement already satisfied: sqlparse in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /opt/anaconda3/lib/python3.11/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)

# %%
# %load_ext sql

# %%
# %sql postgresql://postgres:Champions12!@localhost:5432/postgres

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %% [markdown]
# #### 34. Find the sales in terms of total dollars for all orders in each year, ordered from greatest to least.

# %%
# %%sql
# SELECT
#     order_year,
#     SUM(total_amt_usd) AS total_spend
# FROM (
# SELECT
#     *,
#     EXTRACT(YEAR FROM occurred_at) AS order_year
# FROM orders_consolidated
# ) AS orders_year
# GROUP BY order_year
# ORDER BY total_spend DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 5 rows affected.
# [(Decimal('2016'), Decimal('12864917.92')),
#  (Decimal('2015'), Decimal('5752004.94')),
#  (Decimal('2014'), Decimal('4069106.54')),
#  (Decimal('2013'), Decimal('377331.00')),
#  (Decimal('2017'), Decimal('78151.43'))]

# %% [markdown]
# #### 35. Which month did Parch & Posey have the greatest sales in terms of total dollars? Are all months evenly represented by the dataset?

# %%
# %%sql
# SELECT
#     TO_CHAR(occurred_at, 'Mon') AS order_month,
#     SUM(total_amt_usd) AS total_month_spend
# FROM orders_consolidated
# GROUP BY order_month
# ORDER BY total_month_spend DESC
# LIMIT 1;
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [('Dec', Decimal('3129411.98'))]

# %% [markdown]
# #### 36. Which year did Parch & Posey have the greatest sales in terms of total number of orders? Are all years evenly represented by the dataset?

# %%
# %%sql
# SELECT
#     EXTRACT(YEAR from occurred_at) AS order_year,
#     COUNT(id) AS num_orders
# FROM orders_consolidated
# GROUP BY EXTRACT(YEAR from occurred_at)
# ORDER BY num_orders DESC
# LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(Decimal('2016'), 3757)]

# %% [markdown]
# #### 37. Which month did Parch & Posey have the greatest sales in terms of total number of orders? Are all months evenly represented by the dataset?

# %%
# %%sql
# SELECT
#     TO_CHAR(occurred_at, 'Mon') AS order_month,
#     COUNT(id) AS num_orders
# FROM orders_consolidated
# GROUP BY TO_CHAR(occurred_at, 'Mon')
# ORDER BY num_orders DESC
# LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [('Dec', 882)]

# %% [markdown]
# #### 38. In which month of which year did Walmart spend the most on gloss paper in terms of dollars?

# %%
# %%sql
# WITH walmart_cte AS (
# SELECT
#     *
# FROM orders_consolidated
# WHERE company = 'Walmart'
#
# )
# SELECT
#     EXTRACT(YEAR FROM occurred_at) AS order_year,
#     TO_CHAR(occurred_at, 'Mon') AS order_month,
#     SUM(gloss_amt_usd) AS gloss_total_spend
# FROM walmart_cte
# GROUP BY order_year, order_month
# ORDER BY gloss_total_spend DESC
# LIMIT 1
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 1 rows affected.
# [(Decimal('2016'), 'May', Decimal('9257.64'))]

# %% [markdown]
# #### 39. Write a query to display for each order, the account ID, total amount of the order, and the level of the order - ‘Large’ or ‘Small’ - depending on if the order is 3000 USD or more, or smaller than 3000 USD.

# %%
# %%sql
# SELECT
#     account_id,
#     total_amt_usd,
#     CASE
#         WHEN total_amt_usd > 3000 THEN 'Large'
#         ELSE 'Small' END
# FROM orders_consolidated
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 6912 rows affected.
# [(1001, Decimal('973.43'), 'Small'),
#  (1001, Decimal('1718.03'), 'Small'),
#  (1001, Decimal('776.18'), 'Small'),
#  (1001, Decimal('958.24'), 'Small'),
#  (1001, Decimal('983.49'), 'Small'),
#  (1001, Decimal('1067.25'), 'Small'),
#  (1001, Decimal('1498.20'), 'Small'),
#  (1001, Decimal('2052.20'), 'Small'),
#  (1001, Decimal('752.57'), 'Small'),
#  (1001, Decimal('878.56'), 'Small'),
#  (1001, Decimal('773.63'), 'Small'),
#  (1001, Decimal('1182.61'), 'Small'),
#  (1001, Decimal('951.14'), 'Small'),
#  (1001, Decimal('1993.58'), 'Small'),
#  (1001, Decimal('1283.12'), 'Small'),
#  (1001, Decimal('1719.28'), 'Small'),
#  (1011, Decimal('2734.59'), 'Small'),
#  (1021, Decimal('2747.11'), 'Small'),
#  (1021, Decimal('2936.92'), 'Small'),
#  (1021, Decimal('2580.69'), 'Small'),
#  (1021, Decimal('2945.73'), 'Small'),
#  (1021, Decimal('2608.02'), 'Small'),
#  (1021, Decimal('2944.24'), 'Small'),
#  (1031, Decimal('7474.32'), 'Large'),
#  (1041, Decimal('2257.02'), 'Small'),
#  (1041, Decimal('1696.71'), 'Small'),
#  (1041, Decimal('1208.61'), 'Small'),
#  (1051, Decimal('3149.11'), 'Large'),
#  (1051, Decimal('2820.25'), 'Small'),
#  (1051, Decimal('2433.26'), 'Small'),
#  (1051, Decimal('3206.02'), 'Large'),
#  (1051, Decimal('2579.92'), 'Small'),
#  (1051, Decimal('2485.66'), 'Small'),
#  (1061, Decimal('2023.34'), 'Small'),
#  (1061, Decimal('1403.02'), 'Small'),
#  (1061, Decimal('1758.04'), 'Small'),
#  (1071, Decimal('4393.44'), 'Large'),
#  (1081, Decimal('2055.82'), 'Small'),
#  (1081, Decimal('1744.91'), 'Small'),
#  (1081, Decimal('1771.10'), 'Small'),
#  (1081, Decimal('1741.25'), 'Small'),
#  (1081, Decimal('2225.17'), 'Small'),
#  (1081, Decimal('2888.25'), 'Small'),
#  (1081, Decimal('1734.87'), 'Small'),
#  (1081, Decimal('1849.17'), 'Small'),
#  (1081, Decimal('2016.33'), 'Small'),
#  (1081, Decimal('1840.92'), 'Small'),
#  (1081, Decimal('3405.62'), 'Large'),
#  (1081, Decimal('1884.76'), 'Small'),
#  (1081, Decimal('1898.62'), 'Small'),
#  (1081, Decimal('2816.53'), 'Small'),
#  (1081, Decimal('2152.01'), 'Small'),
#  (1081, Decimal('1994.49'), 'Small'),
#  (1081, Decimal('2065.72'), 'Small'),
#  (1081, Decimal('1788.13'), 'Small'),
#  (1081, Decimal('2748.98'), 'Small'),
#  (1081, Decimal('1721.69'), 'Small'),
#  (1081, Decimal('2016.31'), 'Small'),
#  (1081, Decimal('1679.28'), 'Small'),
#  (1091, Decimal('902.78'), 'Small'),
#  (1091, Decimal('1088.14'), 'Small'),
#  (1091, Decimal('2220.94'), 'Small'),
#  (1091, Decimal('941.48'), 'Small'),
#  (1091, Decimal('1595.20'), 'Small'),
#  (1091, Decimal('1597.91'), 'Small'),
#  (1091, Decimal('844.74'), 'Small'),
#  (1091, Decimal('474.05'), 'Small'),
#  (1091, Decimal('837.82'), 'Small'),
#  (1091, Decimal('796.63'), 'Small'),
#  (1091, Decimal('646.23'), 'Small'),
#  (1091, Decimal('1061.33'), 'Small'),
#  (1091, Decimal('1000.62'), 'Small'),
#  (1091, Decimal('738.61'), 'Small'),
#  (1091, Decimal('905.75'), 'Small'),
#  (1091, Decimal('931.50'), 'Small'),
#  (1091, Decimal('1323.75'), 'Small'),
#  (1091, Decimal('910.29'), 'Small'),
#  (1091, Decimal('761.97'), 'Small'),
#  (1091, Decimal('845.35'), 'Small'),
#  (1091, Decimal('867.76'), 'Small'),
#  (1091, Decimal('803.43'), 'Small'),
#  (1091, Decimal('1144.52'), 'Small'),
#  (1091, Decimal('822.23'), 'Small'),
#  (1091, Decimal('980.08'), 'Small'),
#  (1091, Decimal('803.44'), 'Small'),
#  (1091, Decimal('1323.04'), 'Small'),
#  (1091, Decimal('869.03'), 'Small'),
#  (1101, Decimal('3585.33'), 'Large'),
#  (1101, Decimal('1177.33'), 'Small'),
#  (1101, Decimal('693.61'), 'Small'),
#  (1101, Decimal('876.56'), 'Small'),
#  (1101, Decimal('1086.98'), 'Small'),
#  (1101, Decimal('1194.14'), 'Small'),
#  (1101, Decimal('874.62'), 'Small'),
#  (1101, Decimal('862.05'), 'Small'),
#  (1101, Decimal('259.70'), 'Small'),
#  (1101, Decimal('918.24'), 'Small'),
#  (1101, Decimal('1111.85'), 'Small'),
#  (1101, Decimal('845.94'), 'Small'),
#  (1111, Decimal('2265.48'), 'Small'),
#  (1111, Decimal('2048.60'), 'Small'),
#  (1121, Decimal('1798.56'), 'Small'),
#  (1121, Decimal('1966.38'), 'Small'),
#  (1121, Decimal('2245.54'), 'Small'),
#  (1121, Decimal('1972.57'), 'Small'),
#  (1121, Decimal('1582.01'), 'Small'),
#  (1121, Decimal('1461.26'), 'Small'),
#  (1121, Decimal('1833.52'), 'Small'),
#  (1121, Decimal('1661.80'), 'Small'),
#  (1121, Decimal('1657.54'), 'Small'),
#  (1121, Decimal('2027.68'), 'Small'),
#  (1121, Decimal('1714.93'), 'Small'),
#  (1121, Decimal('1611.84'), 'Small'),
#  (1121, Decimal('1664.26'), 'Small'),
#  (1121, Decimal('2816.63'), 'Small'),
#  (1121, Decimal('2020.97'), 'Small'),
#  (1121, Decimal('1959.49'), 'Small'),
#  (1131, Decimal('2200.99'), 'Small'),
#  (1131, Decimal('411.46'), 'Small'),
#  (1131, Decimal('1895.36'), 'Small'),
#  (1131, Decimal('2365.93'), 'Small'),
#  (1131, Decimal('1704.19'), 'Small'),
#  (1131, Decimal('1990.29'), 'Small'),
#  (1131, Decimal('0.00'), 'Small'),
#  (1131, Decimal('1721.69'), 'Small'),
#  (1141, Decimal('963.07'), 'Small'),
#  (1141, Decimal('1144.34'), 'Small'),
#  (1141, Decimal('805.34'), 'Small'),
#  (1141, Decimal('26055.46'), 'Large'),
#  (1151, Decimal('2964.69'), 'Small'),
#  (1161, Decimal('2194.05'), 'Small'),
#  (1161, Decimal('2724.68'), 'Small'),
#  (1161, Decimal('2747.18'), 'Small'),
#  (1161, Decimal('3400.18'), 'Large'),
#  (1161, Decimal('2655.45'), 'Small'),
#  (1161, Decimal('2697.41'), 'Small'),
#  (1161, Decimal('2519.64'), 'Small'),
#  (1161, Decimal('2356.19'), 'Small'),
#  (1161, Decimal('2552.42'), 'Small'),
#  (1161, Decimal('2380.49'), 'Small'),
#  (1161, Decimal('2641.06'), 'Small'),
#  (1171, Decimal('2001.92'), 'Small'),
#  (1171, Decimal('2022.94'), 'Small'),
#  (1171, Decimal('1813.02'), 'Small'),
#  (1171, Decimal('1780.62'), 'Small'),
#  (1171, Decimal('2048.65'), 'Small'),
#  (1181, Decimal('1691.61'), 'Small'),
#  (1181, Decimal('2776.62'), 'Small'),
#  (1181, Decimal('2606.88'), 'Small'),
#  (1181, Decimal('2626.85'), 'Small'),
#  (1181, Decimal('3323.83'), 'Large'),
#  (1181, Decimal('2919.42'), 'Small'),
#  (1181, Decimal('2597.33'), 'Small'),
#  (1181, Decimal('2460.07'), 'Small'),
#  (1181, Decimal('2606.23'), 'Small'),
#  (1181, Decimal('2642.30'), 'Small'),
#  (1181, Decimal('3008.20'), 'Large'),
#  (1181, Decimal('3644.67'), 'Large'),
#  (1181, Decimal('2407.72'), 'Small'),
#  (1181, Decimal('2391.48'), 'Small'),
#  (1181, Decimal('2657.32'), 'Small'),
#  (1181, Decimal('2699.36'), 'Small'),
#  (1181, Decimal('2520.68'), 'Small'),
#  (1181, Decimal('2692.21'), 'Small'),
#  (1181, Decimal('2632.28'), 'Small'),
#  (1181, Decimal('2450.09'), 'Small'),
#  (1181, Decimal('2559.96'), 'Small'),
#  (1181, Decimal('2619.81'), 'Small'),
#  (1181, Decimal('2793.58'), 'Small'),
#  (1181, Decimal('2729.57'), 'Small'),
#  (1181, Decimal('2526.95'), 'Small'),
#  (1181, Decimal('2555.15'), 'Small'),
#  (1181, Decimal('2505.00'), 'Small'),
#  (1181, Decimal('2614.88'), 'Small'),
#  (1181, Decimal('2415.25'), 'Small'),
#  (1181, Decimal('11390.06'), 'Large'),
#  (1181, Decimal('2707.17'), 'Small'),
#  (1181, Decimal('2485.04'), 'Small'),
#  (1181, Decimal('2735.35'), 'Small'),
#  (1181, Decimal('2799.09'), 'Small'),
#  (1181, Decimal('2589.86'), 'Small'),
#  (1181, Decimal('2797.19'), 'Small'),
#  (1181, Decimal('3254.40'), 'Large'),
#  (1181, Decimal('2314.36'), 'Small'),
#  (1191, Decimal('2643.02'), 'Small'),
#  (1191, Decimal('2693.01'), 'Small'),
#  (1191, Decimal('3423.81'), 'Large'),
#  (1191, Decimal('2741.62'), 'Small'),
#  (1191, Decimal('2519.36'), 'Small'),
#  (1191, Decimal('2555.55'), 'Small'),
#  (1191, Decimal('2622.38'), 'Small'),
#  (1191, Decimal('2699.74'), 'Small'),
#  (1191, Decimal('3141.54'), 'Large'),
#  (1191, Decimal('2431.49'), 'Small'),
#  (1191, Decimal('2505.66'), 'Small'),
#  (1191, Decimal('1475.67'), 'Small'),
#  (1201, Decimal('2450.09'), 'Small'),
#  (1201, Decimal('2634.22'), 'Small'),
#  (1211, Decimal('1696.38'), 'Small'),
#  (1211, Decimal('1797.87'), 'Small'),
#  (1221, Decimal('2554.95'), 'Small'),
#  (1221, Decimal('3499.16'), 'Large'),
#  (1221, Decimal('2624.24'), 'Small'),
#  (1221, Decimal('2764.73'), 'Small'),
#  (1221, Decimal('1927.66'), 'Small'),
#  (1221, Decimal('2919.51'), 'Small'),
#  (1221, Decimal('2776.07'), 'Small'),
#  (1221, Decimal('2502.12'), 'Small'),
#  (1221, Decimal('2730.89'), 'Small'),
#  (1221, Decimal('2723.60'), 'Small'),
#  (1221, Decimal('2618.07'), 'Small'),
#  (1221, Decimal('2909.17'), 'Small'),
#  (1221, Decimal('3476.38'), 'Large'),
#  (1221, Decimal('12664.72'), 'Large'),
#  (1221, Decimal('2579.24'), 'Small'),
#  (1221, Decimal('2854.38'), 'Small'),
#  (1221, Decimal('2779.20'), 'Small'),
#  (1221, Decimal('3582.32'), 'Large'),
#  (1221, Decimal('3108.40'), 'Large'),
#  (1221, Decimal('2585.57'), 'Small'),
#  (1221, Decimal('2544.90'), 'Small'),
#  (1221, Decimal('2679.21'), 'Small'),
#  (1221, Decimal('2539.96'), 'Small'),
#  (1221, Decimal('3410.69'), 'Large'),
#  (1221, Decimal('2928.99'), 'Small'),
#  (1231, Decimal('2472.58'), 'Small'),
#  (1231, Decimal('3882.50'), 'Large'),
#  (1231, Decimal('2729.03'), 'Small'),
#  (1231, Decimal('2584.91'), 'Small'),
#  (1231, Decimal('2729.80'), 'Small'),
#  (1231, Decimal('3364.41'), 'Large'),
#  (1231, Decimal('2744.16'), 'Small'),
#  (1231, Decimal('2470.74'), 'Small'),
#  (1231, Decimal('13522.55'), 'Large'),
#  (1231, Decimal('2504.98'), 'Small'),
#  (1241, Decimal('838.44'), 'Small'),
#  (1241, Decimal('1389.78'), 'Small'),
#  (1241, Decimal('1050.62'), 'Small'),
#  (1241, Decimal('920.72'), 'Small'),
#  (1241, Decimal('1627.29'), 'Small'),
#  (1241, Decimal('912.05'), 'Small'),
#  (1241, Decimal('954.72'), 'Small'),
#  (1251, Decimal('997.33'), 'Small'),
#  (1251, Decimal('1127.00'), 'Small'),
#  (1251, Decimal('851.82'), 'Small'),
#  (1251, Decimal('878.68'), 'Small'),
#  (1251, Decimal('876.11'), 'Small'),
#  (1251, Decimal('1300.66'), 'Small'),
#  (1251, Decimal('1384.70'), 'Small'),
#  (1251, Decimal('1049.76'), 'Small'),
#  (1251, Decimal('869.91'), 'Small'),
#  (1251, Decimal('1059.67'), 'Small'),
#  (1251, Decimal('814.29'), 'Small'),
#  (1251, Decimal('138.04'), 'Small'),
#  (1251, Decimal('856.16'), 'Small'),
#  (1251, Decimal('2163.56'), 'Small'),
#  (1251, Decimal('1480.47'), 'Small'),
#  (1261, Decimal('2010.12'), 'Small'),
#  (1261, Decimal('1914.72'), 'Small'),
#  (1261, Decimal('2836.12'), 'Small'),
#  (1261, Decimal('1639.35'), 'Small'),
#  (1261, Decimal('5905.77'), 'Large'),
#  (1261, Decimal('1810.33'), 'Small'),
#  (1261, Decimal('1851.48'), 'Small'),
#  (1261, Decimal('2387.08'), 'Small'),
#  (1261, Decimal('1757.28'), 'Small'),
#  (1261, Decimal('2108.81'), 'Small'),
#  (1261, Decimal('1869.20'), 'Small'),
#  (1261, Decimal('1554.43'), 'Small'),
#  (1261, Decimal('2258.50'), 'Small'),
#  (1261, Decimal('1974.05'), 'Small'),
#  (1261, Decimal('1948.44'), 'Small'),
#  (1261, Decimal('1714.82'), 'Small'),
#  (1261, Decimal('644.75'), 'Small'),
#  (1261, Decimal('1681.39'), 'Small'),
#  (1261, Decimal('2276.09'), 'Small'),
#  (1261, Decimal('1906.15'), 'Small'),
#  (1261, Decimal('1924.69'), 'Small'),
#  (1261, Decimal('2048.67'), 'Small'),
#  (1261, Decimal('1510.88'), 'Small'),
#  (1261, Decimal('1630.64'), 'Small'),
#  (1261, Decimal('2212.86'), 'Small'),
#  (1261, Decimal('1833.74'), 'Small'),
#  (1261, Decimal('2218.77'), 'Small'),
#  (1271, Decimal('830.05'), 'Small'),
#  (1271, Decimal('1115.36'), 'Small'),
#  (1281, Decimal('3001.85'), 'Large'),
#  (1281, Decimal('2554.95'), 'Small'),
#  (1281, Decimal('4400.46'), 'Large'),
#  (1281, Decimal('5338.72'), 'Large'),
#  (1281, Decimal('1405.50'), 'Small'),
#  (1281, Decimal('3229.00'), 'Large'),
#  (1281, Decimal('2692.20'), 'Small'),
#  (1281, Decimal('2287.95'), 'Small'),
#  (1281, Decimal('2652.94'), 'Small'),
#  (1281, Decimal('3218.55'), 'Large'),
#  (1281, Decimal('6925.43'), 'Large'),
#  (1281, Decimal('2495.03'), 'Small'),
#  (1281, Decimal('2410.22'), 'Small'),
#  (1281, Decimal('3490.62'), 'Large'),
#  (1281, Decimal('5342.55'), 'Large'),
#  (1281, Decimal('2539.59'), 'Small'),
#  (1281, Decimal('2690.56'), 'Small'),
#  (1281, Decimal('2697.23'), 'Small'),
#  (1281, Decimal('3198.93'), 'Large'),
#  (1281, Decimal('2458.21'), 'Small'),
#  (1281, Decimal('3216.40'), 'Large'),
#  (1281, Decimal('2420.15'), 'Small'),
#  (1281, Decimal('2485.09'), 'Small'),
#  (1281, Decimal('4445.73'), 'Large'),
#  (1281, Decimal('2591.27'), 'Small'),
#  (1281, Decimal('3166.85'), 'Large'),
#  (1281, Decimal('2808.55'), 'Small'),
#  (1281, Decimal('2407.70'), 'Small'),
#  (1281, Decimal('2677.27'), 'Small'),
#  (1281, Decimal('2499.99'), 'Small'),
#  (1281, Decimal('3182.25'), 'Large'),
#  (1281, Decimal('2514.99'), 'Small'),
#  (1281, Decimal('3264.09'), 'Large'),
#  (1281, Decimal('29699.28'), 'Large'),
#  (1281, Decimal('2666.84'), 'Small'),
#  (1281, Decimal('4363.14'), 'Large'),
#  (1281, Decimal('2702.28'), 'Small'),
#  (1281, Decimal('2766.00'), 'Small'),
#  (1291, Decimal('5650.29'), 'Large'),
#  (1291, Decimal('2221.85'), 'Small'),
#  (1291, Decimal('1954.09'), 'Small'),
#  (1291, Decimal('312.83'), 'Small'),
#  (1291, Decimal('1987.22'), 'Small'),
#  (1291, Decimal('1761.61'), 'Small'),
#  (1291, Decimal('1951.38'), 'Small'),
#  (1291, Decimal('1837.36'), 'Small'),
#  (1291, Decimal('1750.54'), 'Small'),
#  (1291, Decimal('2183.69'), 'Small'),
#  (1291, Decimal('2027.69'), 'Small'),
#  (1291, Decimal('2315.36'), 'Small'),
#  (1291, Decimal('1588.23'), 'Small'),
#  (1291, Decimal('1070.47'), 'Small'),
#  (1291, Decimal('1925.82'), 'Small'),
#  (1291, Decimal('1688.04'), 'Small'),
#  (1291, Decimal('2036.32'), 'Small'),
#  (1291, Decimal('1784.31'), 'Small'),
#  (1291, Decimal('1901.64'), 'Small'),
#  (1291, Decimal('1878.39'), 'Small'),
#  (1291, Decimal('2124.09'), 'Small'),
#  (1301, Decimal('1350.60'), 'Small'),
#  (1301, Decimal('1311.98'), 'Small'),
#  (1301, Decimal('1453.25'), 'Small'),
#  (1301, Decimal('976.62'), 'Small'),
#  (1301, Decimal('939.83'), 'Small'),
#  (1301, Decimal('1009.79'), 'Small'),
#  (1301, Decimal('1070.61'), 'Small'),
#  (1301, Decimal('832.57'), 'Small'),
#  (1301, Decimal('1257.45'), 'Small'),
#  (1301, Decimal('940.03'), 'Small'),
#  (1301, Decimal('1118.50'), 'Small'),
#  (1301, Decimal('904.23'), 'Small'),
#  (1301, Decimal('1027.32'), 'Small'),
#  (1301, Decimal('1247.62'), 'Small'),
#  (1301, Decimal('800.66'), 'Small'),
#  (1301, Decimal('1026.48'), 'Small'),
#  (1301, Decimal('93106.81'), 'Large'),
#  (1301, Decimal('868.45'), 'Small'),
#  (1301, Decimal('663.34'), 'Small'),
#  (1301, Decimal('1268.82'), 'Small'),
#  (1301, Decimal('1260.51'), 'Small'),
#  (1301, Decimal('756.86'), 'Small'),
#  (1301, Decimal('828.02'), 'Small'),
#  (1301, Decimal('835.92'), 'Small'),
#  (1301, Decimal('1157.76'), 'Small'),
#  (1301, Decimal('553.98'), 'Small'),
#  (1301, Decimal('672.56'), 'Small'),
#  (1301, Decimal('1163.89'), 'Small'),
#  (1301, Decimal('791.27'), 'Small'),
#  (1301, Decimal('717.70'), 'Small'),
#  (1301, Decimal('882.92'), 'Small'),
#  (1301, Decimal('833.76'), 'Small'),
#  (1301, Decimal('1184.38'), 'Small'),
#  (1301, Decimal('1130.23'), 'Small'),
#  (1301, Decimal('778.80'), 'Small'),
#  (1301, Decimal('1762.90'), 'Small'),
#  (1301, Decimal('898.69'), 'Small'),
#  (1311, Decimal('1540.73'), 'Small'),
#  (1311, Decimal('2383.16'), 'Small'),
#  (1311, Decimal('619.43'), 'Small'),
#  (1311, Decimal('1709.35'), 'Small'),
#  (1311, Decimal('1768.94'), 'Small'),
#  (1311, Decimal('2014.04'), 'Small'),
#  (1311, Decimal('1853.62'), 'Small'),
#  (1321, Decimal('2612.36'), 'Small'),
#  (1321, Decimal('2507.55'), 'Small'),
#  (1321, Decimal('2639.29'), 'Small'),
#  (1321, Decimal('2623.56'), 'Small'),
#  (1321, Decimal('2808.38'), 'Small'),
#  (1321, Decimal('2711.10'), 'Small'),
#  (1321, Decimal('2521.90'), 'Small'),
#  (1321, Decimal('2466.40'), 'Small'),
#  (1321, Decimal('2779.58'), 'Small'),
#  (1321, Decimal('2450.09'), 'Small'),
#  (1321, Decimal('5841.78'), 'Large'),
#  (1321, Decimal('2721.63'), 'Small'),
#  (1321, Decimal('2504.98'), 'Small'),
#  (1321, Decimal('2677.89'), 'Small'),
#  (1331, Decimal('689.57'), 'Small'),
#  (1331, Decimal('798.11'), 'Small'),
#  (1331, Decimal('1063.58'), 'Small'),
#  (1331, Decimal('1270.22'), 'Small'),
#  (1331, Decimal('982.27'), 'Small'),
#  (1341, Decimal('557.44'), 'Small'),
#  (1341, Decimal('1689.90'), 'Small'),
#  (1341, Decimal('2376.47'), 'Small'),
#  (1341, Decimal('1870.42'), 'Small'),
#  (1341, Decimal('1596.91'), 'Small'),
#  (1351, Decimal('622.10'), 'Small'),
#  (1351, Decimal('869.68'), 'Small'),
#  (1351, Decimal('1764.48'), 'Small'),
#  (1351, Decimal('960.40'), 'Small'),
#  (1351, Decimal('885.57'), 'Small'),
#  (1361, Decimal('3079.22'), 'Large'),
#  (1361, Decimal('2669.75'), 'Small'),
#  (1361, Decimal('2400.19'), 'Small'),
#  (1361, Decimal('3174.55'), 'Large'),
#  (1371, Decimal('2117.61'), 'Small'),
#  (1371, Decimal('1716.14'), 'Small'),
#  (1371, Decimal('1704.31'), 'Small'),
#  (1371, Decimal('1754.80'), 'Small'),
#  (1371, Decimal('1951.44'), 'Small'),
#  (1371, Decimal('2686.63'), 'Small'),
#  (1371, Decimal('1620.16'), 'Small'),
#  (1371, Decimal('2309.34'), 'Small'),
#  (1371, Decimal('1536.99'), 'Small'),
#  (1371, Decimal('2683.36'), 'Small'),
#  (1371, Decimal('2292.51'), 'Small'),
#  (1371, Decimal('8747.25'), 'Large'),
#  (1371, Decimal('4355.28'), 'Large'),
#  (1371, Decimal('2090.07'), 'Small'),
#  (1371, Decimal('1734.87'), 'Small'),
#  (1371, Decimal('1803.11'), 'Small'),
#  (1371, Decimal('1892.17'), 'Small'),
#  (1371, Decimal('1592.64'), 'Small'),
#  (1381, Decimal('1865.44'), 'Small'),
#  (1381, Decimal('1744.22'), 'Small'),
#  (1391, Decimal('2554.88'), 'Small'),
#  (1391, Decimal('2535.59'), 'Small'),
#  (1391, Decimal('2525.00'), 'Small'),
#  (1401, Decimal('2011.48'), 'Small'),
#  (1401, Decimal('1668.79'), 'Small'),
#  (1401, Decimal('2045.95'), 'Small'),
#  (1401, Decimal('1805.44'), 'Small'),
#  (1401, Decimal('1897.91'), 'Small'),
#  (1401, Decimal('2320.90'), 'Small'),
#  (1401, Decimal('2093.12'), 'Small'),
#  (1401, Decimal('1784.96'), 'Small'),
#  (1401, Decimal('1815.76'), 'Small'),
#  (1401, Decimal('2573.29'), 'Small'),
#  (1401, Decimal('1885.37'), 'Small'),
#  (1401, Decimal('1946.56'), 'Small'),
#  (1401, Decimal('8686.10'), 'Large'),
#  (1401, Decimal('1132.40'), 'Small'),
#  (1401, Decimal('3461.85'), 'Large'),
#  (1401, Decimal('2153.74'), 'Small'),
#  (1401, Decimal('2032.05'), 'Small'),
#  (1401, Decimal('1714.95'), 'Small'),
#  (1401, Decimal('1753.62'), 'Small'),
#  (1401, Decimal('2024.02'), 'Small'),
#  (1401, Decimal('2377.92'), 'Small'),
#  (1401, Decimal('1959.04'), 'Small'),
#  (1401, Decimal('2450.85'), 'Small'),
#  (1401, Decimal('2170.85'), 'Small'),
#  (1401, Decimal('1599.38'), 'Small'),
#  (1401, Decimal('3293.82'), 'Large'),
#  (1401, Decimal('1731.71'), 'Small'),
#  (1401, Decimal('1514.58'), 'Small'),
#  (1401, Decimal('1956.29'), 'Small'),
#  (1401, Decimal('1816.10'), 'Small'),
#  (1401, Decimal('1615.14'), 'Small'),
#  (1401, Decimal('1877.82'), 'Small'),
#  (1401, Decimal('1959.75'), 'Small'),
#  (1401, Decimal('1902.88'), 'Small'),
#  (1401, Decimal('1091.75'), 'Small'),
#  (1401, Decimal('1758.09'), 'Small'),
#  (1401, Decimal('2190.64'), 'Small'),
#  (1401, Decimal('1517.23'), 'Small'),
#  (1411, Decimal('2792.11'), 'Small'),
#  (1411, Decimal('2725.46'), 'Small'),
#  (1411, Decimal('2543.04'), 'Small'),
#  (1411, Decimal('3143.52'), 'Large'),
#  (1411, Decimal('3301.49'), 'Large'),
#  (1411, Decimal('2375.24'), 'Small'),
#  (1411, Decimal('2679.64'), 'Small'),
#  (1411, Decimal('2926.64'), 'Small'),
#  (1411, Decimal('2804.15'), 'Small'),
#  (1411, Decimal('2755.97'), 'Small'),
#  (1411, Decimal('2716.52'), 'Small'),
#  (1411, Decimal('2850.83'), 'Small'),
#  (1411, Decimal('2796.71'), 'Small'),
#  (1411, Decimal('3242.19'), 'Large'),
#  (1411, Decimal('6799.09'), 'Large'),
#  (1411, Decimal('2662.30'), 'Small'),
#  (1411, Decimal('2798.52'), 'Small'),
#  (1411, Decimal('2732.13'), 'Small'),
#  (1411, Decimal('2609.39'), 'Small'),
#  (1411, Decimal('4804.39'), 'Large'),
#  (1411, Decimal('2488.15'), 'Small'),
#  (1411, Decimal('2564.92'), 'Small'),
#  (1411, Decimal('3855.73'), 'Large'),
#  (1411, Decimal('2770.81'), 'Small'),
#  (1411, Decimal('3351.37'), 'Large'),
#  (1411, Decimal('2858.46'), 'Small'),
#  (1411, Decimal('4046.95'), 'Large'),
#  (1411, Decimal('4114.60'), 'Large'),
#  (1411, Decimal('2657.19'), 'Small'),
#  (1411, Decimal('2734.67'), 'Small'),
#  (1411, Decimal('2854.78'), 'Small'),
#  (1411, Decimal('2551.16'), 'Small'),
#  (1411, Decimal('3009.13'), 'Large'),
#  (1411, Decimal('2642.43'), 'Small'),
#  (1411, Decimal('3493.32'), 'Large'),
#  (1411, Decimal('2393.34'), 'Small'),
#  (1421, Decimal('1851.78'), 'Small'),
#  (1421, Decimal('3273.34'), 'Large'),
#  (1421, Decimal('1651.87'), 'Small'),
#  (1421, Decimal('1809.22'), 'Small'),
#  (1421, Decimal('1990.79'), 'Small'),
#  (1421, Decimal('2023.49'), 'Small'),
#  (1421, Decimal('1643.43'), 'Small'),
#  (1421, Decimal('1926.32'), 'Small'),
#  (1421, Decimal('1382.23'), 'Small'),
#  (1421, Decimal('1925.51'), 'Small'),
#  (1421, Decimal('1623.91'), 'Small'),
#  (1421, Decimal('2070.16'), 'Small'),
#  (1421, Decimal('1967.79'), 'Small'),
#  (1421, Decimal('1857.89'), 'Small'),
#  (1421, Decimal('1857.85'), 'Small'),
#  (1421, Decimal('1801.70'), 'Small'),
#  (1421, Decimal('2189.39'), 'Small'),
#  (1421, Decimal('1764.28'), 'Small'),
#  (1421, Decimal('1884.17'), 'Small'),
#  (1421, Decimal('1967.71'), 'Small'),
#  (1421, Decimal('1404.66'), 'Small'),
#  (1421, Decimal('1467.06'), 'Small'),
#  (1421, Decimal('479.36'), 'Small'),
#  (1421, Decimal('1705.53'), 'Small'),
#  (1421, Decimal('2062.70'), 'Small'),
#  (1421, Decimal('1310.34'), 'Small'),
#  (1421, Decimal('1735.50'), 'Small'),
#  (1421, Decimal('2234.73'), 'Small'),
#  (1421, Decimal('1852.31'), 'Small'),
#  (1421, Decimal('1437.28'), 'Small'),
#  (1421, Decimal('2175.71'), 'Small'),
#  (1421, Decimal('2131.33'), 'Small'),
#  (1421, Decimal('1926.53'), 'Small'),
#  (1421, Decimal('1506.99'), 'Small'),
#  (1421, Decimal('1889.79'), 'Small'),
#  (1421, Decimal('2073.09'), 'Small'),
#  (1421, Decimal('2023.58'), 'Small'),
#  (1431, Decimal('892.94'), 'Small'),
#  (1431, Decimal('951.65'), 'Small'),
#  (1431, Decimal('771.14'), 'Small'),
#  (1431, Decimal('1631.94'), 'Small'),
#  (1441, Decimal('1847.13'), 'Small'),
#  (1441, Decimal('1996.60'), 'Small'),
#  (1441, Decimal('2187.33'), 'Small'),
#  (1441, Decimal('1555.20'), 'Small'),
#  (1441, Decimal('2136.52'), 'Small'),
#  (1441, Decimal('2260.15'), 'Small'),
#  (1441, Decimal('1927.82'), 'Small'),
#  (1441, Decimal('1921.55'), 'Small'),
#  (1441, Decimal('1689.30'), 'Small'),
#  (1441, Decimal('1895.38'), 'Small'),
#  (1441, Decimal('1865.36'), 'Small'),
#  (1441, Decimal('1544.45'), 'Small'),
#  (1441, Decimal('2325.13'), 'Small'),
#  (1441, Decimal('1950.46'), 'Small'),
#  (1441, Decimal('1848.99'), 'Small'),
#  (1441, Decimal('1652.55'), 'Small'),
#  (1441, Decimal('1683.85'), 'Small'),
#  (1441, Decimal('1426.33'), 'Small'),
#  (1441, Decimal('2695.21'), 'Small'),
#  (1441, Decimal('1745.51'), 'Small'),
#  (1441, Decimal('1676.91'), 'Small'),
#  (1441, Decimal('2123.35'), 'Small'),
#  (1441, Decimal('2383.03'), 'Small'),
#  (1441, Decimal('1985.97'), 'Small'),
#  (1441, Decimal('2115.07'), 'Small'),
#  (1441, Decimal('2256.90'), 'Small'),
#  (1441, Decimal('2014.74'), 'Small'),
#  (1441, Decimal('1771.02'), 'Small'),
#  (1441, Decimal('1874.57'), 'Small'),
#  (1441, Decimal('1814.20'), 'Small'),
#  (1441, Decimal('2403.17'), 'Small'),
#  (1441, Decimal('2200.14'), 'Small'),
#  (1441, Decimal('1761.81'), 'Small'),
#  (1441, Decimal('2069.01'), 'Small'),
#  (1441, Decimal('2052.61'), 'Small'),
#  (1451, Decimal('2308.02'), 'Small'),
#  (1451, Decimal('1791.63'), 'Small'),
#  (1451, Decimal('3427.27'), 'Large'),
#  (1451, Decimal('1783.78'), 'Small'),
#  (1451, Decimal('1998.88'), 'Small'),
#  (1451, Decimal('1928.91'), 'Small'),
#  (1451, Decimal('1806.13'), 'Small'),
#  (1451, Decimal('1775.53'), 'Small'),
#  (1451, Decimal('2055.88'), 'Small'),
#  (1451, Decimal('1622.67'), 'Small'),
#  (1451, Decimal('1807.91'), 'Small'),
#  (1451, Decimal('1988.69'), 'Small'),
#  (1451, Decimal('1977.77'), 'Small'),
#  (1451, Decimal('1958.48'), 'Small'),
#  (1451, Decimal('2441.03'), 'Small'),
#  (1451, Decimal('7417.96'), 'Large'),
#  (1451, Decimal('1511.97'), 'Small'),
#  (1451, Decimal('1764.14'), 'Small'),
#  (1451, Decimal('1851.51'), 'Small'),
#  (1451, Decimal('2131.28'), 'Small'),
#  (1451, Decimal('1771.03'), 'Small'),
#  (1451, Decimal('2052.07'), 'Small'),
#  (1451, Decimal('1854.74'), 'Small'),
#  (1451, Decimal('1776.76'), 'Small'),
#  (1451, Decimal('1726.24'), 'Small'),
#  (1451, Decimal('1858.49'), 'Small'),
#  (1451, Decimal('2034.65'), 'Small'),
#  (1451, Decimal('3163.10'), 'Large'),
#  (1451, Decimal('1779.12'), 'Small'),
#  (1451, Decimal('1868.83'), 'Small'),
#  (1451, Decimal('1586.41'), 'Small'),
#  (1451, Decimal('1732.38'), 'Small'),
#  (1451, Decimal('1793.58'), 'Small'),
#  (1461, Decimal('2581.19'), 'Small'),
#  (1461, Decimal('2577.35'), 'Small'),
#  (1461, Decimal('2604.85'), 'Small'),
#  (1461, Decimal('5136.95'), 'Large'),
#  (1461, Decimal('2488.30'), 'Small'),
#  (1461, Decimal('2771.55'), 'Small'),
#  (1461, Decimal('2465.10'), 'Small'),
#  (1461, Decimal('2193.22'), 'Small'),
#  (1461, Decimal('2495.00'), 'Small'),
#  (1461, Decimal('2515.01'), 'Small'),
#  (1461, Decimal('2518.86'), 'Small'),
#  (1461, Decimal('4434.27'), 'Large'),
#  (1461, Decimal('2932.44'), 'Small'),
#  (1461, Decimal('2766.71'), 'Small'),
#  (1471, Decimal('967.31'), 'Small'),
#  (1481, Decimal('902.30'), 'Small'),
#  (1491, Decimal('1659.35'), 'Small'),
#  (1491, Decimal('4751.82'), 'Large'),
#  (1491, Decimal('3770.08'), 'Large'),
#  (1491, Decimal('1856.47'), 'Small'),
#  (1491, Decimal('2085.25'), 'Small'),
#  (1491, Decimal('2127.66'), 'Small'),
#  (1491, Decimal('2090.52'), 'Small'),
#  (1491, Decimal('1881.62'), 'Small'),
#  (1491, Decimal('2140.25'), 'Small'),
#  (1491, Decimal('1645.11'), 'Small'),
#  (1491, Decimal('2965.91'), 'Small'),
#  (1491, Decimal('1946.48'), 'Small'),
#  (1491, Decimal('1688.79'), 'Small'),
#  (1491, Decimal('2037.14'), 'Small'),
#  (1491, Decimal('1815.44'), 'Small'),
#  (1491, Decimal('1883.95'), 'Small'),
#  (1491, Decimal('2179.72'), 'Small'),
#  (1491, Decimal('1742.36'), 'Small'),
#  (1491, Decimal('1779.31'), 'Small'),
#  (1491, Decimal('1844.16'), 'Small'),
#  (1491, Decimal('1482.03'), 'Small'),
#  (1491, Decimal('1073.83'), 'Small'),
#  (1491, Decimal('1886.11'), 'Small'),
#  (1491, Decimal('1746.66'), 'Small'),
#  (1501, Decimal('2049.52'), 'Small'),
#  (1501, Decimal('1917.74'), 'Small'),
#  (1501, Decimal('2059.47'), 'Small'),
#  (1501, Decimal('1822.88'), 'Small'),
#  (1501, Decimal('1719.36'), 'Small'),
#  (1501, Decimal('2095.91'), 'Small'),
#  (1501, Decimal('1761.77'), 'Small'),
#  (1501, Decimal('2413.73'), 'Small'),
#  (1501, Decimal('1856.13'), 'Small'),
#  (1501, Decimal('2113.74'), 'Small'),
#  (1501, Decimal('1716.88'), 'Small'),
#  (1501, Decimal('2523.17'), 'Small'),
#  (1501, Decimal('1482.03'), 'Small'),
#  (1501, Decimal('1784.84'), 'Small'),
#  (1501, Decimal('242.27'), 'Small'),
#  (1501, Decimal('2090.92'), 'Small'),
#  (1501, Decimal('1925.88'), 'Small'),
#  (1501, Decimal('1658.07'), 'Small'),
#  (1501, Decimal('1731.72'), 'Small'),
#  (1501, Decimal('2422.41'), 'Small'),
#  (1501, Decimal('1907.30'), 'Small'),
#  (1501, Decimal('1953.99'), 'Small'),
#  (1501, Decimal('2092.63'), 'Small'),
#  (1511, Decimal('2802.73'), 'Small'),
#  (1511, Decimal('2642.93'), 'Small'),
#  (1511, Decimal('2606.23'), 'Small'),
#  (1511, Decimal('2185.62'), 'Small'),
#  (1511, Decimal('2600.15'), 'Small'),
#  (1511, Decimal('2440.11'), 'Small'),
#  (1511, Decimal('2728.40'), 'Small'),
#  (1511, Decimal('2397.85'), 'Small'),
#  (1511, Decimal('2658.07'), 'Small'),
#  (1511, Decimal('2924.34'), 'Small'),
#  (1521, Decimal('1538.46'), 'Small'),
#  (1521, Decimal('2413.30'), 'Small'),
#  (1521, Decimal('2564.95'), 'Small'),
#  (1521, Decimal('2597.43'), 'Small'),
#  (1521, Decimal('3256.49'), 'Large'),
#  (1521, Decimal('3218.91'), 'Large'),
#  (1521, Decimal('2290.62'), 'Small'),
#  (1521, Decimal('2831.83'), 'Small'),
#  (1521, Decimal('2499.99'), 'Small'),
#  (1521, Decimal('2565.00'), 'Small'),
#  (1521, Decimal('2847.47'), 'Small'),
#  (1521, Decimal('141.12'), 'Small'),
#  (1521, Decimal('3166.78'), 'Large'),
#  (1521, Decimal('2646.06'), 'Small'),
#  (1521, Decimal('2499.42'), 'Small'),
#  (1521, Decimal('2629.99'), 'Small'),
#  (1521, Decimal('3075.56'), 'Large'),
#  (1521, Decimal('2869.73'), 'Small'),
#  (1521, Decimal('2662.33'), 'Small'),
#  (1521, Decimal('5452.98'), 'Large'),
#  (1521, Decimal('2440.12'), 'Small'),
#  (1521, Decimal('2472.70'), 'Small'),
#  (1521, Decimal('2669.92'), 'Small'),
#  (1521, Decimal('2937.69'), 'Small'),
#  (1521, Decimal('4525.23'), 'Large'),
#  (1521, Decimal('2465.06'), 'Small'),
#  (1521, Decimal('3041.85'), 'Large'),
#  (1521, Decimal('2514.96'), 'Small'),
#  (1521, Decimal('16.24'), 'Small'),
#  (1521, Decimal('92991.05'), 'Large'),
#  (1521, Decimal('2669.92'), 'Small'),
#  (1521, Decimal('2914.52'), 'Small'),
#  (1521, Decimal('2574.55'), 'Small'),
#  (1521, Decimal('2387.81'), 'Small'),
#  (1521, Decimal('2764.84'), 'Small'),
#  (1521, Decimal('2617.31'), 'Small'),
#  (1521, Decimal('3831.68'), 'Large'),
#  (1531, Decimal('2499.99'), 'Small'),
#  (1531, Decimal('1588.25'), 'Small'),
#  (1531, Decimal('2557.50'), 'Small'),
#  (1531, Decimal('2546.81'), 'Small'),
#  (1531, Decimal('2592.35'), 'Small'),
#  (1531, Decimal('2699.86'), 'Small'),
#  (1531, Decimal('2492.54'), 'Small'),
#  (1531, Decimal('2513.19'), 'Small'),
#  (1531, Decimal('2687.19'), 'Small'),
#  (1531, Decimal('3114.84'), 'Large'),
#  (1531, Decimal('2690.51'), 'Small'),
#  (1531, Decimal('2663.07'), 'Small'),
#  (1531, Decimal('2569.33'), 'Small'),
#  (1531, Decimal('2648.01'), 'Small'),
#  (1531, Decimal('3337.72'), 'Large'),
#  (1531, Decimal('2297.93'), 'Small'),
#  (1531, Decimal('2537.55'), 'Small'),
#  (1531, Decimal('2078.56'), 'Small'),
#  (1531, Decimal('2630.55'), 'Small'),
#  (1531, Decimal('2495.04'), 'Small'),
#  (1531, Decimal('2694.78'), 'Small'),
#  (1531, Decimal('2562.01'), 'Small'),
#  (1531, Decimal('3207.38'), 'Large'),
#  (1531, Decimal('2556.39'), 'Small'),
#  (1531, Decimal('2781.65'), 'Small'),
#  (1531, Decimal('3198.69'), 'Large'),
#  (1531, Decimal('2544.90'), 'Small'),
#  (1531, Decimal('2556.24'), 'Small'),
#  (1531, Decimal('2820.27'), 'Small'),
#  (1531, Decimal('2639.72'), 'Small'),
#  (1531, Decimal('2891.25'), 'Small'),
#  (1531, Decimal('3977.99'), 'Large'),
#  (1531, Decimal('3498.82'), 'Large'),
#  (1531, Decimal('2773.46'), 'Small'),
#  (1531, Decimal('2596.14'), 'Small'),
#  (1531, Decimal('2621.71'), 'Small'),
#  (1531, Decimal('2779.03'), 'Small'),
#  (1531, Decimal('2793.47'), 'Small'),
#  (1541, Decimal('949.23'), 'Small'),
#  (1541, Decimal('1485.58'), 'Small'),
#  (1541, Decimal('1137.84'), 'Small'),
#  (1541, Decimal('924.28'), 'Small'),
#  (1541, Decimal('1057.28'), 'Small'),
#  (1541, Decimal('1541.76'), 'Small'),
#  (1541, Decimal('767.08'), 'Small'),
#  (1541, Decimal('901.77'), 'Small'),
#  (1541, Decimal('1098.97'), 'Small'),
#  (1541, Decimal('1852.17'), 'Small'),
#  (1541, Decimal('834.48'), 'Small'),
#  (1541, Decimal('1329.03'), 'Small'),
#  (1541, Decimal('902.42'), 'Small'),
#  (1541, Decimal('756.22'), 'Small'),
#  (1541, Decimal('1156.55'), 'Small'),
#  (1541, Decimal('1172.76'), 'Small'),
#  (1541, Decimal('1032.88'), 'Small'),
#  (1551, Decimal('1682.49'), 'Small'),
#  (1561, Decimal('2712.61'), 'Small'),
#  (1561, Decimal('1518.32'), 'Small'),
#  (1561, Decimal('1981.52'), 'Small'),
#  (1561, Decimal('1768.00'), 'Small'),
#  (1561, Decimal('1936.55'), 'Small'),
#  (1561, Decimal('1605.15'), 'Small'),
#  (1561, Decimal('1962.64'), 'Small'),
#  (1561, Decimal('2787.78'), 'Small'),
#  (1561, Decimal('308.56'), 'Small'),
#  (1561, Decimal('1562.05'), 'Small'),
#  (1561, Decimal('1892.18'), 'Small'),
#  (1561, Decimal('2011.31'), 'Small'),
#  (1561, Decimal('1871.04'), 'Small'),
#  (1561, Decimal('1998.94'), 'Small'),
#  (1561, Decimal('1579.42'), 'Small'),
#  (1561, Decimal('2143.96'), 'Small'),
#  (1561, Decimal('2130.78'), 'Small'),
#  (1561, Decimal('1787.42'), 'Small'),
#  (1561, Decimal('1713.64'), 'Small'),
#  (1561, Decimal('2444.18'), 'Small'),
#  (1561, Decimal('2168.78'), 'Small'),
#  (1561, Decimal('1596.92'), 'Small'),
#  (1561, Decimal('1814.89'), 'Small'),
#  (1561, Decimal('2003.95'), 'Small'),
#  (1561, Decimal('1842.40'), 'Small'),
#  (1561, Decimal('1883.59'), 'Small'),
#  (1561, Decimal('1549.49'), 'Small'),
#  (1561, Decimal('1604.33'), 'Small'),
#  (1561, Decimal('2177.66'), 'Small'),
#  (1561, Decimal('2062.68'), 'Small'),
#  (1561, Decimal('1908.44'), 'Small'),
#  (1561, Decimal('1660.90'), 'Small'),
#  (1561, Decimal('2150.73'), 'Small'),
#  (1561, Decimal('1757.40'), 'Small'),
#  (1561, Decimal('1593.62'), 'Small'),
#  (1561, Decimal('1754.16'), 'Small'),
#  (1561, Decimal('1869.04'), 'Small'),
#  (1561, Decimal('2114.23'), 'Small'),
#  (1571, Decimal('2981.38'), 'Small'),
#  (1571, Decimal('2584.92'), 'Small'),
#  (1571, Decimal('2589.87'), 'Small'),
#  (1571, Decimal('3258.92'), 'Large'),
#  (1571, Decimal('2740.32'), 'Small'),
#  (1571, Decimal('3012.08'), 'Large'),
#  (1571, Decimal('2900.78'), 'Small'),
#  (1571, Decimal('2704.69'), 'Small'),
#  (1571, Decimal('2705.38'), 'Small'),
#  (1571, Decimal('2660.94'), 'Small'),
#  (1571, Decimal('2722.15'), 'Small'),
#  (1571, Decimal('2763.38'), 'Small'),
#  (1571, Decimal('2518.85'), 'Small'),
#  (1571, Decimal('2588.05'), 'Small'),
#  (1571, Decimal('2874.24'), 'Small'),
#  (1571, Decimal('2716.19'), 'Small'),
#  (1571, Decimal('3597.93'), 'Large'),
#  (1571, Decimal('2499.99'), 'Small'),
#  (1571, Decimal('3499.44'), 'Large'),
#  (1571, Decimal('2482.12'), 'Small'),
#  (1571, Decimal('2613.60'), 'Small'),
#  (1571, Decimal('4642.17'), 'Large'),
#  (1571, Decimal('2647.16'), 'Small'),
#  (1571, Decimal('2636.76'), 'Small'),
#  (1571, Decimal('2540.60'), 'Small'),
#  (1571, Decimal('2653.68'), 'Small'),
#  (1571, Decimal('2554.39'), 'Small'),
#  (1571, Decimal('14.98'), 'Small'),
#  (1571, Decimal('4042.01'), 'Large'),
#  (1571, Decimal('2792.16'), 'Small'),
#  (1571, Decimal('2460.07'), 'Small'),
#  (1571, Decimal('2597.48'), 'Small'),
#  (1571, Decimal('2558.78'), 'Small'),
#  (1571, Decimal('2763.58'), 'Small'),
#  (1571, Decimal('3121.08'), 'Large'),
#  (1571, Decimal('2699.20'), 'Small'),
#  (1571, Decimal('3233.08'), 'Large'),
#  (1571, Decimal('2755.31'), 'Small'),
#  (1581, Decimal('1180.86'), 'Small'),
#  (1581, Decimal('2053.08'), 'Small'),
#  (1581, Decimal('11860.85'), 'Large'),
#  (1581, Decimal('1049.22'), 'Small'),
#  (1581, Decimal('1087.01'), 'Small'),
#  (1581, Decimal('1725.54'), 'Small'),
#  (1581, Decimal('890.81'), 'Small'),
#  (1581, Decimal('881.06'), 'Small'),
#  (1581, Decimal('586.46'), 'Small'),
#  (1591, Decimal('2440.31'), 'Small'),
#  (1601, Decimal('3565.48'), 'Large'),
#  (1601, Decimal('2678.03'), 'Small'),
#  (1601, Decimal('2843.39'), 'Small'),
#  (1601, Decimal('2683.62'), 'Small'),
#  (1601, Decimal('2595.66'), 'Small'),
#  (1601, Decimal('3223.29'), 'Large'),
#  (1601, Decimal('2535.03'), 'Small'),
#  (1601, Decimal('2642.28'), 'Small'),
#  (1601, Decimal('2410.21'), 'Small'),
#  (1601, Decimal('4359.48'), 'Large'),
#  (1601, Decimal('2617.44'), 'Small'),
#  (1601, Decimal('2449.59'), 'Small'),
#  (1601, Decimal('2576.91'), 'Small'),
#  (1601, Decimal('2644.89'), 'Small'),
#  (1601, Decimal('2585.66'), 'Small'),
#  (1601, Decimal('2815.94'), 'Small'),
#  (1601, Decimal('7045.91'), 'Large'),
#  (1601, Decimal('2604.85'), 'Small'),
#  (1601, Decimal('453.73'), 'Small'),
#  (1601, Decimal('2890.12'), 'Small'),
#  (1601, Decimal('2679.21'), 'Small'),
#  (1601, Decimal('2846.84'), 'Small'),
#  (1601, Decimal('2838.37'), 'Small'),
#  (1601, Decimal('2891.41'), 'Small'),
#  (1601, Decimal('2435.12'), 'Small'),
#  (1601, Decimal('3098.67'), 'Large'),
#  (1601, Decimal('2417.76'), 'Small'),
#  (1601, Decimal('2664.78'), 'Small'),
#  (1601, Decimal('2690.50'), 'Small'),
#  (1601, Decimal('2501.99'), 'Small'),
#  (1601, Decimal('2794.17'), 'Small'),
#  (1601, Decimal('150.43'), 'Small'),
#  (1601, Decimal('3427.45'), 'Large'),
#  (1601, Decimal('2607.45'), 'Small'),
#  (1601, Decimal('2807.37'), 'Small'),
#  (1601, Decimal('2981.03'), 'Small'),
#  (1601, Decimal('3061.38'), 'Large'),
#  (1601, Decimal('2604.96'), 'Small'),
#  (1611, Decimal('2614.91'), 'Small'),
#  (1611, Decimal('2504.99'), 'Small'),
#  (1611, Decimal('2523.85'), 'Small'),
#  (1611, Decimal('2693.54'), 'Small'),
#  (1611, Decimal('2732.10'), 'Small'),
#  (1611, Decimal('2754.77'), 'Small'),
#  (1611, Decimal('2145.70'), 'Small'),
#  (1611, Decimal('2405.36'), 'Small'),
#  (1611, Decimal('96.17'), 'Small'),
#  (1611, Decimal('2562.43'), 'Small'),
#  (1611, Decimal('2779.52'), 'Small'),
#  (1611, Decimal('2800.31'), 'Small'),
#  (1611, Decimal('205.45'), 'Small'),
#  (1611, Decimal('3118.37'), 'Large'),
#  (1611, Decimal('2664.27'), 'Small'),
#  (1611, Decimal('2710.44'), 'Small'),
#  (1621, Decimal('1374.38'), 'Small'),
#  (1631, Decimal('1881.92'), 'Small'),
#  (1631, Decimal('858.08'), 'Small'),
#  (1631, Decimal('855.57'), 'Small'),
#  (1631, Decimal('1124.54'), 'Small'),
#  (1631, Decimal('899.92'), 'Small'),
#  (1631, Decimal('813.61'), 'Small'),
#  (1631, Decimal('548.90'), 'Small'),
#  (1641, Decimal('1886.52'), 'Small'),
#  (1641, Decimal('2002.44'), 'Small'),
#  (1641, Decimal('1744.20'), 'Small'),
#  (1641, Decimal('1814.95'), 'Small'),
#  (1651, Decimal('833.39'), 'Small'),
#  (1651, Decimal('1031.43'), 'Small'),
#  (1651, Decimal('199.60'), 'Small'),
#  (1651, Decimal('915.21'), 'Small'),
#  (1651, Decimal('967.54'), 'Small'),
#  (1651, Decimal('1112.85'), 'Small'),
#  (1651, Decimal('486.55'), 'Small'),
#  (1651, Decimal('753.49'), 'Small'),
#  (1651, Decimal('798.74'), 'Small'),
#  (1651, Decimal('830.88'), 'Small'),
#  (1651, Decimal('1025.20'), 'Small'),
#  (1651, Decimal('938.37'), 'Small'),
#  (1651, Decimal('953.23'), 'Small'),
#  (1651, Decimal('1070.68'), 'Small'),
#  (1651, Decimal('1941.93'), 'Small'),
#  (1651, Decimal('653.69'), 'Small'),
#  (1651, Decimal('900.74'), 'Small'),
#  (1651, Decimal('721.11'), 'Small'),
#  (1651, Decimal('1043.15'), 'Small'),
#  (1651, Decimal('785.95'), 'Small'),
#  (1651, Decimal('920.73'), 'Small'),
#  (1651, Decimal('815.93'), 'Small'),
#  (1651, Decimal('1482.81'), 'Small'),
#  (1651, Decimal('908.30'), 'Small'),
#  (1651, Decimal('736.04'), 'Small'),
#  (1651, Decimal('187.85'), 'Small'),
#  (1651, Decimal('2403.17'), 'Small'),
#  (1651, Decimal('1074.27'), 'Small'),
#  (1651, Decimal('827.27'), 'Small'),
#  (1651, Decimal('819.63'), 'Small'),
#  (1661, Decimal('3374.33'), 'Large'),
#  (1661, Decimal('8373.38'), 'Large'),
#  (1661, Decimal('2600.56'), 'Small'),
#  (1661, Decimal('2577.47'), 'Small'),
#  (1661, Decimal('2546.89'), 'Small'),
#  (1661, Decimal('2474.49'), 'Small'),
#  (1661, Decimal('3096.41'), 'Large'),
#  (1661, Decimal('2581.19'), 'Small'),
#  (1671, Decimal('859.64'), 'Small'),
#  (1681, Decimal('1921.46'), 'Small'),
#  (1681, Decimal('1824.83'), 'Small'),
#  (1681, Decimal('4909.59'), 'Large'),
#  (1681, Decimal('2169.92'), 'Small'),
#  (1681, Decimal('1657.47'), 'Small'),
#  (1681, Decimal('6144.25'), 'Large'),
#  (1681, Decimal('1819.11'), 'Small'),
#  (1681, Decimal('1932.05'), 'Small'),
#  (1681, Decimal('4051.74'), 'Large'),
#  (1691, Decimal('2661.13'), 'Small'),
#  (1691, Decimal('3222.67'), 'Large'),
#  (1691, Decimal('2839.53'), 'Small'),
#  (1691, Decimal('2716.00'), 'Small'),
#  (1691, Decimal('2514.96'), 'Small'),
#  (1691, Decimal('2211.89'), 'Small'),
#  ...]

# %% [markdown]
# #### 40. Write a query to display the number of orders in each of three categories, based on the total number of items in each order. The three categories are: 'At Least 2000', 'Between 1000 and 2000' and 'Less than 1000'.

# %%
# %%sql
# SELECT
#     total,
#     CASE
#     WHEN total < 1000 THEN 'Less than 1000'
#     WHEN total >= 1000 AND total < 2000 THEN 'Between 1000 and 2000'
#     WHEN total >= 2000 THEN  'At Least 2000' END
# FROM orders_consolidated
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 6912 rows affected.
# [(169, 'Less than 1000'),
#  (288, 'Less than 1000'),
#  (132, 'Less than 1000'),
#  (176, 'Less than 1000'),
#  (165, 'Less than 1000'),
#  (173, 'Less than 1000'),
#  (226, 'Less than 1000'),
#  (293, 'Less than 1000'),
#  (129, 'Less than 1000'),
#  (148, 'Less than 1000'),
#  (137, 'Less than 1000'),
#  (196, 'Less than 1000'),
#  (158, 'Less than 1000'),
#  (294, 'Less than 1000'),
#  (210, 'Less than 1000'),
#  (269, 'Less than 1000'),
#  (541, 'Less than 1000'),
#  (539, 'Less than 1000'),
#  (558, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (569, 'Less than 1000'),
#  (515, 'Less than 1000'),
#  (578, 'Less than 1000'),
#  (1363, 'Between 1000 and 2000'),
#  (395, 'Less than 1000'),
#  (329, 'Less than 1000'),
#  (212, 'Less than 1000'),
#  (589, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (487, 'Less than 1000'),
#  (595, 'Less than 1000'),
#  (508, 'Less than 1000'),
#  (497, 'Less than 1000'),
#  (365, 'Less than 1000'),
#  (269, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (853, 'Less than 1000'),
#  (367, 'Less than 1000'),
#  (334, 'Less than 1000'),
#  (333, 'Less than 1000'),
#  (322, 'Less than 1000'),
#  (389, 'Less than 1000'),
#  (524, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (343, 'Less than 1000'),
#  (375, 'Less than 1000'),
#  (349, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (349, 'Less than 1000'),
#  (341, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (376, 'Less than 1000'),
#  (374, 'Less than 1000'),
#  (375, 'Less than 1000'),
#  (327, 'Less than 1000'),
#  (465, 'Less than 1000'),
#  (331, 'Less than 1000'),
#  (379, 'Less than 1000'),
#  (322, 'Less than 1000'),
#  (169, 'Less than 1000'),
#  (194, 'Less than 1000'),
#  (345, 'Less than 1000'),
#  (173, 'Less than 1000'),
#  (299, 'Less than 1000'),
#  (255, 'Less than 1000'),
#  (156, 'Less than 1000'),
#  (95, 'Less than 1000'),
#  (161, 'Less than 1000'),
#  (154, 'Less than 1000'),
#  (127, 'Less than 1000'),
#  (190, 'Less than 1000'),
#  (188, 'Less than 1000'),
#  (143, 'Less than 1000'),
#  (175, 'Less than 1000'),
#  (171, 'Less than 1000'),
#  (222, 'Less than 1000'),
#  (168, 'Less than 1000'),
#  (132, 'Less than 1000'),
#  (160, 'Less than 1000'),
#  (167, 'Less than 1000'),
#  (157, 'Less than 1000'),
#  (198, 'Less than 1000'),
#  (155, 'Less than 1000'),
#  (187, 'Less than 1000'),
#  (156, 'Less than 1000'),
#  (261, 'Less than 1000'),
#  (166, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (214, 'Less than 1000'),
#  (139, 'Less than 1000'),
#  (165, 'Less than 1000'),
#  (194, 'Less than 1000'),
#  (212, 'Less than 1000'),
#  (166, 'Less than 1000'),
#  (171, 'Less than 1000'),
#  (38, 'Less than 1000'),
#  (176, 'Less than 1000'),
#  (201, 'Less than 1000'),
#  (162, 'Less than 1000'),
#  (401, 'Less than 1000'),
#  (390, 'Less than 1000'),
#  (337, 'Less than 1000'),
#  (362, 'Less than 1000'),
#  (397, 'Less than 1000'),
#  (373, 'Less than 1000'),
#  (307, 'Less than 1000'),
#  (260, 'Less than 1000'),
#  (339, 'Less than 1000'),
#  (320, 'Less than 1000'),
#  (319, 'Less than 1000'),
#  (370, 'Less than 1000'),
#  (326, 'Less than 1000'),
#  (316, 'Less than 1000'),
#  (324, 'Less than 1000'),
#  (466, 'Less than 1000'),
#  (364, 'Less than 1000'),
#  (368, 'Less than 1000'),
#  (417, 'Less than 1000'),
#  (53, 'Less than 1000'),
#  (350, 'Less than 1000'),
#  (407, 'Less than 1000'),
#  (331, 'Less than 1000'),
#  (365, 'Less than 1000'),
#  (0, 'Less than 1000'),
#  (331, 'Less than 1000'),
#  (193, 'Less than 1000'),
#  (208, 'Less than 1000'),
#  (157, 'Less than 1000'),
#  (3345, 'At Least 2000'),
#  (559, 'Less than 1000'),
#  (414, 'Less than 1000'),
#  (536, 'Less than 1000'),
#  (532, 'Less than 1000'),
#  (618, 'Less than 1000'),
#  (524, 'Less than 1000'),
#  (523, 'Less than 1000'),
#  (487, 'Less than 1000'),
#  (454, 'Less than 1000'),
#  (508, 'Less than 1000'),
#  (459, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (377, 'Less than 1000'),
#  (364, 'Less than 1000'),
#  (336, 'Less than 1000'),
#  (326, 'Less than 1000'),
#  (354, 'Less than 1000'),
#  (339, 'Less than 1000'),
#  (539, 'Less than 1000'),
#  (509, 'Less than 1000'),
#  (510, 'Less than 1000'),
#  (604, 'Less than 1000'),
#  (558, 'Less than 1000'),
#  (517, 'Less than 1000'),
#  (493, 'Less than 1000'),
#  (511, 'Less than 1000'),
#  (520, 'Less than 1000'),
#  (566, 'Less than 1000'),
#  (722, 'Less than 1000'),
#  (480, 'Less than 1000'),
#  (478, 'Less than 1000'),
#  (524, 'Less than 1000'),
#  (519, 'Less than 1000'),
#  (499, 'Less than 1000'),
#  (529, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (491, 'Less than 1000'),
#  (508, 'Less than 1000'),
#  (519, 'Less than 1000'),
#  (530, 'Less than 1000'),
#  (543, 'Less than 1000'),
#  (494, 'Less than 1000'),
#  (493, 'Less than 1000'),
#  (500, 'Less than 1000'),
#  (514, 'Less than 1000'),
#  (479, 'Less than 1000'),
#  (2250, 'At Least 2000'),
#  (533, 'Less than 1000'),
#  (496, 'Less than 1000'),
#  (530, 'Less than 1000'),
#  (540, 'Less than 1000'),
#  (514, 'Less than 1000'),
#  (541, 'Less than 1000'),
#  (598, 'Less than 1000'),
#  (450, 'Less than 1000'),
#  (519, 'Less than 1000'),
#  (520, 'Less than 1000'),
#  (619, 'Less than 1000'),
#  (531, 'Less than 1000'),
#  (503, 'Less than 1000'),
#  (508, 'Less than 1000'),
#  (518, 'Less than 1000'),
#  (526, 'Less than 1000'),
#  (596, 'Less than 1000'),
#  (481, 'Less than 1000'),
#  (499, 'Less than 1000'),
#  (195, 'Less than 1000'),
#  (491, 'Less than 1000'),
#  (521, 'Less than 1000'),
#  (311, 'Less than 1000'),
#  (343, 'Less than 1000'),
#  (505, 'Less than 1000'),
#  (636, 'Less than 1000'),
#  (519, 'Less than 1000'),
#  (539, 'Less than 1000'),
#  (368, 'Less than 1000'),
#  (565, 'Less than 1000'),
#  (535, 'Less than 1000'),
#  (487, 'Less than 1000'),
#  (541, 'Less than 1000'),
#  (526, 'Less than 1000'),
#  (514, 'Less than 1000'),
#  (583, 'Less than 1000'),
#  (683, 'Less than 1000'),
#  (1851, 'Between 1000 and 2000'),
#  (515, 'Less than 1000'),
#  (562, 'Less than 1000'),
#  (535, 'Less than 1000'),
#  (637, 'Less than 1000'),
#  (574, 'Less than 1000'),
#  (510, 'Less than 1000'),
#  (510, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (622, 'Less than 1000'),
#  (558, 'Less than 1000'),
#  (492, 'Less than 1000'),
#  (756, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (511, 'Less than 1000'),
#  (532, 'Less than 1000'),
#  (607, 'Less than 1000'),
#  (531, 'Less than 1000'),
#  (489, 'Less than 1000'),
#  (1860, 'Between 1000 and 2000'),
#  (502, 'Less than 1000'),
#  (156, 'Less than 1000'),
#  (272, 'Less than 1000'),
#  (190, 'Less than 1000'),
#  (178, 'Less than 1000'),
#  (258, 'Less than 1000'),
#  (173, 'Less than 1000'),
#  (170, 'Less than 1000'),
#  (159, 'Less than 1000'),
#  (190, 'Less than 1000'),
#  (143, 'Less than 1000'),
#  (144, 'Less than 1000'),
#  (149, 'Less than 1000'),
#  (198, 'Less than 1000'),
#  (235, 'Less than 1000'),
#  (170, 'Less than 1000'),
#  (145, 'Less than 1000'),
#  (173, 'Less than 1000'),
#  (140, 'Less than 1000'),
#  (17, 'Less than 1000'),
#  (146, 'Less than 1000'),
#  (400, 'Less than 1000'),
#  (237, 'Less than 1000'),
#  (372, 'Less than 1000'),
#  (353, 'Less than 1000'),
#  (530, 'Less than 1000'),
#  (321, 'Less than 1000'),
#  (878, 'Less than 1000'),
#  (345, 'Less than 1000'),
#  (352, 'Less than 1000'),
#  (436, 'Less than 1000'),
#  (337, 'Less than 1000'),
#  (383, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (307, 'Less than 1000'),
#  (400, 'Less than 1000'),
#  (359, 'Less than 1000'),
#  (359, 'Less than 1000'),
#  (331, 'Less than 1000'),
#  (100, 'Less than 1000'),
#  (306, 'Less than 1000'),
#  (405, 'Less than 1000'),
#  (346, 'Less than 1000'),
#  (356, 'Less than 1000'),
#  (383, 'Less than 1000'),
#  (294, 'Less than 1000'),
#  (318, 'Less than 1000'),
#  (405, 'Less than 1000'),
#  (337, 'Less than 1000'),
#  (389, 'Less than 1000'),
#  (139, 'Less than 1000'),
#  (179, 'Less than 1000'),
#  (565, 'Less than 1000'),
#  (505, 'Less than 1000'),
#  (747, 'Less than 1000'),
#  (864, 'Less than 1000'),
#  (271, 'Less than 1000'),
#  (602, 'Less than 1000'),
#  (530, 'Less than 1000'),
#  (455, 'Less than 1000'),
#  (523, 'Less than 1000'),
#  (645, 'Less than 1000'),
#  (1042, 'Between 1000 and 2000'),
#  (497, 'Less than 1000'),
#  (478, 'Less than 1000'),
#  (688, 'Less than 1000'),
#  (883, 'Less than 1000'),
#  (492, 'Less than 1000'),
#  (517, 'Less than 1000'),
#  (527, 'Less than 1000'),
#  (582, 'Less than 1000'),
#  (492, 'Less than 1000'),
#  (589, 'Less than 1000'),
#  (485, 'Less than 1000'),
#  (491, 'Less than 1000'),
#  (751, 'Less than 1000'),
#  (503, 'Less than 1000'),
#  (591, 'Less than 1000'),
#  (535, 'Less than 1000'),
#  (480, 'Less than 1000'),
#  (529, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (575, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (619, 'Less than 1000'),
#  (5078, 'At Least 2000'),
#  (517, 'Less than 1000'),
#  (725, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (1105, 'Between 1000 and 2000'),
#  (392, 'Less than 1000'),
#  (359, 'Less than 1000'),
#  (40, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (339, 'Less than 1000'),
#  (362, 'Less than 1000'),
#  (341, 'Less than 1000'),
#  (328, 'Less than 1000'),
#  (397, 'Less than 1000'),
#  (369, 'Less than 1000'),
#  (407, 'Less than 1000'),
#  (309, 'Less than 1000'),
#  (203, 'Less than 1000'),
#  (363, 'Less than 1000'),
#  (324, 'Less than 1000'),
#  (372, 'Less than 1000'),
#  (333, 'Less than 1000'),
#  (350, 'Less than 1000'),
#  (352, 'Less than 1000'),
#  (373, 'Less than 1000'),
#  (206, 'Less than 1000'),
#  (241, 'Less than 1000'),
#  (254, 'Less than 1000'),
#  (165, 'Less than 1000'),
#  (157, 'Less than 1000'),
#  (163, 'Less than 1000'),
#  (191, 'Less than 1000'),
#  (135, 'Less than 1000'),
#  (208, 'Less than 1000'),
#  (125, 'Less than 1000'),
#  (178, 'Less than 1000'),
#  (158, 'Less than 1000'),
#  (164, 'Less than 1000'),
#  (195, 'Less than 1000'),
#  (133, 'Less than 1000'),
#  (175, 'Less than 1000'),
#  (11509, 'At Least 2000'),
#  (155, 'Less than 1000'),
#  (111, 'Less than 1000'),
#  (199, 'Less than 1000'),
#  (215, 'Less than 1000'),
#  (133, 'Less than 1000'),
#  (143, 'Less than 1000'),
#  (127, 'Less than 1000'),
#  (179, 'Less than 1000'),
#  (102, 'Less than 1000'),
#  (126, 'Less than 1000'),
#  (194, 'Less than 1000'),
#  (135, 'Less than 1000'),
#  (112, 'Less than 1000'),
#  (151, 'Less than 1000'),
#  (140, 'Less than 1000'),
#  (198, 'Less than 1000'),
#  (178, 'Less than 1000'),
#  (136, 'Less than 1000'),
#  (268, 'Less than 1000'),
#  (147, 'Less than 1000'),
#  (305, 'Less than 1000'),
#  (436, 'Less than 1000'),
#  (79, 'Less than 1000'),
#  (323, 'Less than 1000'),
#  (309, 'Less than 1000'),
#  (364, 'Less than 1000'),
#  (339, 'Less than 1000'),
#  (514, 'Less than 1000'),
#  (495, 'Less than 1000'),
#  (514, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (526, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (486, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (491, 'Less than 1000'),
#  (1149, 'Between 1000 and 2000'),
#  (530, 'Less than 1000'),
#  (502, 'Less than 1000'),
#  (528, 'Less than 1000'),
#  (120, 'Less than 1000'),
#  (134, 'Less than 1000'),
#  (172, 'Less than 1000'),
#  (238, 'Less than 1000'),
#  (163, 'Less than 1000'),
#  (81, 'Less than 1000'),
#  (325, 'Less than 1000'),
#  (399, 'Less than 1000'),
#  (348, 'Less than 1000'),
#  (309, 'Less than 1000'),
#  (111, 'Less than 1000'),
#  (160, 'Less than 1000'),
#  (318, 'Less than 1000'),
#  (161, 'Less than 1000'),
#  (146, 'Less than 1000'),
#  (590, 'Less than 1000'),
#  (529, 'Less than 1000'),
#  (481, 'Less than 1000'),
#  (583, 'Less than 1000'),
#  (381, 'Less than 1000'),
#  (327, 'Less than 1000'),
#  (329, 'Less than 1000'),
#  (333, 'Less than 1000'),
#  (360, 'Less than 1000'),
#  (483, 'Less than 1000'),
#  (309, 'Less than 1000'),
#  (401, 'Less than 1000'),
#  (301, 'Less than 1000'),
#  (464, 'Less than 1000'),
#  (407, 'Less than 1000'),
#  (1724, 'Between 1000 and 2000'),
#  (679, 'Less than 1000'),
#  (379, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (335, 'Less than 1000'),
#  (350, 'Less than 1000'),
#  (305, 'Less than 1000'),
#  (350, 'Less than 1000'),
#  (332, 'Less than 1000'),
#  (512, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (500, 'Less than 1000'),
#  (366, 'Less than 1000'),
#  (320, 'Less than 1000'),
#  (370, 'Less than 1000'),
#  (340, 'Less than 1000'),
#  (347, 'Less than 1000'),
#  (420, 'Less than 1000'),
#  (393, 'Less than 1000'),
#  (329, 'Less than 1000'),
#  (322, 'Less than 1000'),
#  (424, 'Less than 1000'),
#  (349, 'Less than 1000'),
#  (358, 'Less than 1000'),
#  (1272, 'Between 1000 and 2000'),
#  (203, 'Less than 1000'),
#  (574, 'Less than 1000'),
#  (392, 'Less than 1000'),
#  (372, 'Less than 1000'),
#  (328, 'Less than 1000'),
#  (337, 'Less than 1000'),
#  (368, 'Less than 1000'),
#  (458, 'Less than 1000'),
#  (358, 'Less than 1000'),
#  (427, 'Less than 1000'),
#  (382, 'Less than 1000'),
#  (312, 'Less than 1000'),
#  (525, 'Less than 1000'),
#  (329, 'Less than 1000'),
#  (292, 'Less than 1000'),
#  (342, 'Less than 1000'),
#  (339, 'Less than 1000'),
#  (305, 'Less than 1000'),
#  (348, 'Less than 1000'),
#  (352, 'Less than 1000'),
#  (350, 'Less than 1000'),
#  (207, 'Less than 1000'),
#  (325, 'Less than 1000'),
#  (389, 'Less than 1000'),
#  (289, 'Less than 1000'),
#  (539, 'Less than 1000'),
#  (527, 'Less than 1000'),
#  (509, 'Less than 1000'),
#  (587, 'Less than 1000'),
#  (607, 'Less than 1000'),
#  (476, 'Less than 1000'),
#  (536, 'Less than 1000'),
#  (586, 'Less than 1000'),
#  (540, 'Less than 1000'),
#  (537, 'Less than 1000'),
#  (537, 'Less than 1000'),
#  (551, 'Less than 1000'),
#  (536, 'Less than 1000'),
#  (604, 'Less than 1000'),
#  (1091, 'Between 1000 and 2000'),
#  (526, 'Less than 1000'),
#  (536, 'Less than 1000'),
#  (537, 'Less than 1000'),
#  (506, 'Less than 1000'),
#  (811, 'Less than 1000'),
#  (498, 'Less than 1000'),
#  (508, 'Less than 1000'),
#  (679, 'Less than 1000'),
#  (549, 'Less than 1000'),
#  (613, 'Less than 1000'),
#  (546, 'Less than 1000'),
#  (703, 'Less than 1000'),
#  (701, 'Less than 1000'),
#  (531, 'Less than 1000'),
#  (533, 'Less than 1000'),
#  (544, 'Less than 1000'),
#  (510, 'Less than 1000'),
#  (587, 'Less than 1000'),
#  (517, 'Less than 1000'),
#  (612, 'Less than 1000'),
#  (479, 'Less than 1000'),
#  (336, 'Less than 1000'),
#  (544, 'Less than 1000'),
#  (321, 'Less than 1000'),
#  (338, 'Less than 1000'),
#  (366, 'Less than 1000'),
#  (368, 'Less than 1000'),
#  (289, 'Less than 1000'),
#  (368, 'Less than 1000'),
#  (277, 'Less than 1000'),
#  (345, 'Less than 1000'),
#  (306, 'Less than 1000'),
#  (370, 'Less than 1000'),
#  (355, 'Less than 1000'),
#  (345, 'Less than 1000'),
#  (347, 'Less than 1000'),
#  (340, 'Less than 1000'),
#  (394, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (351, 'Less than 1000'),
#  (363, 'Less than 1000'),
#  (247, 'Less than 1000'),
#  (294, 'Less than 1000'),
#  (64, 'Less than 1000'),
#  (327, 'Less than 1000'),
#  (374, 'Less than 1000'),
#  (230, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (411, 'Less than 1000'),
#  (342, 'Less than 1000'),
#  (272, 'Less than 1000'),
#  (390, 'Less than 1000'),
#  (381, 'Less than 1000'),
#  (361, 'Less than 1000'),
#  (301, 'Less than 1000'),
#  (348, 'Less than 1000'),
#  (388, 'Less than 1000'),
#  (392, 'Less than 1000'),
#  (153, 'Less than 1000'),
#  (160, 'Less than 1000'),
#  (136, 'Less than 1000'),
#  (306, 'Less than 1000'),
#  (352, 'Less than 1000'),
#  (362, 'Less than 1000'),
#  (405, 'Less than 1000'),
#  (301, 'Less than 1000'),
#  (378, 'Less than 1000'),
#  (436, 'Less than 1000'),
#  (354, 'Less than 1000'),
#  (357, 'Less than 1000'),
#  (324, 'Less than 1000'),
#  (350, 'Less than 1000'),
#  (348, 'Less than 1000'),
#  (307, 'Less than 1000'),
#  (434, 'Less than 1000'),
#  (350, 'Less than 1000'),
#  (351, 'Less than 1000'),
#  (318, 'Less than 1000'),
#  (316, 'Less than 1000'),
#  (255, 'Less than 1000'),
#  (422, 'Less than 1000'),
#  (333, 'Less than 1000'),
#  (321, 'Less than 1000'),
#  (415, 'Less than 1000'),
#  (453, 'Less than 1000'),
#  (360, 'Less than 1000'),
#  (379, 'Less than 1000'),
#  (399, 'Less than 1000'),
#  (363, 'Less than 1000'),
#  (339, 'Less than 1000'),
#  (356, 'Less than 1000'),
#  (338, 'Less than 1000'),
#  (416, 'Less than 1000'),
#  (392, 'Less than 1000'),
#  (329, 'Less than 1000'),
#  (373, 'Less than 1000'),
#  (371, 'Less than 1000'),
#  (448, 'Less than 1000'),
#  (337, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (325, 'Less than 1000'),
#  (372, 'Less than 1000'),
#  (359, 'Less than 1000'),
#  (340, 'Less than 1000'),
#  (335, 'Less than 1000'),
#  (412, 'Less than 1000'),
#  (306, 'Less than 1000'),
#  (341, 'Less than 1000'),
#  (381, 'Less than 1000'),
#  (363, 'Less than 1000'),
#  (355, 'Less than 1000'),
#  (425, 'Less than 1000'),
#  (1112, 'Between 1000 and 2000'),
#  (303, 'Less than 1000'),
#  (336, 'Less than 1000'),
#  (349, 'Less than 1000'),
#  (388, 'Less than 1000'),
#  (338, 'Less than 1000'),
#  (374, 'Less than 1000'),
#  (345, 'Less than 1000'),
#  (334, 'Less than 1000'),
#  (327, 'Less than 1000'),
#  (344, 'Less than 1000'),
#  (364, 'Less than 1000'),
#  (517, 'Less than 1000'),
#  (338, 'Less than 1000'),
#  (367, 'Less than 1000'),
#  (306, 'Less than 1000'),
#  (327, 'Less than 1000'),
#  (337, 'Less than 1000'),
#  (511, 'Less than 1000'),
#  (515, 'Less than 1000'),
#  (515, 'Less than 1000'),
#  (835, 'Less than 1000'),
#  (487, 'Less than 1000'),
#  (540, 'Less than 1000'),
#  (490, 'Less than 1000'),
#  (430, 'Less than 1000'),
#  (500, 'Less than 1000'),
#  (499, 'Less than 1000'),
#  (496, 'Less than 1000'),
#  (742, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (530, 'Less than 1000'),
#  (159, 'Less than 1000'),
#  (154, 'Less than 1000'),
#  (315, 'Less than 1000'),
#  (700, 'Less than 1000'),
#  (569, 'Less than 1000'),
#  (353, 'Less than 1000'),
#  (373, 'Less than 1000'),
#  (382, 'Less than 1000'),
#  (395, 'Less than 1000'),
#  (352, 'Less than 1000'),
#  (377, 'Less than 1000'),
#  (314, 'Less than 1000'),
#  (494, 'Less than 1000'),
#  (362, 'Less than 1000'),
#  (320, 'Less than 1000'),
#  (371, 'Less than 1000'),
#  (340, 'Less than 1000'),
#  (357, 'Less than 1000'),
#  (410, 'Less than 1000'),
#  (331, 'Less than 1000'),
#  (333, 'Less than 1000'),
#  (342, 'Less than 1000'),
#  (297, 'Less than 1000'),
#  (188, 'Less than 1000'),
#  (336, 'Less than 1000'),
#  (334, 'Less than 1000'),
#  (373, 'Less than 1000'),
#  (358, 'Less than 1000'),
#  (376, 'Less than 1000'),
#  (344, 'Less than 1000'),
#  (322, 'Less than 1000'),
#  (372, 'Less than 1000'),
#  (333, 'Less than 1000'),
#  (417, 'Less than 1000'),
#  (338, 'Less than 1000'),
#  (390, 'Less than 1000'),
#  (326, 'Less than 1000'),
#  (496, 'Less than 1000'),
#  (297, 'Less than 1000'),
#  (335, 'Less than 1000'),
#  (31, 'Less than 1000'),
#  (371, 'Less than 1000'),
#  (357, 'Less than 1000'),
#  (321, 'Less than 1000'),
#  (328, 'Less than 1000'),
#  (454, 'Less than 1000'),
#  (349, 'Less than 1000'),
#  (361, 'Less than 1000'),
#  (379, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (524, 'Less than 1000'),
#  (511, 'Less than 1000'),
#  (438, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (489, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (465, 'Less than 1000'),
#  (516, 'Less than 1000'),
#  (566, 'Less than 1000'),
#  (292, 'Less than 1000'),
#  (483, 'Less than 1000'),
#  (509, 'Less than 1000'),
#  (513, 'Less than 1000'),
#  (601, 'Less than 1000'),
#  (621, 'Less than 1000'),
#  (438, 'Less than 1000'),
#  (567, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (506, 'Less than 1000'),
#  (566, 'Less than 1000'),
#  (18, 'Less than 1000'),
#  (586, 'Less than 1000'),
#  (524, 'Less than 1000'),
#  (497, 'Less than 1000'),
#  (509, 'Less than 1000'),
#  (576, 'Less than 1000'),
#  (547, 'Less than 1000'),
#  (521, 'Less than 1000'),
#  (891, 'Less than 1000'),
#  (488, 'Less than 1000'),
#  (486, 'Less than 1000'),
#  (520, 'Less than 1000'),
#  (554, 'Less than 1000'),
#  (756, 'Less than 1000'),
#  (494, 'Less than 1000'),
#  (565, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (2, 'Less than 1000'),
#  (12598, 'At Least 2000'),
#  (520, 'Less than 1000'),
#  (560, 'Less than 1000'),
#  (486, 'Less than 1000'),
#  (471, 'Less than 1000'),
#  (532, 'Less than 1000'),
#  (519, 'Less than 1000'),
#  (664, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (307, 'Less than 1000'),
#  (500, 'Less than 1000'),
#  (508, 'Less than 1000'),
#  (515, 'Less than 1000'),
#  (526, 'Less than 1000'),
#  (496, 'Less than 1000'),
#  (498, 'Less than 1000'),
#  (531, 'Less than 1000'),
#  (585, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (518, 'Less than 1000'),
#  (506, 'Less than 1000'),
#  (520, 'Less than 1000'),
#  (606, 'Less than 1000'),
#  (457, 'Less than 1000'),
#  (499, 'Less than 1000'),
#  (404, 'Less than 1000'),
#  (514, 'Less than 1000'),
#  (496, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (498, 'Less than 1000'),
#  (603, 'Less than 1000'),
#  (495, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (596, 'Less than 1000'),
#  (510, 'Less than 1000'),
#  (506, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (528, 'Less than 1000'),
#  (570, 'Less than 1000'),
#  (778, 'Less than 1000'),
#  (689, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (514, 'Less than 1000'),
#  (518, 'Less than 1000'),
#  (542, 'Less than 1000'),
#  (541, 'Less than 1000'),
#  (156, 'Less than 1000'),
#  (265, 'Less than 1000'),
#  (179, 'Less than 1000'),
#  (151, 'Less than 1000'),
#  (166, 'Less than 1000'),
#  (226, 'Less than 1000'),
#  (121, 'Less than 1000'),
#  (148, 'Less than 1000'),
#  (182, 'Less than 1000'),
#  (313, 'Less than 1000'),
#  (131, 'Less than 1000'),
#  (235, 'Less than 1000'),
#  (150, 'Less than 1000'),
#  (132, 'Less than 1000'),
#  (182, 'Less than 1000'),
#  (185, 'Less than 1000'),
#  (167, 'Less than 1000'),
#  (322, 'Less than 1000'),
#  (489, 'Less than 1000'),
#  (298, 'Less than 1000'),
#  (362, 'Less than 1000'),
#  (332, 'Less than 1000'),
#  (357, 'Less than 1000'),
#  (306, 'Less than 1000'),
#  (368, 'Less than 1000'),
#  (472, 'Less than 1000'),
#  (38, 'Less than 1000'),
#  (303, 'Less than 1000'),
#  (353, 'Less than 1000'),
#  (377, 'Less than 1000'),
#  (345, 'Less than 1000'),
#  (368, 'Less than 1000'),
#  (308, 'Less than 1000'),
#  (384, 'Less than 1000'),
#  (379, 'Less than 1000'),
#  (331, 'Less than 1000'),
#  (327, 'Less than 1000'),
#  (431, 'Less than 1000'),
#  (365, 'Less than 1000'),
#  (308, 'Less than 1000'),
#  (334, 'Less than 1000'),
#  (367, 'Less than 1000'),
#  (341, 'Less than 1000'),
#  (346, 'Less than 1000'),
#  (301, 'Less than 1000'),
#  (317, 'Less than 1000'),
#  (386, 'Less than 1000'),
#  (372, 'Less than 1000'),
#  (353, 'Less than 1000'),
#  (300, 'Less than 1000'),
#  (394, 'Less than 1000'),
#  (325, 'Less than 1000'),
#  (288, 'Less than 1000'),
#  (334, 'Less than 1000'),
#  (346, 'Less than 1000'),
#  (363, 'Less than 1000'),
#  (567, 'Less than 1000'),
#  (508, 'Less than 1000'),
#  (513, 'Less than 1000'),
#  (608, 'Less than 1000'),
#  (535, 'Less than 1000'),
#  (564, 'Less than 1000'),
#  (560, 'Less than 1000'),
#  (531, 'Less than 1000'),
#  (525, 'Less than 1000'),
#  (532, 'Less than 1000'),
#  (535, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (493, 'Less than 1000'),
#  (512, 'Less than 1000'),
#  (576, 'Less than 1000'),
#  (523, 'Less than 1000'),
#  (646, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (653, 'Less than 1000'),
#  (483, 'Less than 1000'),
#  (518, 'Less than 1000'),
#  (785, 'Less than 1000'),
#  (497, 'Less than 1000'),
#  (519, 'Less than 1000'),
#  (503, 'Less than 1000'),
#  (518, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (2, 'Less than 1000'),
#  (701, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (493, 'Less than 1000'),
#  (510, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (532, 'Less than 1000'),
#  (599, 'Less than 1000'),
#  (523, 'Less than 1000'),
#  (592, 'Less than 1000'),
#  (534, 'Less than 1000'),
#  (188, 'Less than 1000'),
#  (389, 'Less than 1000'),
#  (1620, 'Between 1000 and 2000'),
#  (163, 'Less than 1000'),
#  (189, 'Less than 1000'),
#  (256, 'Less than 1000'),
#  (169, 'Less than 1000'),
#  (150, 'Less than 1000'),
#  (104, 'Less than 1000'),
#  (477, 'Less than 1000'),
#  (638, 'Less than 1000'),
#  (520, 'Less than 1000'),
#  (551, 'Less than 1000'),
#  (524, 'Less than 1000'),
#  (503, 'Less than 1000'),
#  (585, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (479, 'Less than 1000'),
#  (743, 'Less than 1000'),
#  (512, 'Less than 1000'),
#  (484, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (517, 'Less than 1000'),
#  (503, 'Less than 1000'),
#  (544, 'Less than 1000'),
#  (1102, 'Between 1000 and 2000'),
#  (515, 'Less than 1000'),
#  (74, 'Less than 1000'),
#  (553, 'Less than 1000'),
#  (522, 'Less than 1000'),
#  (568, 'Less than 1000'),
#  (547, 'Less than 1000'),
#  (556, 'Less than 1000'),
#  (488, 'Less than 1000'),
#  (580, 'Less than 1000'),
#  (478, 'Less than 1000'),
#  (524, 'Less than 1000'),
#  (521, 'Less than 1000'),
#  (494, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (20, 'Less than 1000'),
#  (616, 'Less than 1000'),
#  (511, 'Less than 1000'),
#  (535, 'Less than 1000'),
#  (586, 'Less than 1000'),
#  (612, 'Less than 1000'),
#  (512, 'Less than 1000'),
#  (509, 'Less than 1000'),
#  (501, 'Less than 1000'),
#  (497, 'Less than 1000'),
#  (528, 'Less than 1000'),
#  (540, 'Less than 1000'),
#  (533, 'Less than 1000'),
#  (430, 'Less than 1000'),
#  (464, 'Less than 1000'),
#  (13, 'Less than 1000'),
#  (507, 'Less than 1000'),
#  (548, 'Less than 1000'),
#  (538, 'Less than 1000'),
#  (26, 'Less than 1000'),
#  (575, 'Less than 1000'),
#  (520, 'Less than 1000'),
#  (529, 'Less than 1000'),
#  (208, 'Less than 1000'),
#  (275, 'Less than 1000'),
#  (143, 'Less than 1000'),
#  (146, 'Less than 1000'),
#  (184, 'Less than 1000'),
#  (150, 'Less than 1000'),
#  (139, 'Less than 1000'),
#  (110, 'Less than 1000'),
#  (356, 'Less than 1000'),
#  (390, 'Less than 1000'),
#  (330, 'Less than 1000'),
#  (338, 'Less than 1000'),
#  (161, 'Less than 1000'),
#  (186, 'Less than 1000'),
#  (40, 'Less than 1000'),
#  (174, 'Less than 1000'),
#  (187, 'Less than 1000'),
#  (215, 'Less than 1000'),
#  (95, 'Less than 1000'),
#  (151, 'Less than 1000'),
#  (138, 'Less than 1000'),
#  (162, 'Less than 1000'),
#  (181, 'Less than 1000'),
#  (171, 'Less than 1000'),
#  (177, 'Less than 1000'),
#  (188, 'Less than 1000'),
#  (302, 'Less than 1000'),
#  (131, 'Less than 1000'),
#  (176, 'Less than 1000'),
#  (139, 'Less than 1000'),
#  (191, 'Less than 1000'),
#  (155, 'Less than 1000'),
#  (177, 'Less than 1000'),
#  (157, 'Less than 1000'),
#  (284, 'Less than 1000'),
#  (170, 'Less than 1000'),
#  (146, 'Less than 1000'),
#  (32, 'Less than 1000'),
#  (374, 'Less than 1000'),
#  (205, 'Less than 1000'),
#  (153, 'Less than 1000'),
#  (163, 'Less than 1000'),
#  (615, 'Less than 1000'),
#  (1217, 'Between 1000 and 2000'),
#  (513, 'Less than 1000'),
#  (509, 'Less than 1000'),
#  (502, 'Less than 1000'),
#  (490, 'Less than 1000'),
#  (609, 'Less than 1000'),
#  (511, 'Less than 1000'),
#  (164, 'Less than 1000'),
#  (360, 'Less than 1000'),
#  (340, 'Less than 1000'),
#  (764, 'Less than 1000'),
#  (392, 'Less than 1000'),
#  (316, 'Less than 1000'),
#  (1104, 'Between 1000 and 2000'),
#  (345, 'Less than 1000'),
#  (364, 'Less than 1000'),
#  (785, 'Less than 1000'),
#  (521, 'Less than 1000'),
#  (619, 'Less than 1000'),
#  (547, 'Less than 1000'),
#  (530, 'Less than 1000'),
#  (504, 'Less than 1000'),
#  (439, 'Less than 1000'),
#  ...]

# %% [markdown]
# #### 41. We would like to understand 3 different levels of customers based on the amount associated with their purchases. The top level includes anyone with a Lifetime Value (total sales of all orders) greater than 200,000 USD. The second level is between 200,000 and 100,000 USD. The lowest level is anyone under 100,000 USD. Provide a table that includes the level associated with each account. You should provide the account name, the total sales of all orders for the customer, and the level. Order with the top spending customers listed first.

# %%
# %%sql
#
# WITH sales_cte AS (
# SELECT
#     company,
#     SUM(total_amt_usd) AS total_spend
# FROM orders_consolidated
# GROUP BY company
# )
# SELECT
#     company,
#     total_spend,
#     CASE
#         WHEN total_spend < 100000 THEN 'Lowest level'
#         WHEN total_spend >= 100000 AND total_spend <= 200000 THEN 'Second level'
#         WHEN total_spend > 200000 THEN 'Highest level' END AS customer_level
# FROM sales_cte
# ORDER BY total_spend DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 350 rows affected.
# [('EOG Resources', Decimal('382873.30'), 'Highest level'),
#  ('Mosaic', Decimal('345618.59'), 'Highest level'),
#  ('IBM', Decimal('326819.48'), 'Highest level'),
#  ('General Dynamics', Decimal('300694.79'), 'Highest level'),
#  ('Republic Services', Decimal('293861.14'), 'Highest level'),
#  ('Leucadia National', Decimal('291047.25'), 'Highest level'),
#  ('Arrow Electronics', Decimal('281018.36'), 'Highest level'),
#  ('Sysco', Decimal('278575.64'), 'Highest level'),
#  ('Supervalu', Decimal('275288.30'), 'Highest level'),
#  ('Archer Daniels Midland', Decimal('272672.84'), 'Highest level'),
#  ('Western Digital', Decimal('269155.34'), 'Highest level'),
#  ('Pacific Life', Decimal('255319.18'), 'Highest level'),
#  ('DISH Network', Decimal('253635.75'), 'Highest level'),
#  ('Fluor', Decimal('251299.77'), 'Highest level'),
#  ('United States Steel', Decimal('244695.99'), 'Highest level'),
#  ('Avis Budget Group', Decimal('241711.25'), 'Highest level'),
#  ('Centene', Decimal('238962.47'), 'Highest level'),
#  ('Aetna', Decimal('237781.30'), 'Highest level'),
#  ('United Technologies', Decimal('235051.07'), 'Highest level'),
#  ('Freddie Mac', Decimal('234225.65'), 'Highest level'),
#  ('Core-Mark Holding', Decimal('231856.98'), 'Highest level'),
#  ('KKR', Decimal('217473.85'), 'Highest level'),
#  ('Disney', Decimal('205886.97'), 'Highest level'),
#  ('Wells Fargo', Decimal('200174.66'), 'Highest level'),
#  ('Bristol-Myers Squibb', Decimal('188457.46'), 'Second level'),
#  ('Goodyear Tire & Rubber', Decimal('185463.76'), 'Second level'),
#  ('Jarden', Decimal('179761.43'), 'Second level'),
#  ('Intel', Decimal('167717.40'), 'Second level'),
#  ('CHS', Decimal('167271.80'), 'Second level'),
#  ('Best Buy', Decimal('163887.39'), 'Second level'),
#  ('ADP', Decimal('163579.18'), 'Second level'),
#  ('Paccar', Decimal('161294.62'), 'Second level'),
#  ('Citigroup', Decimal('160051.04'), 'Second level'),
#  ('Prudential Financial', Decimal('157782.52'), 'Second level'),
#  ('Guardian Life Ins. Co. of America', Decimal('157523.24'), 'Second level'),
#  ('Travelers Cos.', Decimal('156582.24'), 'Second level'),
#  ('Ford Motor', Decimal('154811.43'), 'Second level'),
#  ('Thermo Fisher Scientific', Decimal('153705.10'), 'Second level'),
#  ('American Family Insurance Group', Decimal('153015.87'), 'Second level'),
#  ('BlackRock', Decimal('147599.56'), 'Second level'),
#  ('Pfizer', Decimal('144865.83'), 'Second level'),
#  ('Emerson Electric', Decimal('143471.26'), 'Second level'),
#  ('TJX', Decimal('140046.68'), 'Second level'),
#  ('Sears Holdings', Decimal('139015.09'), 'Second level'),
#  ("Land O'Lakes", Decimal('138323.59'), 'Second level'),
#  ('Philip Morris International', Decimal('137600.67'), 'Second level'),
#  ('Marathon Petroleum', Decimal('137227.88'), 'Second level'),
#  ('Charter Communications', Decimal('135924.15'), 'Second level'),
#  ('AutoNation', Decimal('135822.85'), 'Second level'),
#  ('Franklin Resources', Decimal('135730.44'), 'Second level'),
#  ('Ecolab', Decimal('135517.95'), 'Second level'),
#  ('Synnex', Decimal('134039.25'), 'Second level'),
#  ('FirstEnergy', Decimal('132868.82'), 'Second level'),
#  ('National Oilwell Varco', Decimal('131318.64'), 'Second level'),
#  ('Phillips 66', Decimal('131173.41'), 'Second level'),
#  ('Monsanto', Decimal('130964.11'), 'Second level'),
#  ('Cisco Systems', Decimal('130917.00'), 'Second level'),
#  ('Colgate-Palmolive', Decimal('130893.51'), 'Second level'),
#  ('Walgreens Boots Alliance', Decimal('130153.59'), 'Second level'),
#  ('3M', Decimal('127945.10'), 'Second level'),
#  ('Cigna', Decimal('127671.94'), 'Second level'),
#  ('New York Life Insurance', Decimal('126898.91'), 'Second level'),
#  ('Southwest Airlines', Decimal('125968.04'), 'Second level'),
#  ('Walmart', Decimal('124014.87'), 'Second level'),
#  ('BB&T Corp.', Decimal('123847.32'), 'Second level'),
#  ('Entergy', Decimal('123503.18'), 'Second level'),
#  ('CST Brands', Decimal('122957.11'), 'Second level'),
#  ('Target', Decimal('120523.91'), 'Second level'),
#  ('FedEx', Decimal('119965.08'), 'Second level'),
#  ('State Street Corp.', Decimal('119173.59'), 'Second level'),
#  ('United Continental Holdings', Decimal('118879.76'), 'Second level'),
#  ('Duke Energy', Decimal('118867.17'), 'Second level'),
#  ('Aflac', Decimal('117862.77'), 'Second level'),
#  ('Altria Group', Decimal('116165.15'), 'Second level'),
#  ('Verizon', Decimal('115376.17'), 'Second level'),
#  ('PPL', Decimal('112176.03'), 'Second level'),
#  ('State Farm Insurance Cos.', Decimal('111810.55'), 'Second level'),
#  ('Fidelity National Financial', Decimal('110027.29'), 'Second level'),
#  ('Western Refining', Decimal('108579.84'), 'Second level'),
#  ('Lithia Motors', Decimal('107142.63'), 'Second level'),
#  ('Occidental Petroleum', Decimal('105115.44'), 'Second level'),
#  ('CDW', Decimal('101553.15'), 'Second level'),
#  ('SunTrust Banks', Decimal('99125.76'), 'Lowest level'),
#  ('D.R. Horton', Decimal('98474.44'), 'Lowest level'),
#  ('Abbott Laboratories', Decimal('96819.92'), 'Lowest level'),
#  ('Allstate', Decimal('96779.18'), 'Lowest level'),
#  ('Celgene', Decimal('96593.53'), 'Lowest level'),
#  ('Farmers Insurance Exchange', Decimal('96376.94'), 'Lowest level'),
#  ('Raytheon', Decimal('94725.92'), 'Lowest level'),
#  ('J.P. Morgan Chase', Decimal('94684.25'), 'Lowest level'),
#  ('eBay', Decimal('94244.44'), 'Lowest level'),
#  ('Bank of America Corp.', Decimal('93217.80'), 'Lowest level'),
#  ("Kohl's", Decimal('90105.16'), 'Lowest level'),
#  ('Hormel Foods', Decimal('88946.14'), 'Lowest level'),
#  ('Honeywell International', Decimal('86362.70'), 'Lowest level'),
#  ('PayPal Holdings', Decimal('84768.94'), 'Lowest level'),
#  ('Kellogg', Decimal('83419.38'), 'Lowest level'),
#  ('Amgen', Decimal('82013.05'), 'Lowest level'),
#  ('Caterpillar', Decimal('81700.33'), 'Lowest level'),
#  ('PG&E Corp.', Decimal('81697.27'), 'Lowest level'),
#  ('Anadarko Petroleum', Decimal('80328.56'), 'Lowest level'),
#  ('HollyFrontier', Decimal('79488.37'), 'Lowest level'),
#  ('Jabil Circuit', Decimal('79246.93'), 'Lowest level'),
#  ('Lincoln National', Decimal('77628.11'), 'Lowest level'),
#  ('Nationwide', Decimal('76630.92'), 'Lowest level'),
#  ('Jacobs Engineering Group', Decimal('75600.49'), 'Lowest level'),
#  ('Broadcom', Decimal('75130.50'), 'Lowest level'),
#  ('Crown Holdings', Decimal('75110.81'), 'Lowest level'),
#  ('Public Service Enterprise Group', Decimal('73833.01'), 'Lowest level'),
#  ('Progressive', Decimal('72875.84'), 'Lowest level'),
#  ('Stanley Black & Decker', Decimal('72788.52'), 'Lowest level'),
#  ('Capital One Financial', Decimal('72595.01'), 'Lowest level'),
#  ('Time Warner', Decimal('69479.06'), 'Lowest level'),
#  ('Global Partners', Decimal('67909.96'), 'Lowest level'),
#  ('Cameron International', Decimal('67459.65'), 'Lowest level'),
#  ('Illinois Tool Works', Decimal('67439.95'), 'Lowest level'),
#  ('Avnet', Decimal('66812.24'), 'Lowest level'),
#  ('Molina Healthcare', Decimal('66381.57'), 'Lowest level'),
#  ('AutoZone', Decimal('65958.07'), 'Lowest level'),
#  ('Boeing', Decimal('65091.39'), 'Lowest level'),
#  ('Dominion Resources', Decimal('64604.00'), 'Lowest level'),
#  ('Merck', Decimal('64536.17'), 'Lowest level'),
#  ('CarMax', Decimal('64251.56'), 'Lowest level'),
#  ('Precision Castparts', Decimal('63743.89'), 'Lowest level'),
#  ('Cognizant Technology Solutions', Decimal('62504.05'), 'Lowest level'),
#  ('Gilead Sciences', Decimal('62148.87'), 'Lowest level'),
#  ('Genuine Parts', Decimal('61561.44'), 'Lowest level'),
#  ('Visa', Decimal('61255.50'), 'Lowest level'),
#  ('Nucor', Decimal('60936.18'), 'Lowest level'),
#  ('Kroger', Decimal('59946.40'), 'Lowest level'),
#  ('NRG Energy', Decimal('59727.21'), 'Lowest level'),
#  ('International Paper', Decimal('59086.76'), 'Lowest level'),
#  ('Time Warner Cable', Decimal('57130.53'), 'Lowest level'),
#  ('Eversource Energy', Decimal('57059.76'), 'Lowest level'),
#  ('Discover Financial Services', Decimal('57035.05'), 'Lowest level'),
#  ('Community Health Systems', Decimal('56644.60'), 'Lowest level'),
#  ("Toys 'R' Us", Decimal('56179.21'), 'Lowest level'),
#  ('HP', Decimal('56162.34'), 'Lowest level'),
#  ('Ameriprise Financial', Decimal('55883.55'), 'Lowest level'),
#  ('Kinder Morgan', Decimal('54891.56'), 'Lowest level'),
#  ('Texas Instruments', Decimal('54792.72'), 'Lowest level'),
#  ('United Natural Foods', Decimal('54443.06'), 'Lowest level'),
#  ('Qualcomm', Decimal('54114.02'), 'Lowest level'),
#  ('Valero Energy', Decimal('52020.60'), 'Lowest level'),
#  ('AT&T', Decimal('51647.76'), 'Lowest level'),
#  ('Office Depot', Decimal('51477.19'), 'Lowest level'),
#  ('HD Supply Holdings', Decimal('50888.03'), 'Lowest level'),
#  ('Dollar General', Decimal('49975.93'), 'Lowest level'),
#  ('Reynolds American', Decimal('49930.29'), 'Lowest level'),
#  ('Freeport-McMoRan', Decimal('49162.70'), 'Lowest level'),
#  ('Northrop Grumman', Decimal('48578.16'), 'Lowest level'),
#  ('Performance Food Group', Decimal('47645.86'), 'Lowest level'),
#  ('Anthem', Decimal('47487.78'), 'Lowest level'),
#  ('Tyson Foods', Decimal('47417.76'), 'Lowest level'),
#  ("McDonald's", Decimal('47258.13'), 'Lowest level'),
#  ('USAA', Decimal('46822.63'), 'Lowest level'),
#  ('Chevron', Decimal('46725.41'), 'Lowest level'),
#  ('PNC Financial Services Group', Decimal('46208.37'), 'Lowest level'),
#  ('First Data', Decimal('45967.25'), 'Lowest level'),
#  ("Lowe's", Decimal('45873.47'), 'Lowest level'),
#  ('American Express', Decimal('45557.51'), 'Lowest level'),
#  ('CenturyLink', Decimal('44535.04'), 'Lowest level'),
#  ('Chesapeake Energy', Decimal('44534.95'), 'Lowest level'),
#  ('Alphabet', Decimal('44407.22'), 'Lowest level'),
#  ('Coca-Cola', Decimal('43692.29'), 'Lowest level'),
#  ('Southern', Decimal('42881.21'), 'Lowest level'),
#  ('Twenty-First Century Fox', Decimal('42065.82'), 'Lowest level'),
#  ('BorgWarner', Decimal('41242.06'), 'Lowest level'),
#  ('Omnicom Group', Decimal('41161.06'), 'Lowest level'),
#  ('NGL Energy Partners', Decimal('40607.07'), 'Lowest level'),
#  ('Icahn Enterprises', Decimal('38851.15'), 'Lowest level'),
#  ('AmerisourceBergen', Decimal('38741.81'), 'Lowest level'),
#  ('Hilton Worldwide Holdings', Decimal('38648.01'), 'Lowest level'),
#  ('Sempra Energy', Decimal('38569.85'), 'Lowest level'),
#  ('GameStop', Decimal('38469.65'), 'Lowest level'),
#  ('Thrivent Financial for Lutherans', Decimal('38204.46'), 'Lowest level'),
#  ('Estee Lauder', Decimal('38198.82'), 'Lowest level'),
#  ('Johnson Controls', Decimal('37796.28'), 'Lowest level'),
#  ('Ally Financial', Decimal('37653.96'), 'Lowest level'),
#  ('Mondelez International', Decimal('37465.37'), 'Lowest level'),
#  ('Edison International', Decimal('37010.95'), 'Lowest level'),
#  ('EMC', Decimal('36982.12'), 'Lowest level'),
#  ('Murphy USA', Decimal('36294.27'), 'Lowest level'),
#  ('R.R. Donnelley & Sons', Decimal('36218.43'), 'Lowest level'),
#  ('Becton Dickinson', Decimal('35961.76'), 'Lowest level'),
#  ('CSX', Decimal('35759.70'), 'Lowest level'),
#  ('Henry Schein', Decimal('35487.34'), 'Lowest level'),
#  ('Cummins', Decimal('34839.82'), 'Lowest level'),
#  ('News Corp.', Decimal('34675.03'), 'Lowest level'),
#  ('DaVita HealthCare Partners', Decimal('33982.78'), 'Lowest level'),
#  ('Viacom', Decimal('33673.86'), 'Lowest level'),
#  ('Tenet Healthcare', Decimal('33028.08'), 'Lowest level'),
#  ('Whirlpool', Decimal('32965.13'), 'Lowest level'),
#  ('Humana', Decimal('32937.93'), 'Lowest level'),
#  ('Halliburton', Decimal('32645.38'), 'Lowest level'),
#  ('General Mills', Decimal('32226.37'), 'Lowest level'),
#  ('American Electric Power', Decimal('32044.55'), 'Lowest level'),
#  ('Enterprise Products Partners', Decimal('31971.72'), 'Lowest level'),
#  ('Nordstrom', Decimal('31273.02'), 'Lowest level'),
#  ('Oracle', Decimal('31231.56'), 'Lowest level'),
#  ('Costco', Decimal('30741.01'), 'Lowest level'),
#  ('Group 1 Automotive', Decimal('30708.92'), 'Lowest level'),
#  ('PepsiCo', Decimal('30095.72'), 'Lowest level'),
#  ('American Airlines Group', Decimal('30083.18'), 'Lowest level'),
#  ('Kimberly-Clark', Decimal('29151.21'), 'Lowest level'),
#  ('Amazon.com', Decimal('28678.06'), 'Lowest level'),
#  ('Yum Brands', Decimal('28296.53'), 'Lowest level'),
#  ('Computer Sciences', Decimal('28012.07'), 'Lowest level'),
#  ('Health Net', Decimal('27733.33'), 'Lowest level'),
#  ('Exelon', Decimal('27558.30'), 'Lowest level'),
#  ('US Foods Holding', Decimal('27074.63'), 'Lowest level'),
#  ('U.S. Bancorp', Decimal('26641.71'), 'Lowest level'),
#  ('Dean Foods', Decimal('26514.93'), 'Lowest level'),
#  ('Penske Automotive Group', Decimal('26485.87'), 'Lowest level'),
#  ('Textron', Decimal('26339.70'), 'Lowest level'),
#  ('Campbell Soup', Decimal('25765.95'), 'Lowest level'),
#  ('Kraft Heinz', Decimal('25765.17'), 'Lowest level'),
#  ('DuPont', Decimal('25526.30'), 'Lowest level'),
#  ('Laboratory Corp. of America', Decimal('25507.06'), 'Lowest level'),
#  ('General Electric', Decimal('25335.68'), 'Lowest level'),
#  ('Ingram Micro', Decimal('25198.55'), 'Lowest level'),
#  ('Union Pacific', Decimal('25107.81'), 'Lowest level'),
#  ('Ross Stores', Decimal('24961.87'), 'Lowest level'),
#  ('Lear', Decimal('23718.31'), 'Lowest level'),
#  ('CVS Health', Decimal('23667.51'), 'Lowest level'),
#  ('Facebook', Decimal('23522.79'), 'Lowest level'),
#  ('Procter & Gamble', Decimal('22961.03'), 'Lowest level'),
#  ('Unum Group', Decimal('22734.13'), 'Lowest level'),
#  ('Baxter International', Decimal('22681.17'), 'Lowest level'),
#  ('Navistar International', Decimal('22484.81'), 'Lowest level'),
#  ('L-3 Communications', Decimal('22266.77'), 'Lowest level'),
#  ('Norfolk Southern', Decimal('22100.01'), 'Lowest level'),
#  ('PPG Industries', Decimal('21960.88'), 'Lowest level'),
#  ('UnitedHealth Group', Decimal('21937.08'), 'Lowest level'),
#  ('Aramark', Decimal('21692.01'), 'Lowest level'),
#  ('Apple', Decimal('20767.15'), 'Lowest level'),
#  ('Morgan Stanley', Decimal('20277.57'), 'Lowest level'),
#  ('Hartford Financial Services Group', Decimal('20257.43'), 'Lowest level'),
#  ('Whole Foods Market', Decimal('20240.66'), 'Lowest level'),
#  ("Peter Kiewit Sons'", Decimal('20232.97'), 'Lowest level'),
#  ('Huntsman', Decimal('20092.35'), 'Lowest level'),
#  ('Xcel Energy', Decimal('19975.91'), 'Lowest level'),
#  ('Masco', Decimal('19963.61'), 'Lowest level'),
#  ('Alcoa', Decimal('19882.16'), 'Lowest level'),
#  ('Energy Transfer Equity', Decimal('19539.86'), 'Lowest level'),
#  ('Baker Hughes', Decimal('19409.95'), 'Lowest level'),
#  ('Biogen', Decimal('19386.53'), 'Lowest level'),
#  ('Tech Data', Decimal('19218.88'), 'Lowest level'),
#  ('ConAgra Foods', Decimal('19142.48'), 'Lowest level'),
#  ('Express Scripts Holding', Decimal('19090.45'), 'Lowest level'),
#  ('Praxair', Decimal('19023.36'), 'Lowest level'),
#  ('AECOM', Decimal('18491.51'), 'Lowest level'),
#  ('PBF Energy', Decimal('18285.93'), 'Lowest level'),
#  ('VF', Decimal('18251.39'), 'Lowest level'),
#  ('Johnson & Johnson', Decimal('18242.74'), 'Lowest level'),
#  ('L Brands', Decimal('17439.25'), 'Lowest level'),
#  ('MGM Resorts International', Decimal('16976.76'), 'Lowest level'),
#  ('Liberty Mutual Insurance Group', Decimal('16923.55'), 'Lowest level'),
#  ('Gap', Decimal('16791.91'), 'Lowest level'),
#  ('Univar', Decimal('16626.60'), 'Lowest level'),
#  ('Eastman Chemical', Decimal('16303.42'), 'Lowest level'),
#  ('Marsh & McLennan', Decimal('16257.21'), 'Lowest level'),
#  ('Voya Financial', Decimal('15782.23'), 'Lowest level'),
#  ('Parker-Hannifin', Decimal('15727.19'), 'Lowest level'),
#  ('Staples', Decimal('15716.26'), 'Lowest level'),
#  ('ConocoPhillips', Decimal('15578.40'), 'Lowest level'),
#  ('Microsoft', Decimal('15454.01'), 'Lowest level'),
#  ('McKesson', Decimal('15184.46'), 'Lowest level'),
#  ('Principal Financial', Decimal('15177.80'), 'Lowest level'),
#  ('Starbucks', Decimal('14875.19'), 'Lowest level'),
#  ('SpartanNash', Decimal('14629.16'), 'Lowest level'),
#  ('Tesoro', Decimal('14482.60'), 'Lowest level'),
#  ('Owens & Minor', Decimal('13507.23'), 'Lowest level'),
#  ('WestRock', Decimal('13282.42'), 'Lowest level'),
#  ('AES', Decimal('13038.64'), 'Lowest level'),
#  ('Comcast', Decimal('12868.38'), 'Lowest level'),
#  ('Northwestern Mutual', Decimal('11862.92'), 'Lowest level'),
#  ('Air Products & Chemicals', Decimal('11814.55'), 'Lowest level'),
#  ('Plains GP Holdings', Decimal('11531.70'), 'Lowest level'),
#  ('DTE Energy', Decimal('11501.84'), 'Lowest level'),
#  ('AbbVie', Decimal('11243.63'), 'Lowest level'),
#  ('Hertz Global Holdings', Decimal('10959.77'), 'Lowest level'),
#  ('World Fuel Services', Decimal('10833.11'), 'Lowest level'),
#  ('Marriott International', Decimal('10779.77'), 'Lowest level'),
#  ('PVH', Decimal('10699.35'), 'Lowest level'),
#  ('UPS', Decimal('10678.77'), 'Lowest level'),
#  ('Home Depot', Decimal('10667.46'), 'Lowest level'),
#  ('MasterCard', Decimal('10555.35'), 'Lowest level'),
#  ('HCA Holdings', Decimal('10323.23'), 'Lowest level'),
#  ('Autoliv', Decimal('10282.96'), 'Lowest level'),
#  ('Reinsurance Group of America', Decimal('10264.51'), 'Lowest level'),
#  ('Dollar Tree', Decimal('10212.06'), 'Lowest level'),
#  ('Reliance Steel & Aluminum', Decimal('10187.64'), 'Lowest level'),
#  ('Waste Management', Decimal('10067.87'), 'Lowest level'),
#  ('General Motors', Decimal('9995.05'), 'Lowest level'),
#  ('AIG', Decimal('9980.93'), 'Lowest level'),
#  ("O'Reilly Automotive", Decimal('9914.23'), 'Lowest level'),
#  ('WellCare Health Plans', Decimal('9743.13'), 'Lowest level'),
#  ('CBRE Group', Decimal('9715.71'), 'Lowest level'),
#  ('Newmont Mining', Decimal('9618.81'), 'Lowest level'),
#  ("Macy's", Decimal('9613.32'), 'Lowest level'),
#  ('Devon Energy', Decimal('9536.55'), 'Lowest level'),
#  ('Eli Lilly', Decimal('9339.20'), 'Lowest level'),
#  ('Xerox', Decimal('8759.93'), 'Lowest level'),
#  ('CBS', Decimal('8648.07'), 'Lowest level'),
#  ('Dow Chemical', Decimal('8431.81'), 'Lowest level'),
#  ('W.W. Grainger', Decimal('8384.61'), 'Lowest level'),
#  ('Publix Super Markets', Decimal('8364.40'), 'Lowest level'),
#  ('Danaher', Decimal('8133.47'), 'Lowest level'),
#  ('TIAA', Decimal('7971.51'), 'Lowest level'),
#  ('Corning', Decimal('7940.37'), 'Lowest level'),
#  ('MetLife', Decimal('7615.47'), 'Lowest level'),
#  ('Berkshire Hathaway', Decimal('7474.32'), 'Lowest level'),
#  ('C.H. Robinson Worldwide', Decimal('7460.32'), 'Lowest level'),
#  ('ManpowerGroup', Decimal('7313.08'), 'Lowest level'),
#  ('Cardinal Health', Decimal('7210.91'), 'Lowest level'),
#  ('Sonic Automotive', Decimal('7192.13'), 'Lowest level'),
#  ('Advance Auto Parts', Decimal('6962.07'), 'Lowest level'),
#  ('Liberty Interactive', Decimal('6497.70'), 'Lowest level'),
#  ('Genworth Financial', Decimal('6402.38'), 'Lowest level'),
#  ('Tenneco', Decimal('5739.63'), 'Lowest level'),
#  ('Veritiv', Decimal('5735.41'), 'Lowest level'),
#  ('Rite Aid', Decimal('5616.90'), 'Lowest level'),
#  ('NextEra Energy', Decimal('5321.23'), 'Lowest level'),
#  ('Universal Health Services', Decimal('5269.51'), 'Lowest level'),
#  ('Stryker', Decimal('4521.36'), 'Lowest level'),
#  ('Massachusetts Mutual Life Insurance', Decimal('3927.05'), 'Lowest level'),
#  ('Fannie Mae', Decimal('3780.53'), 'Lowest level'),
#  ('J.C. Penney', Decimal('3253.04'), 'Lowest level'),
#  ('Applied Materials', Decimal('3093.95'), 'Lowest level'),
#  ('Mohawk Industries', Decimal('3025.65'), 'Lowest level'),
#  ('Oneok', Decimal('2844.46'), 'Lowest level'),
#  ('Exxon Mobil', Decimal('2734.59'), 'Lowest level'),
#  ('Consolidated Edison', Decimal('2674.04'), 'Lowest level'),
#  ('Lennar', Decimal('2670.97'), 'Lowest level'),
#  ('Loews', Decimal('2566.22'), 'Lowest level'),
#  ('Lockheed Martin', Decimal('2440.31'), 'Lowest level'),
#  ('Micron Technology', Decimal('2438.51'), 'Lowest level'),
#  ('Sherwin-Williams', Decimal('2372.95'), 'Lowest level'),
#  ('INTL FCStone', Decimal('2372.11'), 'Lowest level'),
#  ('Bank of New York Mellon Corp.', Decimal('2155.98'), 'Lowest level'),
#  ('Priceline Group', Decimal('2129.24'), 'Lowest level'),
#  ('Ball', Decimal('1982.74'), 'Lowest level'),
#  ('Assurant', Decimal('1235.81'), 'Lowest level'),
#  ('Las Vegas Sands', Decimal('1113.29'), 'Lowest level'),
#  ('Bed Bath & Beyond', Decimal('1069.64'), 'Lowest level'),
#  ('Deere', Decimal('1036.57'), 'Lowest level'),
#  ('Level 3 Communications', Decimal('881.73'), 'Lowest level'),
#  ('Delta Air Lines', Decimal('859.64'), 'Lowest level'),
#  ('Nike', Decimal('390.25'), 'Lowest level')]

# %% [markdown]
# #### 42. We would now like to perform a similar calculation to the first, but we want to obtain the total amount spent by customers only in 2016 and 2017. Keep the same levels as in the previous question. Order with the top spending customers listed first.

# %%
# %%sql
#
# WITH sales_cte_2016_2017 AS (
# SELECT
#     company,
#     SUM(total_amt_usd) AS total_spend
# FROM orders_consolidated
# WHERE EXTRACT(YEAR FROM occurred_at) = 2016 OR EXTRACT(YEAR FROM occurred_at) = 2017
# GROUP BY company
# )
# SELECT
#     company,
#     total_spend,
#     CASE
#         WHEN total_spend < 100000 THEN 'Lowest level'
#         WHEN total_spend >= 100000 AND total_spend <= 200000 THEN 'Second level'
#         WHEN total_spend > 200000 THEN 'Highest level' END AS customer_level
# FROM sales_cte_2016_2017
# ORDER BY total_spend DESC
# Out:
#  * postgresql://postgres:***@localhost:5432/postgres
# 322 rows affected.
# [('Pacific Life', Decimal('255319.18'), 'Highest level'),
#  ('Mosaic', Decimal('172180.04'), 'Second level'),
#  ('CHS', Decimal('163471.78'), 'Second level'),
#  ('Core-Mark Holding', Decimal('148105.93'), 'Second level'),
#  ('Disney', Decimal('129157.38'), 'Second level'),
#  ('National Oilwell Varco', Decimal('121873.16'), 'Second level'),
#  ('Sears Holdings', Decimal('114003.21'), 'Second level'),
#  ('State Farm Insurance Cos.', Decimal('111810.55'), 'Second level'),
#  ('Fidelity National Financial', Decimal('110027.29'), 'Second level'),
#  ('BB&T Corp.', Decimal('107300.05'), 'Second level'),
#  ('Arrow Electronics', Decimal('105426.87'), 'Second level'),
#  ('United States Steel', Decimal('104452.39'), 'Second level'),
#  ('Walmart', Decimal('102363.34'), 'Second level'),
#  ('Jarden', Decimal('100993.44'), 'Second level'),
#  ('Target', Decimal('99778.69'), 'Lowest level'),
#  ('SunTrust Banks', Decimal('99125.76'), 'Lowest level'),
#  ('General Dynamics', Decimal('98377.59'), 'Lowest level'),
#  ('State Street Corp.', Decimal('96673.98'), 'Lowest level'),
#  ('Pfizer', Decimal('95339.33'), 'Lowest level'),
#  ('Raytheon', Decimal('94725.92'), 'Lowest level'),
#  ('Goodyear Tire & Rubber', Decimal('90258.51'), 'Lowest level'),
#  ("Kohl's", Decimal('90105.16'), 'Lowest level'),
#  ('D.R. Horton', Decimal('89544.66'), 'Lowest level'),
#  ('Franklin Resources', Decimal('86555.72'), 'Lowest level'),
#  ('Allstate', Decimal('85842.14'), 'Lowest level'),
#  ('Bristol-Myers Squibb', Decimal('85495.29'), 'Lowest level'),
#  ('Occidental Petroleum', Decimal('85440.98'), 'Lowest level'),
#  ('IBM', Decimal('85282.63'), 'Lowest level'),
#  ('Leucadia National', Decimal('84784.63'), 'Lowest level'),
#  ('Western Digital', Decimal('84481.77'), 'Lowest level'),
#  ('Archer Daniels Midland', Decimal('84344.61'), 'Lowest level'),
#  ('Wells Fargo', Decimal('83886.20'), 'Lowest level'),
#  ('Fluor', Decimal('83287.31'), 'Lowest level'),
#  ('Emerson Electric', Decimal('82527.79'), 'Lowest level'),
#  ('Amgen', Decimal('82013.05'), 'Lowest level'),
#  ('Synnex', Decimal('81722.47'), 'Lowest level'),
#  ('Caterpillar', Decimal('81700.33'), 'Lowest level'),
#  ('PG&E Corp.', Decimal('81697.27'), 'Lowest level'),
#  ('KKR', Decimal('81222.69'), 'Lowest level'),
#  ('Duke Energy', Decimal('80494.19'), 'Lowest level'),
#  ('Intel', Decimal('79491.18'), 'Lowest level'),
#  ('HollyFrontier', Decimal('79488.37'), 'Lowest level'),
#  ('Celgene', Decimal('78164.23'), 'Lowest level'),
#  ('DISH Network', Decimal('78105.13'), 'Lowest level'),
#  ('Lincoln National', Decimal('77628.11'), 'Lowest level'),
#  ('Supervalu', Decimal('77271.55'), 'Lowest level'),
#  ('Nationwide', Decimal('76630.92'), 'Lowest level'),
#  ('CDW', Decimal('76392.22'), 'Lowest level'),
#  ('Centene', Decimal('76364.92'), 'Lowest level'),
#  ('Jacobs Engineering Group', Decimal('75600.49'), 'Lowest level'),
#  ('Broadcom', Decimal('75130.50'), 'Lowest level'),
#  ('Crown Holdings', Decimal('75110.81'), 'Lowest level'),
#  ('Public Service Enterprise Group', Decimal('73833.01'), 'Lowest level'),
#  ('Sysco', Decimal('73636.55'), 'Lowest level'),
#  ('3M', Decimal('70895.01'), 'Lowest level'),
#  ('Prudential Financial', Decimal('67868.76'), 'Lowest level'),
#  ('Hormel Foods', Decimal('67706.16'), 'Lowest level'),
#  ('Avis Budget Group', Decimal('67410.18'), 'Lowest level'),
#  ('Thermo Fisher Scientific', Decimal('66922.08'), 'Lowest level'),
#  ('Freddie Mac', Decimal('66821.09'), 'Lowest level'),
#  ('Avnet', Decimal('66812.24'), 'Lowest level'),
#  ('Molina Healthcare', Decimal('66381.57'), 'Lowest level'),
#  ('AutoZone', Decimal('65958.07'), 'Lowest level'),
#  ('EOG Resources', Decimal('65894.28'), 'Lowest level'),
#  ('Ford Motor', Decimal('65571.97'), 'Lowest level'),
#  ('Boeing', Decimal('65091.39'), 'Lowest level'),
#  ('Dominion Resources', Decimal('64604.00'), 'Lowest level'),
#  ('CarMax', Decimal('64251.56'), 'Lowest level'),
#  ('Citigroup', Decimal('63746.46'), 'Lowest level'),
#  ('Precision Castparts', Decimal('63743.89'), 'Lowest level'),
#  ('Cognizant Technology Solutions', Decimal('62504.05'), 'Lowest level'),
#  ('Phillips 66', Decimal('62166.06'), 'Lowest level'),
#  ('Time Warner', Decimal('61892.96'), 'Lowest level'),
#  ('Genuine Parts', Decimal('61561.44'), 'Lowest level'),
#  ('Visa', Decimal('61255.50'), 'Lowest level'),
#  ('Verizon', Decimal('61216.36'), 'Lowest level'),
#  ('Aetna', Decimal('60874.20'), 'Lowest level'),
#  ('Anadarko Petroleum', Decimal('60608.48'), 'Lowest level'),
#  ('Kroger', Decimal('59946.40'), 'Lowest level'),
#  ('NRG Energy', Decimal('59727.21'), 'Lowest level'),
#  ('International Paper', Decimal('59086.76'), 'Lowest level'),
#  ('Time Warner Cable', Decimal('57130.53'), 'Lowest level'),
#  ('eBay', Decimal('57088.17'), 'Lowest level'),
#  ('Eversource Energy', Decimal('57059.76'), 'Lowest level'),
#  ('Discover Financial Services', Decimal('57035.05'), 'Lowest level'),
#  ('Community Health Systems', Decimal('56644.60'), 'Lowest level'),
#  ('Honeywell International', Decimal('56479.14'), 'Lowest level'),
#  ("Toys 'R' Us", Decimal('56179.21'), 'Lowest level'),
#  ('HP', Decimal('56162.34'), 'Lowest level'),
#  ('United Technologies', Decimal('55965.46'), 'Lowest level'),
#  ('J.P. Morgan Chase', Decimal('55802.00'), 'Lowest level'),
#  ('Philip Morris International', Decimal('52570.66'), 'Lowest level'),
#  ('Valero Energy', Decimal('52020.60'), 'Lowest level'),
#  ('Freeport-McMoRan', Decimal('49162.70'), 'Lowest level'),
#  ('Office Depot', Decimal('49027.10'), 'Lowest level'),
#  ('Qualcomm', Decimal('48862.43'), 'Lowest level'),
#  ('Entergy', Decimal('48856.27'), 'Lowest level'),
#  ('BlackRock', Decimal('48670.82'), 'Lowest level'),
#  ('Northrop Grumman', Decimal('48578.16'), 'Lowest level'),
#  ('Texas Instruments', Decimal('48529.08'), 'Lowest level'),
#  ('Paccar', Decimal('47685.04'), 'Lowest level'),
#  ('Performance Food Group', Decimal('47645.86'), 'Lowest level'),
#  ('USAA', Decimal('46822.63'), 'Lowest level'),
#  ('Chevron', Decimal('46725.41'), 'Lowest level'),
#  ('Nucor', Decimal('46401.28'), 'Lowest level'),
#  ('First Data', Decimal('45967.25'), 'Lowest level'),
#  ('Walgreens Boots Alliance', Decimal('45276.27'), 'Lowest level'),
#  ('Aflac', Decimal('45241.58'), 'Lowest level'),
#  ('Cisco Systems', Decimal('45220.15'), 'Lowest level'),
#  ('Anthem', Decimal('44875.42'), 'Lowest level'),
#  ('PayPal Holdings', Decimal('44735.91'), 'Lowest level'),
#  ('CenturyLink', Decimal('44535.04'), 'Lowest level'),
#  ('Alphabet', Decimal('44407.22'), 'Lowest level'),
#  ("Land O'Lakes", Decimal('44322.12'), 'Lowest level'),
#  ('Merck', Decimal('43631.17'), 'Lowest level'),
#  ('Marathon Petroleum', Decimal('43431.35'), 'Lowest level'),
#  ("Lowe's", Decimal('43292.28'), 'Lowest level'),
#  ('Progressive', Decimal('43011.91'), 'Lowest level'),
#  ('Charter Communications', Decimal('42773.23'), 'Lowest level'),
#  ('CST Brands', Decimal('42674.22'), 'Lowest level'),
#  ('United Continental Holdings', Decimal('42573.91'), 'Lowest level'),
#  ('PNC Financial Services Group', Decimal('42237.28'), 'Lowest level'),
#  ('American Express', Decimal('41864.13'), 'Lowest level'),
#  ('Cigna', Decimal('41733.53'), 'Lowest level'),
#  ('TJX', Decimal('41712.71'), 'Lowest level'),
#  ('Global Partners', Decimal('41690.40'), 'Lowest level'),
#  ('American Family Insurance Group', Decimal('41540.98'), 'Lowest level'),
#  ('BorgWarner', Decimal('41242.06'), 'Lowest level'),
#  ('Colgate-Palmolive', Decimal('40818.88'), 'Lowest level'),
#  ('FedEx', Decimal('40738.29'), 'Lowest level'),
#  ('NGL Energy Partners', Decimal('40607.07'), 'Lowest level'),
#  ('Southwest Airlines', Decimal('40539.45'), 'Lowest level'),
#  ('Cameron International', Decimal('40370.52'), 'Lowest level'),
#  ('Farmers Insurance Exchange', Decimal('39949.41'), 'Lowest level'),
#  ('Stanley Black & Decker', Decimal('39805.61'), 'Lowest level'),
#  ('Kellogg', Decimal('39586.71'), 'Lowest level'),
#  ('New York Life Insurance', Decimal('39379.37'), 'Lowest level'),
#  ('Best Buy', Decimal('39104.09'), 'Lowest level'),
#  ('Icahn Enterprises', Decimal('38851.15'), 'Lowest level'),
#  ('Ameriprise Financial', Decimal('38619.07'), 'Lowest level'),
#  ('Sempra Energy', Decimal('38569.85'), 'Lowest level'),
#  ('GameStop', Decimal('38469.65'), 'Lowest level'),
#  ('FirstEnergy', Decimal('38215.53'), 'Lowest level'),
#  ('Thrivent Financial for Lutherans', Decimal('38204.46'), 'Lowest level'),
#  ('Estee Lauder', Decimal('38198.82'), 'Lowest level'),
#  ('Johnson Controls', Decimal('37796.28'), 'Lowest level'),
#  ('Ally Financial', Decimal('37653.96'), 'Lowest level'),
#  ('Ecolab', Decimal('37527.67'), 'Lowest level'),
#  ('Mondelez International', Decimal('37465.37'), 'Lowest level'),
#  ('ADP', Decimal('37456.04'), 'Lowest level'),
#  ('Edison International', Decimal('37010.95'), 'Lowest level'),
#  ('EMC', Decimal('36982.12'), 'Lowest level'),
#  ('Omnicom Group', Decimal('36801.71'), 'Lowest level'),
#  ('Republic Services', Decimal('36695.68'), 'Lowest level'),
#  ('Reynolds American', Decimal('36668.29'), 'Lowest level'),
#  ('Altria Group', Decimal('36318.37'), 'Lowest level'),
#  ('Murphy USA', Decimal('36294.27'), 'Lowest level'),
#  ('R.R. Donnelley & Sons', Decimal('36218.43'), 'Lowest level'),
#  ('Becton Dickinson', Decimal('35961.76'), 'Lowest level'),
#  ('CSX', Decimal('35759.70'), 'Lowest level'),
#  ('Henry Schein', Decimal('35487.34'), 'Lowest level'),
#  ('Cummins', Decimal('34839.82'), 'Lowest level'),
#  ('Southern', Decimal('34809.88'), 'Lowest level'),
#  ('News Corp.', Decimal('34675.03'), 'Lowest level'),
#  ('DaVita HealthCare Partners', Decimal('33982.78'), 'Lowest level'),
#  ('Viacom', Decimal('33673.86'), 'Lowest level'),
#  ('Monsanto', Decimal('33253.29'), 'Lowest level'),
#  ('AutoNation', Decimal('33196.76'), 'Lowest level'),
#  ('Tenet Healthcare', Decimal('33028.08'), 'Lowest level'),
#  ('Humana', Decimal('32937.93'), 'Lowest level'),
#  ('Halliburton', Decimal('32645.38'), 'Lowest level'),
#  ('American Electric Power', Decimal('32044.55'), 'Lowest level'),
#  ('Enterprise Products Partners', Decimal('31971.72'), 'Lowest level'),
#  ('HD Supply Holdings', Decimal('31899.58'), 'Lowest level'),
#  ('Coca-Cola', Decimal('31593.08'), 'Lowest level'),
#  ('Nordstrom', Decimal('31273.02'), 'Lowest level'),
#  ('Oracle', Decimal('31231.56'), 'Lowest level'),
#  ('Costco', Decimal('30741.01'), 'Lowest level'),
#  ('Group 1 Automotive', Decimal('30708.92'), 'Lowest level'),
#  ('PepsiCo', Decimal('30095.72'), 'Lowest level'),
#  ('American Airlines Group', Decimal('30083.18'), 'Lowest level'),
#  ('Kimberly-Clark', Decimal('29151.21'), 'Lowest level'),
#  ('Amazon.com', Decimal('28678.06'), 'Lowest level'),
#  ('Yum Brands', Decimal('28296.53'), 'Lowest level'),
#  ('Health Net', Decimal('27733.33'), 'Lowest level'),
#  ('US Foods Holding', Decimal('27074.63'), 'Lowest level'),
#  ('Dean Foods', Decimal('26514.93'), 'Lowest level'),
#  ('Penske Automotive Group', Decimal('26485.87'), 'Lowest level'),
#  ('Textron', Decimal('26339.70'), 'Lowest level'),
#  ('Campbell Soup', Decimal('25765.95'), 'Lowest level'),
#  ('Kraft Heinz', Decimal('25765.17'), 'Lowest level'),
#  ('Ingram Micro', Decimal('25198.55'), 'Lowest level'),
#  ('Union Pacific', Decimal('25107.81'), 'Lowest level'),
#  ('Ross Stores', Decimal('24961.87'), 'Lowest level'),
#  ('CVS Health', Decimal('23667.51'), 'Lowest level'),
#  ('Facebook', Decimal('23522.79'), 'Lowest level'),
#  ('Procter & Gamble', Decimal('22961.03'), 'Lowest level'),
#  ('Unum Group', Decimal('22734.13'), 'Lowest level'),
#  ('Baxter International', Decimal('22681.17'), 'Lowest level'),
#  ('Navistar International', Decimal('22484.81'), 'Lowest level'),
#  ('L-3 Communications', Decimal('22266.77'), 'Lowest level'),
#  ('Norfolk Southern', Decimal('22100.01'), 'Lowest level'),
#  ('PPG Industries', Decimal('21960.88'), 'Lowest level'),
#  ('UnitedHealth Group', Decimal('21937.08'), 'Lowest level'),
#  ('Aramark', Decimal('21692.01'), 'Lowest level'),
#  ('Morgan Stanley', Decimal('20277.57'), 'Lowest level'),
#  ('Hartford Financial Services Group', Decimal('20257.43'), 'Lowest level'),
#  ('Whole Foods Market', Decimal('20240.66'), 'Lowest level'),
#  ("Peter Kiewit Sons'", Decimal('20232.97'), 'Lowest level'),
#  ('Huntsman', Decimal('20092.35'), 'Lowest level'),
#  ('Xcel Energy', Decimal('19975.91'), 'Lowest level'),
#  ('Alcoa', Decimal('19882.16'), 'Lowest level'),
#  ('Energy Transfer Equity', Decimal('19539.86'), 'Lowest level'),
#  ('Biogen', Decimal('19386.53'), 'Lowest level'),
#  ('Tech Data', Decimal('19218.88'), 'Lowest level'),
#  ('AT&T', Decimal('19191.14'), 'Lowest level'),
#  ('ConAgra Foods', Decimal('19142.48'), 'Lowest level'),
#  ('Express Scripts Holding', Decimal('19090.45'), 'Lowest level'),
#  ('Praxair', Decimal('19023.36'), 'Lowest level'),
#  ('Hilton Worldwide Holdings', Decimal('18745.86'), 'Lowest level'),
#  ('AECOM', Decimal('18491.51'), 'Lowest level'),
#  ('VF', Decimal('18251.39'), 'Lowest level'),
#  ('Johnson & Johnson', Decimal('18242.74'), 'Lowest level'),
#  ('Computer Sciences', Decimal('18216.89'), 'Lowest level'),
#  ('Tyson Foods', Decimal('18088.57'), 'Lowest level'),
#  ('Exelon', Decimal('18081.58'), 'Lowest level'),
#  ('Travelers Cos.', Decimal('17808.16'), 'Lowest level'),
#  ('L Brands', Decimal('17439.25'), 'Lowest level'),
#  ('MGM Resorts International', Decimal('16976.76'), 'Lowest level'),
#  ('Liberty Mutual Insurance Group', Decimal('16923.55'), 'Lowest level'),
#  ('Gap', Decimal('16791.91'), 'Lowest level'),
#  ('Univar', Decimal('16626.60'), 'Lowest level'),
#  ('Eastman Chemical', Decimal('16303.42'), 'Lowest level'),
#  ('Marsh & McLennan', Decimal('16257.21'), 'Lowest level'),
#  ('DuPont', Decimal('15862.76'), 'Lowest level'),
#  ('Voya Financial', Decimal('15782.23'), 'Lowest level'),
#  ('Staples', Decimal('15716.26'), 'Lowest level'),
#  ('ConocoPhillips', Decimal('15578.40'), 'Lowest level'),
#  ('Microsoft', Decimal('15454.01'), 'Lowest level'),
#  ('McKesson', Decimal('15184.46'), 'Lowest level'),
#  ('Principal Financial', Decimal('15177.80'), 'Lowest level'),
#  ('Starbucks', Decimal('14875.19'), 'Lowest level'),
#  ('SpartanNash', Decimal('14629.16'), 'Lowest level'),
#  ('Tesoro', Decimal('14482.60'), 'Lowest level'),
#  ('Masco', Decimal('14330.44'), 'Lowest level'),
#  ('Owens & Minor', Decimal('13507.23'), 'Lowest level'),
#  ('WestRock', Decimal('13282.42'), 'Lowest level'),
#  ('AES', Decimal('13038.64'), 'Lowest level'),
#  ('Comcast', Decimal('12868.38'), 'Lowest level'),
#  ('Northwestern Mutual', Decimal('11862.92'), 'Lowest level'),
#  ('Air Products & Chemicals', Decimal('11814.55'), 'Lowest level'),
#  ('General Electric', Decimal('11743.47'), 'Lowest level'),
#  ('Plains GP Holdings', Decimal('11531.70'), 'Lowest level'),
#  ('DTE Energy', Decimal('11501.84'), 'Lowest level'),
#  ('AbbVie', Decimal('11243.63'), 'Lowest level'),
#  ('Hertz Global Holdings', Decimal('10959.77'), 'Lowest level'),
#  ('World Fuel Services', Decimal('10833.11'), 'Lowest level'),
#  ('Marriott International', Decimal('10779.77'), 'Lowest level'),
#  ('PVH', Decimal('10699.35'), 'Lowest level'),
#  ('UPS', Decimal('10678.77'), 'Lowest level'),
#  ('MasterCard', Decimal('10555.35'), 'Lowest level'),
#  ('PBF Energy', Decimal('10535.88'), 'Lowest level'),
#  ('HCA Holdings', Decimal('10323.23'), 'Lowest level'),
#  ('Autoliv', Decimal('10282.96'), 'Lowest level'),
#  ('Reinsurance Group of America', Decimal('10264.51'), 'Lowest level'),
#  ('Dollar Tree', Decimal('10212.06'), 'Lowest level'),
#  ('Reliance Steel & Aluminum', Decimal('10187.64'), 'Lowest level'),
#  ('Waste Management', Decimal('10067.87'), 'Lowest level'),
#  ('General Motors', Decimal('9995.05'), 'Lowest level'),
#  ('AIG', Decimal('9980.93'), 'Lowest level'),
#  ('Western Refining', Decimal('9855.41'), 'Lowest level'),
#  ('WellCare Health Plans', Decimal('9743.13'), 'Lowest level'),
#  ('CBRE Group', Decimal('9715.71'), 'Lowest level'),
#  ('Newmont Mining', Decimal('9618.81'), 'Lowest level'),
#  ("Macy's", Decimal('9613.32'), 'Lowest level'),
#  ('Devon Energy', Decimal('9536.55'), 'Lowest level'),
#  ('Apple', Decimal('9341.65'), 'Lowest level'),
#  ('Eli Lilly', Decimal('9339.20'), 'Lowest level'),
#  ('Xerox', Decimal('8759.93'), 'Lowest level'),
#  ('CBS', Decimal('8648.07'), 'Lowest level'),
#  ('Dow Chemical', Decimal('8431.81'), 'Lowest level'),
#  ('W.W. Grainger', Decimal('8384.61'), 'Lowest level'),
#  ('Publix Super Markets', Decimal('8364.40'), 'Lowest level'),
#  ('Danaher', Decimal('8133.47'), 'Lowest level'),
#  ('TIAA', Decimal('7971.51'), 'Lowest level'),
#  ('Corning', Decimal('7940.37'), 'Lowest level'),
#  ('MetLife', Decimal('7615.47'), 'Lowest level'),
#  ('Berkshire Hathaway', Decimal('7474.32'), 'Lowest level'),
#  ('C.H. Robinson Worldwide', Decimal('7460.32'), 'Lowest level'),
#  ('ManpowerGroup', Decimal('7313.08'), 'Lowest level'),
#  ('Cardinal Health', Decimal('7210.91'), 'Lowest level'),
#  ('Sonic Automotive', Decimal('7192.13'), 'Lowest level'),
#  ('Advance Auto Parts', Decimal('6962.07'), 'Lowest level'),
#  ('Liberty Interactive', Decimal('6497.70'), 'Lowest level'),
#  ('Genworth Financial', Decimal('6402.38'), 'Lowest level'),
#  ('Tenneco', Decimal('5739.63'), 'Lowest level'),
#  ('Veritiv', Decimal('5735.41'), 'Lowest level'),
#  ('Rite Aid', Decimal('5616.90'), 'Lowest level'),
#  ('NextEra Energy', Decimal('5321.23'), 'Lowest level'),
#  ('Universal Health Services', Decimal('5269.51'), 'Lowest level'),
#  ('Stryker', Decimal('4521.36'), 'Lowest level'),
#  ('Fannie Mae', Decimal('3780.53'), 'Lowest level'),
#  ('J.C. Penney', Decimal('3253.04'), 'Lowest level'),
#  ('Applied Materials', Decimal('3093.95'), 'Lowest level'),
#  ('Mohawk Industries', Decimal('3025.65'), 'Lowest level'),
#  ('Oneok', Decimal('2844.46'), 'Lowest level'),
#  ('Exxon Mobil', Decimal('2734.59'), 'Lowest level'),
#  ('Consolidated Edison', Decimal('2674.04'), 'Lowest level'),
#  ('Lennar', Decimal('2670.97'), 'Lowest level'),
#  ('Loews', Decimal('2566.22'), 'Lowest level'),
#  ('Lockheed Martin', Decimal('2440.31'), 'Lowest level'),
#  ('Micron Technology', Decimal('2438.51'), 'Lowest level'),
#  ('Sherwin-Williams', Decimal('2372.95'), 'Lowest level'),
#  ('INTL FCStone', Decimal('2372.11'), 'Lowest level'),
#  ('Bank of New York Mellon Corp.', Decimal('2155.98'), 'Lowest level'),
#  ('Priceline Group', Decimal('2129.24'), 'Lowest level'),
#  ('Ball', Decimal('1982.74'), 'Lowest level'),
#  ('Assurant', Decimal('1235.81'), 'Lowest level'),
#  ('Las Vegas Sands', Decimal('1113.29'), 'Lowest level'),
#  ('Deere', Decimal('1036.57'), 'Lowest level'),
#  ('Delta Air Lines', Decimal('859.64'), 'Lowest level'),
#  ('Nike', Decimal('390.25'), 'Lowest level')]
